# %% [markdown]
# # Import libraries and prepare files

# %% [markdown]
# Import necessary libraries and load all the forum posts in the folder. Check that folder is correct.

# %%
import nltk
import re
from nltk.corpus import stopwords
import pandas
import gensim

# Get all filenames
corpus = nltk.corpus.PlaintextCorpusReader('../WebScraper/seedly-forum/', '.+\.csv')
fids = corpus.fileids()

isVectorBuild = False

fids
# Out:
# ['99.co Event CPF Property Investments 1168.csv',
#  '99.co Event Condominium Property 4341.csv',
#  '99.co Event Condominium Property Investments 1167.csv',
#  '99.co Event EC Condominium Condominium Property 4331.csv',
#  '99.co Event General Investments Property 1132.csv',
#  '99.co Event HDB BTO Investments Property 1124.csv',
#  '99.co Event HDB BTO Investments Property 1169.csv',
#  '99.co Event Investments HDB BTO Property 1166.csv',
#  '99.co Event Investments Loans 1140.csv',
#  '99.co Event Investments Property 1121.csv',
#  '99.co Event Investments Property 1128.csv',
#  '99.co Event Investments Property 1129.csv',
#  '99.co Event Investments Property 1131.csv',
#  '99.co Event Investments Property 1133.csv',
#  '99.co Event Investments Property 1135.csv',
#  '99.co Event Investments Property 1137.csv',
#  '99.co Event Investments Property 1139.csv',
#  '99.co Event Investments Property General 1123.csv',
#  '99.co Event Investments Property General 1126.csv',
#  '99.co Event Investments Property HDB BTO 1125.csv',
#  '99.co Event Investments Property HDB BTO Condominium 1127.csv',
#  '99.co Event Investments REITs Property 1136.csv',
#  '99.co Event Investments REITs Property 1138.csv',
#  '99.co Event Loans 7129.csv',
#  '99.co Event Loans 7130.csv',
#  '99.co Event Loans Property 4315.csv',
#  '99.co Event Property 4346.csv',
#  '99.co Event Property Condominium 4244.csv',
#  '99.co Event Property Condominium 4326.csv',
#  '99.co Event Property Condominium 4348.csv',
#  '99.co Event Property General 4266.csv',
#  '99.co Event Property Investments 1119.csv',
#  '99.co Event Property Investments 1122.csv',
#  '99.co Event Property Investments 1170.csv',
#  '99.co Event Property Investments 1229.csv',
#  '99.co Event Property Investments 1328.csv',
#  '99.co Event Property Investments Condominium 1193.csv',
#  '99.co Event Property Savings 4311.csv',
#  '99.co Event Resale HDB Investments Property Condominium 1134.csv',
#  'AIA Life Protection Investment Linked Policies (ILP) Insurance 3724.csv',
#  'AMA 1M65 CPF 6339.csv',
#  'AMA 1M65 CPF 6344.csv',
#  'AMA 1M65 CPF Expenses Tracking Loans 6288.csv',
#  'AMA 1M65 CPF Investments 3115.csv',
#  'AMA 1M65 CPF Policies 6309.csv',
#  'AMA 1M65 CPF Retirement 5566.csv',
#  'AMA 1M65 Career Investments Savings 3125.csv',
#  'AMA 1M65 Career Investments Savings 5928.csv',
#  'AMA 1M65 Expenses Tracking Savings Family 5343.csv',
#  'AMA 1M65 Family Investments Retirement 3132.csv',
#  'AMA 1M65 Family Retirement CPF 5341.csv',
#  'AMA 1M65 Family Savings 5336.csv',
#  'AMA 1M65 Financial Planners CPF Investments 3096.csv',
#  'AMA 1M65 Insurance 4011.csv',
#  'AMA 1M65 Investments 3036.csv',
#  'AMA 1M65 Investments 3046.csv',
#  'AMA 1M65 Investments 3113.csv',
#  'AMA 1M65 Investments 3130.csv',
#  'AMA 1M65 Investments 3131.csv',
#  'AMA 1M65 Investments 3135.csv',
#  'AMA 1M65 Investments 3136.csv',
#  'AMA 1M65 Investments CPF 3110.csv',
#  'AMA 1M65 Lifestyle Savings Career Investments 3147.csv',
#  'AMA 1M65 Property 4372.csv',
#  'AMA 1M65 Retirement Investments CPF 3094.csv',
#  'AMA 1M65 Savings CPF 6334.csv',
#  'AMA 1M65 Savings CPF Retirement 5585.csv',
#  'AMA 1M65 Savings Career Salary CPF Investments 2973.csv',
#  'AMA 1M65 Savings Career Salary CPF Investments 6985.csv',
#  'AMA 1M65 Savings Investments 3092.csv',
#  'AMA 1M65 Savings Policies CPF 6338.csv',
#  'AMA Christopher Tan CPF Retirement Savings Investments 2801.csv',
#  'AMA Christopher Tan Insurance MoneyOwl 3858.csv',
#  'AMA Christopher Tan Lifestyle 4968.csv',
#  'AMA Christopher Tan Lifestyle 4971.csv',
#  'AMA Christopher Tan Retirement Insurance Investments 2842.csv',
#  'AMA Christopher Tan Singtel ETF REITs Investments 2839.csv',
#  'AMA First Investment Credit Card Insurance Bank Account Investments 3663.csv',
#  'AMA First Investment Credit Card Insurance Bank Account Investments 3975.csv',
#  'AMA First Investment Investments 2799.csv',
#  'AMA First Investment Investments 2834.csv',
#  'AMA First Investment Investments 2836.csv',
#  'AMA First Investment Investments 2838.csv',
#  'AMA First Investment Investments 2846.csv',
#  'AMA Investment Moats Cryptocurrency Investments 3479.csv',
#  'AMA Investment Moats Insurance 4126.csv',
#  'AMA Investment Moats Insurance Investments General 3274.csv',
#  'AMA Investment Moats Investments 1797.csv',
#  'AMA Investment Moats Investments 2172.csv',
#  'AMA Investment Moats Investments 3375.csv',
#  'AMA Investment Moats Investments 3385.csv',
#  'AMA Investment Moats Investments 3468.csv',
#  'AMA Investment Moats Investments 3469.csv',
#  'AMA Investment Moats Investments 3471.csv',
#  'AMA Investment Moats Investments 3472.csv',
#  'AMA Investment Moats Investments 3473.csv',
#  'AMA Investment Moats Investments 3476.csv',
#  'AMA Investment Moats Investments 3477.csv',
#  'AMA Investment Moats Investments 3481.csv',
#  'AMA Investment Moats Property 4530.csv',
#  'AMA SG Budget Babe Bank Account 7595.csv',
#  'AMA SG Budget Babe Career 6006.csv',
#  'AMA SG Budget Babe Career Bank Account 6004.csv',
#  'AMA SG Budget Babe Career General 5957.csv',
#  'AMA SG Budget Babe Career General Investments 3496.csv',
#  'AMA SG Budget Babe Credit Card 4319.csv',
#  'AMA SG Budget Babe General Bank Account 7602.csv',
#  'AMA SG Budget Babe General Property Insurance Bank Account 4054.csv',
#  'AMA SG Budget Babe Investments 3356.csv',
#  'AMA SG Budget Babe Investments General 3491.csv',
#  'AMA SG Budget Babe Property 4532.csv',
#  'AMA SG Budget Babe Property General 4489.csv',
#  'AMA SG Young Investment Career General 5897.csv',
#  'AMA SG Young Investment Career General 6584.csv',
#  'AMA SG Young Investment Credit Card 4308.csv',
#  'AMA SG Young Investment Family Savings Investments General 3382.csv',
#  'AMA SG Young Investment Fresh Graduates General Property 4495.csv',
#  'AMA SG Young Investment Fresh Graduates Investments 3357.csv',
#  'AMA SG Young Investment Fresh Graduates Investments General 3441.csv',
#  'AMA SG Young Investment General Credit Card 4309.csv',
#  'AMA SG Young Investment General Investments 3426.csv',
#  'AMA SG Young Investment Insurance 4107.csv',
#  'AMA SG Young Investment Insurance 4117.csv',
#  'AMA SG Young Investment Insurance 4125.csv',
#  'AMA SG Young Investment Insurance General 4118.csv',
#  'AMA SG Young Investment Investments 3244.csv',
#  'AMA SG Young Investment Investments 3379.csv',
#  'AMA SG Young Investment Investments 3384.csv',
#  'AMA SG Young Investment Investments 3407.csv',
#  'AMA SG Young Investment Investments 3412.csv',
#  'AMA SG Young Investment Investments 3421.csv',
#  'AMA SG Young Investment Investments 3422.csv',
#  'AMA SG Young Investment Investments 3423.csv',
#  'AMA SG Young Investment Investments 3433.csv',
#  'AMA SG Young Investment Investments 3436.csv',
#  'AMA SG Young Investment Investments General 3427.csv',
#  'AMA SG Young Investment Investments General 3429.csv',
#  'AMA SG Young Investment Investments General 3437.csv',
#  'AMA SG Young Investment Loans Investments 3420.csv',
#  'AMA SG Young Investment Savings Autowealth Stashaway Investments Robo-advisors 3293.csv',
#  'AMA SG Young Investment Savings Family 5375.csv',
#  'AMA SG Young Investment Savings Family General 5366.csv',
#  'AMA SG Young Investment Savings Fresh Graduates Career 5995.csv',
#  'AMA The Fifth Person CPF Investments 2783.csv',
#  'AMA The Fifth Person Cryptocurrency Investments 2764.csv',
#  'AMA The Fifth Person ETF Robo-Advisors Investments 879.csv',
#  'AMA The Fifth Person Funding Societies P2P Lending Investments 2776.csv',
#  'AMA The Fifth Person Investments 1669.csv',
#  'AMA The Fifth Person Investments 1701.csv',
#  'AMA The Fifth Person Investments 2121.csv',
#  'AMA The Fifth Person Investments 2431.csv',
#  'AMA The Fifth Person Investments 2433.csv',
#  'AMA The Fifth Person Investments 2584.csv',
#  'AMA The Fifth Person Investments 2593.csv',
#  'AMA The Fifth Person Investments 2678.csv',
#  'AMA The Fifth Person Investments 2692.csv',
#  'AMA The Fifth Person Investments 2695.csv',
#  'AMA The Fifth Person Investments 2699.csv',
#  'AMA The Fifth Person Investments 2702.csv',
#  'AMA The Fifth Person Investments 2705.csv',
#  'AMA The Fifth Person Investments 2706.csv',
#  'AMA The Fifth Person Investments 2711.csv',
#  'AMA The Fifth Person Investments 2712.csv',
#  'AMA The Fifth Person Investments 2714.csv',
#  'AMA The Fifth Person Investments 2715.csv',
#  'AMA The Fifth Person Investments 2717.csv',
#  'AMA The Fifth Person Investments 2718.csv',
#  'AMA The Fifth Person Investments 2720.csv',
#  'AMA The Fifth Person Investments 2721.csv',
#  'AMA The Fifth Person Investments 2722.csv',
#  'AMA The Fifth Person Investments 2723.csv',
#  'AMA The Fifth Person Investments 2728.csv',
#  'AMA The Fifth Person Investments 2737.csv',
#  'AMA The Fifth Person Investments 2739.csv',
#  'AMA The Fifth Person Investments 2742.csv',
#  'AMA The Fifth Person Investments 2743.csv',
#  'AMA The Fifth Person Investments 2744.csv',
#  'AMA The Fifth Person Investments 2745.csv',
#  'AMA The Fifth Person Investments 2746.csv',
#  'AMA The Fifth Person Investments 2747.csv',
#  'AMA The Fifth Person Investments 2751.csv',
#  'AMA The Fifth Person Investments 2752.csv',
#  'AMA The Fifth Person Investments 2754.csv',
#  'AMA The Fifth Person Investments 2757.csv',
#  'AMA The Fifth Person Investments 2759.csv',
#  'AMA The Fifth Person Investments 2761.csv',
#  'AMA The Fifth Person Investments 2762.csv',
#  'AMA The Fifth Person Investments 2768.csv',
#  'AMA The Fifth Person Investments 2769.csv',
#  'AMA The Fifth Person Investments 2782.csv',
#  'AMA The Fifth Person Investments Bank Account 2707.csv',
#  'AMA The Fifth Person Investments CPF 2701.csv',
#  'AMA The Fifth Person Investments Lifestyle Family Savings 1967.csv',
#  'AMA The Fifth Person Investments Savings 2793.csv',
#  'AMA The Fifth Person Investments UOB 2703.csv',
#  'AMA The Fifth Person Lifestyle Investments 1953.csv',
#  'AMA The Fifth Person Lifestyle Investments 2708.csv',
#  'AMA The Fifth Person P2P Lending Investments 2724.csv',
#  'AMA The Fifth Person Property Investments 2741.csv',
#  'AMA The Fifth Person Property Investments 4392.csv',
#  'AMA The Fifth Person Property REITs Investments 2725.csv',
#  'AMA The Fifth Person REITS Investments 2781.csv',
#  'AMA The Fifth Person REITs Investments 2700.csv',
#  'AMA The Fifth Person REITs Investments 2704.csv',
#  'AMA The Fifth Person REITs Investments 2775.csv',
#  'AMA The Fifth Person SSB Investments 2780.csv',
#  'AMA The Fifth Person STI ETF Singapore Saving Bonds (SSB) Investments 2731.csv',
#  'AMA The Fifth Person STI Investments 2735.csv',
#  'AMA The Fifth Person Savings Investments 2716.csv',
#  'AMA The Fifth Person Singtel Starhub Stocks Investments 2719.csv',
#  'AMA The Fifth Person Stocks Investments 2709.csv',
#  'AMA The Fifth Person Stocks Investments 2713.csv',
#  'AMA The Fifth Person Stocks Investments 2727.csv',
#  'AMA The Fifth Person Stocks Investments 2740.csv',
#  'AMEX KrisFlyer Ascend Card AMEX Singapore KrisFlyer Card CITI PremierMiles Visa Card Credit Card 4284.csv',
#  'AMEX Singapore KrisFlyer Card Credit Card 3963.csv',
#  'AMEX Singapore KrisFlyer Card Credit Card 4264.csv',
#  'AMEX True Cashback Card POSB Everyday Card Lifestyle Travel Credit Card 4324.csv',
#  'AVIVA MyWholeLifePlan AMA Christopher Tan CPF Retirement 5546.csv',
#  'AXA Life Insurance Investment Linked Policies (ILP) Investments 425.csv',
#  'Apple Investments Trading Securities Equities Stocks 2252.csv',
#  'Apple Stocks Investments 1997.csv',
#  'Arcc Event Investments 1361.csv',
#  'Arcc Event Investments Bonds 1360.csv',
#  'Arcc Event Investments Forex (FX) Dividends 1367.csv',
#  'Arcc Event Investments Stocks 1368.csv',
#  'BOC Family Card YouTrip Credit Card 4096.csv',
#  'Bank Account 7265.csv',
#  'Bank Account 7276.csv',
#  'Bank Account 7282.csv',
#  'Bank Account 7306.csv',
#  'Bank Account 7308.csv',
#  'Bank Account 7309.csv',
#  'Bank Account 7316.csv',
#  'Bank Account 7339.csv',
#  'Bank Account 7375.csv',
#  'Bank Account 7387.csv',
#  'Bank Account 7389.csv',
#  'Bank Account 7391.csv',
#  'Bank Account 7417.csv',
#  'Bank Account 7424.csv',
#  'Bank Account 7432.csv',
#  'Bank Account 7435.csv',
#  'Bank Account 7443.csv',
#  'Bank Account 7445.csv',
#  'Bank Account 7449.csv',
#  'Bank Account 7459.csv',
#  'Bank Account 7475.csv',
#  'Bank Account 7477.csv',
#  'Bank Account 7481.csv',
#  'Bank Account 7482.csv',
#  'Bank Account 7483.csv',
#  'Bank Account 7486.csv',
#  'Bank Account 7487.csv',
#  'Bank Account 7492.csv',
#  'Bank Account 7497.csv',
#  'Bank Account 7502.csv',
#  'Bank Account 7503.csv',
#  'Bank Account 7509.csv',
#  'Bank Account 7510.csv',
#  'Bank Account 7525.csv',
#  'Bank Account 7527.csv',
#  'Bank Account 7528.csv',
#  'Bank Account 7533.csv',
#  'Bank Account 7547.csv',
#  'Bank Account 7550.csv',
#  'Bank Account 7551.csv',
#  'Bank Account 7563.csv',
#  'Bank Account 7578.csv',
#  'Bank Account 7592.csv',
#  'Bank Account 7596.csv',
#  'Bank Account 7605.csv',
#  'Bank Account 7606.csv',
#  'Bank Account 7615.csv',
#  'Bank Account 7616.csv',
#  'Bank Account 7620.csv',
#  'Bank Account 7622.csv',
#  'Bank Account 7623.csv',
#  'Bank Account 7626.csv',
#  'Bank Account CPF Savings Lifestyle 4361.csv',
#  'Bank Account Credit Card 3950.csv',
#  'Bank Account Credit Card 3960.csv',
#  'Bank Account Credit Card 4005.csv',
#  'Bank Account Credit Card 4234.csv',
#  'Bank Account Credit Card 4249.csv',
#  'Bank Account Credit Card 4251.csv',
#  'Bank Account Credit Card 4298.csv',
#  'Bank Account Credit Card 4321.csv',
#  'Bank Account Credit Card 4336.csv',
#  'Bank Account Credit Card DBS 4055.csv',
#  'Bank Account Credit Card General 4289.csv',
#  'Bank Account Credit Card General 4320.csv',
#  'Bank Account Credit Card Lifestyle Savings 4198.csv',
#  'Bank Account Credit Card Savings 4086.csv',
#  'Bank Account Credit Card Savings 4138.csv',
#  'Bank Account Credit Card Savings Lifestyle 4030.csv',
#  'Bank Account Credit Card Shopping Lifestyle 4027.csv',
#  'Bank Account DBS 7273.csv',
#  'Bank Account DBS 7332.csv',
#  'Bank Account DBS Altitude Visa Signature Card DBS DBS Multiplier OCBC 360 OCBC Credit Card Savings Family Expenses 4033.csv',
#  'Bank Account DBS Multiplier DBS Salary Savings 7343.csv',
#  'Bank Account DBS Multiplier Singapore Saving Bonds (SSB) 7280.csv',
#  'Bank Account Family Savings 5287.csv',
#  'Bank Account Fixed Deposits Investments Savings 334.csv',
#  'Bank Account Fresh Graduates Bonds Investments Singapore Saving Bonds (SSB) DBS Savings 3040.csv',
#  'Bank Account Fresh Graduates Investments 2938.csv',
#  'Bank Account Fresh Graduates Singapore Saving Bonds (SSB) Savings 7522.csv',
#  'Bank Account General 7325.csv',
#  'Bank Account General 7383.csv',
#  'Bank Account General 7428.csv',
#  'Bank Account General 7556.csv',
#  'Bank Account General 7559.csv',
#  'Bank Account General 7571.csv',
#  'Bank Account General 7600.csv',
#  'Bank Account General 7607.csv',
#  'Bank Account General 7608.csv',
#  'Bank Account General 7612.csv',
#  'Bank Account General Investments 3483.csv',
#  'Bank Account General Investments 3486.csv',
#  'Bank Account Investments 2314.csv',
#  'Bank Account Investments 2446.csv',
#  'Bank Account Investments 2636.csv',
#  'Bank Account Investments 2908.csv',
#  'Bank Account Investments 2977.csv',
#  'Bank Account Investments 3007.csv',
#  'Bank Account Investments 3214.csv',
#  'Bank Account Investments 3230.csv',
#  'Bank Account Investments 3389.csv',
#  'Bank Account Investments 423.csv',
#  'Bank Account Investments 528.csv',
#  'Bank Account Investments 7539.csv',
#  'Bank Account Investments AMA Christopher Tan 2871.csv',
#  'Bank Account Investments DBS digiPortfolio 7271.csv',
#  'Bank Account Investments General 2966.csv',
#  'Bank Account Investments General 3246.csv',
#  'Bank Account Investments General 3360.csv',
#  'Bank Account Investments General 3365.csv',
#  'Bank Account Investments General 3409.csv',
#  'Bank Account Investments General 503.csv',
#  'Bank Account Investments Property 3026.csv',
#  'Bank Account Investments Savings 1489.csv',
#  'Bank Account Investments Savings 2264.csv',
#  'Bank Account Investments Savings 7355.csv',
#  'Bank Account Investments Savings DBS Multiplier Insurance 1425.csv',
#  'Bank Account Lifestyle General 4768.csv',
#  'Bank Account Loans 7189.csv',
#  'Bank Account Loans Credit Card Savings 4513.csv',
#  'Bank Account Loans Property 4373.csv',
#  'Bank Account Multi Currency Cards DBS Multi Currency Account 7275.csv',
#  'Bank Account OCBC FRANK Card OCBC 360 7298.csv',
#  'Bank Account PFF Panel 3 Seedly PFF 2019 7469.csv',
#  'Bank Account Policies CPF Retirement Insurance 4052.csv',
#  'Bank Account Property 4531.csv',
#  'Bank Account Retirement Investments 2978.csv',
#  'Bank Account Savings 7357.csv',
#  'Bank Account Savings 7367.csv',
#  'Bank Account Savings 7410.csv',
#  'Bank Account Savings 7414.csv',
#  'Bank Account Savings 7415.csv',
#  'Bank Account Savings 7416.csv',
#  'Bank Account Savings 7421.csv',
#  'Bank Account Savings 7422.csv',
#  'Bank Account Savings 7427.csv',
#  'Bank Account Savings 7444.csv',
#  'Bank Account Savings 7470.csv',
#  'Bank Account Savings 7485.csv',
#  'Bank Account Savings 7519.csv',
#  'Bank Account Savings Credit Card Shopping 4022.csv',
#  'Bank Account Savings DBS Multiplier 7610.csv',
#  'Bank Account Savings Family 5254.csv',
#  'Bank Account Savings Fixed Deposits Investments 356.csv',
#  'Bank Account Savings Investments 3292.csv',
#  'Bank Account Savings Lifestyle 4474.csv',
#  'Bank Account Savings Loans 7134.csv',
#  'Bank Account Savings Marriage 7374.csv',
#  'Bank Account Savings OCBC 360 DBS Multiplier 7476.csv',
#  'Bank Account Savings Standard Chartered DBS Multiplier 4395.csv',
#  'Bank Account Savings UOB OCBC 4495.csv',
#  'Bank Account Seedly 7300.csv',
#  'Bank Account Seedly 7413.csv',
#  'Bank Account Stocks Investments 1729.csv',
#  'Bank Account Travel 7281.csv',
#  'Bank Account UOB One Card Credit Card 4341.csv',
#  'Bank Account Whole Life Insurance Term Life Insurance Savings Insurance 4051.csv',
#  'Bear market Investments 1775.csv',
#  'Bear market Shorting Securities Investments 2078.csv',
#  'Blue Chips ETF Investments 2533.csv',
#  'Blue Chips ETF Investments 3049.csv',
#  'Blue Chips Equities Securities SeedlyTV EP01 Stocks Investments 1987.csv',
#  'Blue Chips Investments 2322.csv',
#  'Blue Chips Investments 556.csv',
#  'Blue Chips Stocks Discussion Stocks Investments 2110.csv',
#  'Blue Chips Stocks Investments 1626.csv',
#  'Blue Chips Stocks Investments 2827.csv',
#  'Bonds AMA The Fifth Person Investments 2669.csv',
#  'Bonds AMA The Fifth Person Investments 2670.csv',
#  'Bonds AMA The Fifth Person Investments 2726.csv',
#  'Bonds CPF SeedlyTV EP06 Investments 1049.csv',
#  'Bonds Dividends Investments 1962.csv',
#  'Bonds Equities Stocks Investments 2202.csv',
#  'Bonds Equities Stocks Technical Analysis Value Investing Valuation Investments 2085.csv',
#  'Bonds Investments 1761.csv',
#  'Bonds Investments 1823.csv',
#  'Bonds Investments 2000.csv',
#  'Bonds Investments 2072.csv',
#  'Bonds Investments 2098.csv',
#  'Bonds Investments 2151.csv',
#  'Bonds Investments 2318.csv',
#  'Bonds Investments 2649.csv',
#  'Bonds Investments Fundamentals 1652.csv',
#  'Bonds Investments Securities 1550.csv',
#  'Bonds PFF Panel 3 Stocks Investments Seedly PFF 2019 2547.csv',
#  'Bonds STI ETF Investments 730.csv',
#  'Bonds SeedlyTV EP01 Online Brokerages Investments 1766.csv',
#  'Bonds Singapore Saving Bonds (SSB) Investments 1894.csv',
#  'Bonds Singapore Saving Bonds (SSB) Robo-Advisors Blue Chips ETF AMA 1M65 Investments 3116.csv',
#  'Bonds Stocks Investments 1804.csv',
#  'Bonds Stocks Investments 1940.csv',
#  'Bonds Stocks Investments 1980.csv',
#  'Bonds Stocks Investments 1999.csv',
#  'Brokerages DBS Vickers Securities Stocks Investments DBS 1058.csv',
#  'Brokerages ETF Investments 3212.csv',
#  'Brokerages Investments 1954.csv',
#  'Brokerages Investments 483.csv',
#  'Bull Market Investments 2049.csv',
#  'Bull Market Stocks Investments 1768.csv',
#  'CIMB FastSaver CIMB Bank Account 7591.csv',
#  'CIMB FastSaver CIMB Bank Account 7609.csv',
#  'CIMB FastSaver CIMB Bank Account 7617.csv',
#  'CIMB FastSaver CIMB Insurance Investments 1821.csv',
#  'CIMB FastSaver DBS Comparison Savings Bank Account 7594.csv',
#  'CIMB Fresh Graduates Credit Card 4311.csv',
#  'CITI PremierMiles Visa Card Credit Card 4202.csv',
#  'CITI PremierMiles Visa Card Credit Card 4277.csv',
#  'CITI PremierMiles Visa Card Credit Card 4301.csv',
#  'CITI PremierMiles Visa Card Credit Card 4340.csv',
#  'CITI PremierMiles Visa Card Miles Credit Card 3925.csv',
#  'CITI PremierMiles Visa Card Travel Insurance Insurance 4086.csv',
#  'CITI PremierMiles Visa Card UOB One Card Credit Card 4101.csv',
#  'CITI Rewards Card UOB Preferred Platinum Visa Card Credit Card 4288.csv',
#  'CPF 6043.csv',
#  'CPF 6051.csv',
#  'CPF 6054.csv',
#  'CPF 6056.csv',
#  'CPF 6062.csv',
#  'CPF 6066.csv',
#  'CPF 6068.csv',
#  'CPF 6074.csv',
#  'CPF 6087.csv',
#  'CPF 6088.csv',
#  'CPF 6091.csv',
#  'CPF 6094.csv',
#  'CPF 6096.csv',
#  'CPF 6107.csv',
#  'CPF 6114.csv',
#  'CPF 6139.csv',
#  'CPF 6162.csv',
#  'CPF 6176.csv',
#  'CPF 6182.csv',
#  'CPF 6185.csv',
#  'CPF 6190.csv',
#  'CPF 6192.csv',
#  'CPF 6211.csv',
#  'CPF 6256.csv',
#  'CPF 6262.csv',
#  'CPF 6265.csv',
#  'CPF 6276.csv',
#  'CPF 6281.csv',
#  'CPF 6285.csv',
#  'CPF 6286.csv',
#  'CPF 6290.csv',
#  'CPF 6303.csv',
#  'CPF 6307.csv',
#  'CPF 6310.csv',
#  'CPF 6312.csv',
#  'CPF 6319.csv',
#  'CPF 6738.csv',
#  'CPF AMA 1M65 6136.csv',
#  'CPF AMA 1M65 6336.csv',
#  'CPF AMA 1M65 6340.csv',
#  'CPF AMA 1M65 6341.csv',
#  'CPF AMA 1M65 6346.csv',
#  'CPF AMA 1M65 Investments 3117.csv',
#  'CPF AMA 1M65 Retirement Savings Investments 2996.csv',
#  'CPF AMA Christopher Tan 6258.csv',
#  'CPF AMA Christopher Tan 6260.csv',
#  'CPF AMA Christopher Tan 6266.csv',
#  'CPF AMA Christopher Tan 6268.csv',
#  'CPF AMA Christopher Tan 6270.csv',
#  'CPF AMA Christopher Tan 6271.csv',
#  'CPF CPF IS Retirement 5496.csv',
#  'CPF CPF IS Retirement 6193.csv',
#  'CPF CPF IS Retirement 6880.csv',
#  'CPF Family Lifestyle Savings Insurance Retirement 3633.csv',
#  'CPF Family Lifestyle Savings Insurance Retirement 4393.csv',
#  'CPF Family Lifestyle Savings Insurance Retirement 6727.csv',
#  'CPF Family Loans HDB BTO Resale HDB 5185.csv',
#  'CPF Family Savings Loans Property 4405.csv',
#  'CPF Family Savings Retirement Bank Account General 5368.csv',
#  'CPF General 6108.csv',
#  'CPF General 6112.csv',
#  'CPF General 6143.csv',
#  'CPF General 6191.csv',
#  'CPF General 6830.csv',
#  'CPF HDB BTO 6049.csv',
#  'CPF HDB BTO 6736.csv',
#  'CPF HDB BTO Investments General Savings Loans Property 2867.csv',
#  'CPF HDB BTO Savings 6138.csv',
#  'CPF Insurance 3708.csv',
#  'CPF Insurance 3751.csv',
#  'CPF Insurance Investments General 2914.csv',
#  'CPF Insurance Investments General 6971.csv',
#  'CPF Insurance Investments Retirement 3766.csv',
#  'CPF Insurance Investments Retirement 932.csv',
#  'CPF Investments 1099.csv',
#  'CPF Investments 2238.csv',
#  'CPF Investments 2439.csv',
#  'CPF Investments AMA 1M65 3093.csv',
#  'CPF Investments AMA 1M65 3100.csv',
#  'CPF Investments AMA 1M65 6135.csv',
#  'CPF Investments AMA Christopher Tan 2862.csv',
#  'CPF Investments AMA Christopher Tan 6959.csv',
#  'CPF Investments Bank Account 531.csv',
#  'CPF Investments Bank Account 6060.csv',
#  'CPF Investments Insurance 3741.csv',
#  'CPF Investments Online Brokerages Brokerages 6093.csv',
#  'CPF Investments Resale HDB HDB BTO Property 3325.csv',
#  'CPF Investments Retirement 2106.csv',
#  'CPF Investments Retirement Supplementary Retirement Scheme (SRS) 371.csv',
#  'CPF Investments Savings Property 1583.csv',
#  'CPF Loans AMA 1M65 6301.csv',
#  'CPF Loans Education Lifestyle 4572.csv',
#  'CPF Loans Education Lifestyle 6708.csv',
#  'CPF Loans HDB BTO 6201.csv',
#  'CPF Loans Investments 2960.csv',
#  'CPF Loans Resale HDB Property 4400.csv',
#  'CPF Money FM 89.3 Show Savings 4414.csv',
#  'CPF Money FM 89.3 Show Savings 4456.csv',
#  'CPF Money FM 89.3 Show Savings 4466.csv',
#  'CPF Money FM 89.3 Show Savings 4468.csv',
#  'CPF Money FM 89.3 Show Savings 4469.csv',
#  'CPF Money FM 89.3 Show Savings 4472.csv',
#  'CPF Money FM 89.3 Show Savings Family 4471.csv',
#  'CPF Money FM 89.3 Show Savings Retirement 4467.csv',
#  'CPF Money FM 89.3 Show Savings Retirement 5441.csv',
#  'CPF Money FM 89.3 Show Savings Retirement Family 4470.csv',
#  'CPF Money FM 89.3 Show Savings Retirement Family 5193.csv',
#  'CPF PFF Panel 1 Insurance Seedly PFF 2019 3917.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6020.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6046.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6210.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6228.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6237.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6239.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6240.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6245.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6247.csv',
#  'CPF PFF Panel 1 Seedly PFF 2019 6707.csv',
#  'CPF PFF Panel 2 Seedly PFF 2019 6229.csv',
#  'CPF Property 4264.csv',
#  'CPF Property 4268.csv',
#  'CPF Property 4410.csv',
#  'CPF Property 4475.csv',
#  'CPF Property 99.co Event Investments 1113.csv',
#  'CPF Property Retirement Supplementary Retirement Scheme (SRS) 4205.csv',
#  'CPF Property SeedlyTV EP06 HDB BTO 4297.csv',
#  'CPF Retirement 5382.csv',
#  'CPF Retirement 5422.csv',
#  'CPF Retirement 5435.csv',
#  'CPF Retirement 5436.csv',
#  'CPF Retirement 5470.csv',
#  'CPF Retirement 5494.csv',
#  'CPF Retirement 6106.csv',
#  'CPF Retirement 6706.csv',
#  'CPF Retirement 6734.csv',
#  'CPF Retirement AMA 1M65 5571.csv',
#  'CPF Retirement Family 5192.csv',
#  'CPF Retirement Resale HDB 5475.csv',
#  'CPF Retirement Savings 4497.csv',
#  'CPF Retirement Supplementary Retirement Scheme (SRS) 5412.csv',
#  'CPF Savings 6322.csv',
#  'CPF Savings 6356.csv',
#  'CPF Savings AMA 1M65 6348.csv',
#  'CPF Savings Regular Shares Savings Plans (RSS) Investments 4452.csv',
#  'CPF Savings Regular Shares Savings Plans (RSS) Investments 538.csv',
#  'CPF Savings Retirement 4386.csv',
#  'CPF Savings Retirement 5415.csv',
#  'CPF Savings Retirement AMA 1M65 5576.csv',
#  'CPF Savings Retirement Healthcare Endowment Policies 4377.csv',
#  'CPF Savings Retirement Healthcare Endowment Policies 5400.csv',
#  'CPF Savings Retirement Healthcare Endowment Policies 6714.csv',
#  'CPF SeedlyTV EP06 6069.csv',
#  'CPF SeedlyTV EP06 6071.csv',
#  'CPF SeedlyTV EP06 6174.csv',
#  'CPF SeedlyTV EP06 Investments CPF IS 6146.csv',
#  'CPF SeedlyTV EP06 Retirement 5488.csv',
#  'CPF SeedlyTV EP06 Retirement Supplementary Retirement Scheme (SRS) 5406.csv',
#  'CPF Whole Life Insurance 6186.csv',
#  'Career 5612.csv',
#  'Career 5617.csv',
#  'Career 5627.csv',
#  'Career 5629.csv',
#  'Career 5632.csv',
#  'Career 5639.csv',
#  'Career 5641.csv',
#  'Career 5642.csv',
#  'Career 5644.csv',
#  'Career 5645.csv',
#  'Career 5649.csv',
#  'Career 5650.csv',
#  'Career 5652.csv',
#  'Career 5653.csv',
#  'Career 5655.csv',
#  'Career 5656.csv',
#  'Career 5657.csv',
#  'Career 5659.csv',
#  'Career 5662.csv',
#  'Career 5663.csv',
#  'Career 5667.csv',
#  'Career 5669.csv',
#  'Career 5674.csv',
#  'Career 5676.csv',
#  'Career 5685.csv',
#  'Career 5687.csv',
#  'Career 5688.csv',
#  'Career 5690.csv',
#  'Career 5691.csv',
#  'Career 5697.csv',
#  'Career 5700.csv',
#  'Career 5703.csv',
#  'Career 5711.csv',
#  'Career 5712.csv',
#  'Career 5720.csv',
#  'Career 5724.csv',
#  'Career 5726.csv',
#  'Career 5729.csv',
#  'Career 5731.csv',
#  'Career 5738.csv',
#  'Career 5741.csv',
#  'Career 5742.csv',
#  'Career 5745.csv',
#  'Career 5749.csv',
#  'Career 5750.csv',
#  'Career 5751.csv',
#  'Career 5757.csv',
#  'Career 5758.csv',
#  'Career 5765.csv',
#  'Career 5769.csv',
#  'Career 5771.csv',
#  'Career 5773.csv',
#  'Career 5774.csv',
#  'Career 5777.csv',
#  'Career 5778.csv',
#  'Career 5779.csv',
#  'Career 5781.csv',
#  'Career 5783.csv',
#  'Career 5788.csv',
#  'Career 5789.csv',
#  'Career 5790.csv',
#  'Career 5791.csv',
#  'Career 5793.csv',
#  'Career 5799.csv',
#  'Career 5801.csv',
#  'Career 5804.csv',
#  'Career 5810.csv',
#  'Career 5811.csv',
#  'Career 5813.csv',
#  'Career 5817.csv',
#  'Career 5819.csv',
#  'Career 5822.csv',
#  'Career 5825.csv',
#  'Career 5826.csv',
#  'Career 5829.csv',
#  'Career 5831.csv',
#  'Career 5834.csv',
#  'Career 5837.csv',
#  'Career 5839.csv',
#  'Career 5842.csv',
#  'Career 5843.csv',
#  'Career 5844.csv',
#  'Career 5848.csv',
#  'Career 5849.csv',
#  'Career 5850.csv',
#  'Career 5851.csv',
#  'Career 5852.csv',
#  'Career 5853.csv',
#  'Career 5858.csv',
#  'Career 5859.csv',
#  'Career 5861.csv',
#  'Career 5863.csv',
#  'Career 5866.csv',
#  'Career 5872.csv',
#  'Career 5874.csv',
#  'Career 5877.csv',
#  'Career 5883.csv',
#  'Career 5884.csv',
#  'Career 5885.csv',
#  'Career 5886.csv',
#  'Career 5887.csv',
#  'Career 5889.csv',
#  'Career 5890.csv',
#  'Career 5892.csv',
#  'Career 5893.csv',
#  'Career 5894.csv',
#  'Career 5899.csv',
#  'Career 5900.csv',
#  'Career 5901.csv',
#  'Career 5902.csv',
#  'Career 5903.csv',
#  'Career 5904.csv',
#  'Career 5905.csv',
#  'Career 5906.csv',
#  'Career 5909.csv',
#  'Career 5911.csv',
#  'Career 5913.csv',
#  'Career 5914.csv',
#  'Career 5915.csv',
#  'Career 5916.csv',
#  'Career 5918.csv',
#  'Career 5919.csv',
#  'Career 5921.csv',
#  'Career 5922.csv',
#  'Career 5923.csv',
#  'Career 5927.csv',
#  'Career 5934.csv',
#  'Career 5935.csv',
#  'Career 5937.csv',
#  'Career 5938.csv',
#  'Career 5939.csv',
#  'Career 5941.csv',
#  'Career 5942.csv',
#  'Career 5945.csv',
#  'Career 5946.csv',
#  'Career 5952.csv',
#  'Career 5953.csv',
#  'Career 5954.csv',
#  'Career 5955.csv',
#  'Career 5956.csv',
#  'Career 5958.csv',
#  'Career 5960.csv',
#  'Career 5961.csv',
#  'Career 5972.csv',
#  'Career 5975.csv',
#  'Career 5976.csv',
#  'Career 5977.csv',
#  'Career 5985.csv',
#  'Career 5994.csv',
#  'Career 5999.csv',
#  'Career 6001.csv',
#  'Career 6007.csv',
#  'Career 6010.csv',
#  'Career 6011.csv',
#  'Career 6012.csv',
#  'Career 6014.csv',
#  'Career 6018.csv',
#  'Career 6531.csv',
#  'Career Credit Card 4200.csv',
#  'Career Credit Card Lifestyle 4237.csv',
#  'Career Education 5626.csv',
#  'Career Education 5633.csv',
#  'Career Education 5684.csv',
#  'Career Education 5719.csv',
#  'Career Education 5740.csv',
#  'Career Education 5833.csv',
#  'Career Education 5845.csv',
#  'Career Education 5878.csv',
#  'Career Education 6532.csv',
#  'Career Endowment Policies Insurance Savings 4044.csv',
#  'Career Family 5275.csv',
#  'Career Family Lifestyle 4750.csv',
#  'Career Family Lifestyle 4778.csv',
#  'Career Family Lifestyle 5714.csv',
#  'Career Financial Planners CFP 5736.csv',
#  'Career Financial Planners Property 4466.csv',
#  'Career Fresh Graduates 5675.csv',
#  'Career Fresh Graduates 5707.csv',
#  'Career Fresh Graduates 5971.csv',
#  'Career General 5668.csv',
#  'Career General 5689.csv',
#  'Career General 5695.csv',
#  'Career General 5696.csv',
#  'Career General 5698.csv',
#  'Career General 5702.csv',
#  'Career General 5732.csv',
#  'Career General 5734.csv',
#  'Career General 5739.csv',
#  'Career General 5743.csv',
#  'Career General 5747.csv',
#  'Career General 5752.csv',
#  'Career General 5767.csv',
#  'Career General 5775.csv',
#  'Career General 5821.csv',
#  'Career General 5846.csv',
#  'Career General 5891.csv',
#  'Career General 5943.csv',
#  'Career General 5947.csv',
#  'Career General 5962.csv',
#  'Career General 5963.csv',
#  'Career General 5965.csv',
#  'Career General 5966.csv',
#  'Career General 5967.csv',
#  'Career General 5969.csv',
#  'Career General 5974.csv',
#  'Career General 5981.csv',
#  'Career General 5982.csv',
#  'Career General 5983.csv',
#  'Career General 5984.csv',
#  'Career General 5991.csv',
#  'Career General 5993.csv',
#  'Career General 6002.csv',
#  'Career General 6008.csv',
#  'Career General 6009.csv',
#  'Career General 6013.csv',
#  'Career General 6508.csv',
#  'Career General Credit Card Loans 4295.csv',
#  'Career General Fresh Graduates 5717.csv',
#  'Career General Lifestyle Loans Bank Account Retirement 4727.csv',
#  'Career General Property 4491.csv',
#  'Career General SeedlyTV EP01 5785.csv',
#  'Career HDB BTO Savings Retirement CPF AMA 1M65 5578.csv',
#  'Career HDB BTO Savings Retirement CPF AMA 1M65 5925.csv',
#  'Career Insurance 3926.csv',
#  'Career Insurance Investments Savings Family General 3373.csv',
#  'Career Insurance Lifestyle 3731.csv',
#  'Career Insurance Property 3644.csv',
#  'Career Insurance Property Credit Card 3978.csv',
#  'Career Insurance Savings HDB BTO 3676.csv',
#  'Career Investments 1927.csv',
#  'Career Investments 3336.csv',
#  'Career Investments 409.csv',
#  'Career Investments General 3359.csv',
#  'Career Investments General 3366.csv',
#  'Career Investments Lifestyle 4722.csv',
#  'Career Investments Savings Insurance 3643.csv',
#  'Career Investments Savings Insurance 460.csv',
#  'Career Lifestyle 4686.csv',
#  'Career Lifestyle 4744.csv',
#  'Career Lifestyle 4752.csv',
#  'Career Lifestyle 4792.csv',
#  'Career Lifestyle 4818.csv',
#  'Career Lifestyle 4896.csv',
#  'Career Lifestyle 4931.csv',
#  'Career Lifestyle 5014.csv',
#  'Career Lifestyle 5026.csv',
#  'Career Lifestyle 5068.csv',
#  'Career Lifestyle 5080.csv',
#  'Career Lifestyle Education 5135.csv',
#  'Career Lifestyle Investments 2632.csv',
#  'Career Lifestyle Savings 4813.csv',
#  'Career Loans Education 5611.csv',
#  'Career Loans Education 7059.csv',
#  'Career PFF Panel 3 Seedly PFF 2019 5815.csv',
#  'Career Policies Lifestyle 4745.csv',
#  'Career Retirement Insurance Investments 324.csv',
#  'Career Retirement Insurance Investments 5390.csv',
#  'Career Salary 5619.csv',
#  'Career Salary 5646.csv',
#  'Career Salary 5679.csv',
#  'Career Salary 5713.csv',
#  'Career Salary 5762.csv',
#  'Career Salary Education 5814.csv',
#  'Career Salary Savings 5936.csv',
#  'Career Savings 5944.csv',
#  'Career Savings Bank Account 5665.csv',
#  'Career Savings Investments 2313.csv',
#  'Career Savings Investments 2535.csv',
#  'Career Savings Investments Credit Card Lifestyle 2887.csv',
#  'Career Savings Investments Lifestyle 4713.csv',
#  'Career Savings Lifestyle 5025.csv',
#  'Career Savings Stocks Investments 2220.csv',
#  'Career Stocks Investments 2217.csv',
#  'Career Stocks Investments PFF Panel 3 Seedly PFF 2019 2491.csv',
#  'Citi Cash Back Insurance Lifestyle Credit Card 3636.csv',
#  'Coffee Meets Investing Investments 3016.csv',
#  'Coffee Meets Investing Investments 3343.csv',
#  'Coffee Meets Investing Investments 812.csv',
#  'Comparison Career 5959.csv',
#  'Comparison Career 5973.csv',
#  'Comparison Early Critical Illness (ECI) Insurance 3956.csv',
#  'Comparison Education Lifestyle 4638.csv',
#  'Comparison In the News Lifestyle 5118.csv',
#  'Comparison Insurance 4099.csv',
#  'Comparison Insurance 4129.csv',
#  'Comparison Investments 2855.csv',
#  'Comparison Investments 3185.csv',
#  'Comparison Investments 3192.csv',
#  'Comparison Investments 3259.csv',
#  'Comparison Investments 3265.csv',
#  'Comparison Investments 3377.csv',
#  'Comparison Investments 3386.csv',
#  'Comparison Investments 771.csv',
#  'Comparison Investments Insurance 3194.csv',
#  'Comparison Lifestyle Travel 5123.csv',
#  'Comparison Savings Investments 3150.csv',
#  'Comparison Stocks Investments 2447.csv',
#  'Condominium Career Property 4490.csv',
#  'Condominium EC Condominium Investments Property 3172.csv',
#  'Condominium Investments Property 3226.csv',
#  'Condominium Investments Property 3229.csv',
#  'Condominium Investments Property 4247.csv',
#  'Condominium Property 4364.csv',
#  'Condominium Property 4467.csv',
#  'Condominium Property HDB BTO 4253.csv',
#  'Condominium Resale HDB HDB BTO Property 4257.csv',
#  'Condominium Salary Resale HDB Property 4487.csv',
#  'Credit Card 3920.csv',
#  'Credit Card 3951.csv',
#  'Credit Card 3959.csv',
#  'Credit Card 3961.csv',
#  'Credit Card 3970.csv',
#  'Credit Card 3977.csv',
#  'Credit Card 3981.csv',
#  'Credit Card 3988.csv',
#  'Credit Card 3990.csv',
#  'Credit Card 3994.csv',
#  'Credit Card 3998.csv',
#  'Credit Card 3999.csv',
#  'Credit Card 4002.csv',
#  'Credit Card 4003.csv',
#  'Credit Card 4008.csv',
#  'Credit Card 4013.csv',
#  'Credit Card 4014.csv',
#  'Credit Card 4024.csv',
#  'Credit Card 4026.csv',
#  'Credit Card 4032.csv',
#  'Credit Card 4037.csv',
#  'Credit Card 4053.csv',
#  'Credit Card 4060.csv',
#  'Credit Card 4062.csv',
#  'Credit Card 4065.csv',
#  'Credit Card 4067.csv',
#  'Credit Card 4073.csv',
#  'Credit Card 4074.csv',
#  'Credit Card 4075.csv',
#  'Credit Card 4076.csv',
#  'Credit Card 4077.csv',
#  'Credit Card 4088.csv',
#  'Credit Card 4093.csv',
#  'Credit Card 4094.csv',
#  'Credit Card 4104.csv',
#  'Credit Card 4112.csv',
#  'Credit Card 4113.csv',
#  'Credit Card 4114.csv',
#  'Credit Card 4117.csv',
#  'Credit Card 4118.csv',
#  'Credit Card 4119.csv',
#  'Credit Card 4126.csv',
#  'Credit Card 4132.csv',
#  'Credit Card 4134.csv',
#  'Credit Card 4137.csv',
#  'Credit Card 4143.csv',
#  'Credit Card 4144.csv',
#  'Credit Card 4145.csv',
#  'Credit Card 4148.csv',
#  'Credit Card 4152.csv',
#  'Credit Card 4153.csv',
#  'Credit Card 4154.csv',
#  'Credit Card 4163.csv',
#  'Credit Card 4164.csv',
#  'Credit Card 4166.csv',
#  'Credit Card 4167.csv',
#  'Credit Card 4173.csv',
#  'Credit Card 4184.csv',
#  'Credit Card 4186.csv',
#  'Credit Card 4189.csv',
#  'Credit Card 4193.csv',
#  'Credit Card 4199.csv',
#  'Credit Card 4206.csv',
#  'Credit Card 4207.csv',
#  'Credit Card 4208.csv',
#  'Credit Card 4209.csv',
#  'Credit Card 4211.csv',
#  'Credit Card 4212.csv',
#  'Credit Card 4213.csv',
#  'Credit Card 4214.csv',
#  'Credit Card 4217.csv',
#  'Credit Card 4221.csv',
#  'Credit Card 4224.csv',
#  'Credit Card 4225.csv',
#  'Credit Card 4227.csv',
#  'Credit Card 4230.csv',
#  'Credit Card 4231.csv',
#  'Credit Card 4233.csv',
#  'Credit Card 4236.csv',
#  'Credit Card 4239.csv',
#  'Credit Card 4242.csv',
#  'Credit Card 4243.csv',
#  'Credit Card 4245.csv',
#  'Credit Card 4246.csv',
#  'Credit Card 4252.csv',
#  'Credit Card 4253.csv',
#  'Credit Card 4255.csv',
#  'Credit Card 4256.csv',
#  'Credit Card 4257.csv',
#  'Credit Card 4258.csv',
#  'Credit Card 4265.csv',
#  'Credit Card 4266.csv',
#  'Credit Card 4268.csv',
#  'Credit Card 4269.csv',
#  'Credit Card 4270.csv',
#  ...]

# %% [markdown]
# # Prepare corpus

# %% [markdown]
# For each file, extract the relevant fields: question, responses. Filter and remove authors, dates and words that are not provided by the users.

# %%
def findnth(haystack, needle, n):
    parts= haystack.split(needle, n+1)
    if len(parts)<=n+1:
        return -1
    return len(haystack)-len(parts[-1])-len(needle)


def process_response(line):
    # Extract date
    temp = line[line.find('Answered on '):]
    x = findnth(temp, ' ', 3)
    answer_date = temp[:x + 5]

    # Extract answer
    answer = line[line.find(answer_date) + len(answer_date):]
    
    return answer_date, answer


corpus = []

for fid in fids[:20]:
    thread = []
    
    with open('../WebScraper/seedly-forum/' + fid, encoding="utf8") as file:
        # Process each line and extract title, date and content of article
        for i, line in enumerate(file):
            if i == 2:
                # Handle question
                first_comma = line.find(',')
                line = line[first_comma + 1:]
                if line[0] == '"':
                    line = line[1:]
                last_qnmark = line.rfind('?')
                line = line[:last_qnmark + 1]
                
                # Extract author
                author = line[line.find('Asked by '):line.find('Asked on')]
                print(author)
                
                # Extract post date
                temp = line[line.find('Asked on '):]
                x = findnth(temp, ' ', 3)
                ask_date = temp[:x + 5]
                print(ask_date)
                
                # Extract title
                title = line[:line.find(author)]
                print(title)
                
                # Extract question
                question = line.replace(author, '').replace(ask_date, '').replace(title, '')
                print(question)
                thread.append(question)
                    
            elif i >= 6:
                # Handle responses
                # Extract response number. If no number, means current line is part of previous response
                temp = line.find(',')
                num = line[:temp]
                is_num = False
                
                try:
                    int(num)
                    is_num = True
                except ValueError:
                    is_num = False
                    
                # If part of previous response, append entire line. If new response, filter the answerer and date
                if not is_num:
#                     end_index = line.rfind('comments')
#                     line = line[:end_index - 2]
                    thread.append(line)
                else:
                    answer_date, answer = process_response(line)
#                     end_index = answer.rfind('comments')
#                     answer = answer[:end_index - 2]
                    thread.append(answer)
    
    corpus.append(thread)
    
# corpus
# Out:
# Asked by Anonymous
# Asked on 24 May 2019
# 99.co Event CPF Property Investments
# Is there any way to increase my CPF amount so that I can buy more than one property?I want to use more of my CPF amount to buy property rather than taking a large loan, is there any way to do so?
# Asked by Kuriakin J. Zeng
# Asked on 21 May 2019
# 99.co Event Condominium Property
# How to pick a property with enbloc potential?
# Asked by Anonymous
# Asked on 24 May 2019
# 99.co Event Condominium Property Investments
# I was at a Condo launch recently and my property agent recommended me a banker. Should I trust him to settle my mortgage or should I look on my own?Don't know whether I'm overthinking but why did this property agent recommend me to go to this banker. Is there something in it for them?
# Asked by Anonymous
# Asked on 24 May 2019
# 99.co Event EC Condominium Condominium Property
# For a first time buyer as a couple, should we wait for ECs or jump straight into Condominiums for our first home?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event General Investments Property
# The second speaker mentioned about “leverage”. What is that, could you elaborate?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event HDB BTO Investments Property
# Should I choose a good BTO and sell it upon MOP to use it for my first investment property? Do you think this is a wise choice?
# Asked by Anonymous
# Asked on 24 May 2019
# 99.co Event HDB BTO Investments Property
# If I don't even have enough money to buy my first BTO to live in, how do I invest in another property?Looking to invest in property but dont even have money to buy my first bto, is there a way around this?
# Asked by Anonymous
# Asked on 24 May 2019
# 99.co Event Investments HDB BTO Property
# I am in the phase of getting married soon. Should I be prioritising getting a BTO or investing in a property? Limited money so can only choose one. Which one should I prioritise?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Loans
# I already own one HDB, can I still owe a private property and get a loan for my second property?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# Should I invest in a property to rent it out or to sell it eventually? If to sell, when is the best time frame to sell for new launched property?
# Asked by Michelle Chua
# Asked on 25 May 2019
# 99.co Event Investments Property
# What are the various strategies to own multiple properties without paying ABSD?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# There has been alot of talk on how affordable private property is.  How good it is actually to get a one bedroom for rental / investment?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# Why are there so many gurus out there boasting owning multiple properties with no money down using their investment strategies? What do we need to watch out for in such property investment seminars?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# Should I buy a resale or new launch?I'm looking to get my first investment property, however, will it be a better choice to get a resale or a new launch. When is it that I should consider one or the other?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# Would you recommend renting or buying a property in Singapore?The prices of property in Singapore is so high. As such, renting seems like a better option. What are your thoughts?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property
# Based on a personal experience, it seems like the moment when we buy a property, the breakeven point is another 10-20%. Is it true? What are your thoughts?
# Asked by Ivy Chin
# Asked on 25 May 2019
# 99.co Event Investments Property
# How do I buy/plan for second condo as investment, given the down payment so heavy in Singapore?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property General
# What would you consider a diversified investment portfolio?What would you consider a diversified investment portfolio with regards to property?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property General
#  What are the more important factors when selecting my first house?Which is more important: location vs view?
# Asked by Anonymous
# Asked on 25 May 2019
# 99.co Event Investments Property HDB BTO
# How to decide between BTO or Private?

# %% [markdown]
# # Preprocess corpus

# %% [markdown]
# For each post, perform Tokenization, Stop words removal, and lowercase all words.

# %%
stop_list = nltk.corpus.stopwords.words('english')
my_stopwords = ['comments', 'answerAnswerBump']

tokenized = []

# Tokenization
for thread in corpus:
    tokens = [nltk.word_tokenize(post) for post in thread]
    tokenized.append(tokens)
    
    
# Pre-processing
cleaned_corpus = []
    
for thread in tokenized:
    cleaned_thread = [[w.lower() for w in post] for post in thread]
    cleaned_thread = [[w for w in post if re.search('^[a-z]+$', w)] for post in cleaned_thread]
    cleaned_thread = [[w for w in post if w not in stop_list and w not in my_stopwords] for post in cleaned_thread]
    cleaned_corpus.append(cleaned_thread)
    
cleaned_corpus
# Out:
# [[['way',
#    'increase',
#    'cpf',
#    'amount',
#    'buy',
#    'one',
#    'property',
#    'want',
#    'use',
#    'cpf',
#    'amount',
#    'buy',
#    'property',
#    'rather',
#    'taking',
#    'large',
#    'loan',
#    'way'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'afraid',
#    'pump',
#    'higher',
#    'paying',
#    'job',
#    'assuming',
#    'hit',
#    'ceiling',
#    'cap',
#    'cpf'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['pick', 'property', 'enbloc', 'potential'],
#   ['condos',
#    'potential',
#    'enough',
#    'holding',
#    'question',
#    'long',
#    'much',
#    'earn',
#    'longthe',
#    'timing',
#    'depends',
#    'two',
#    'factors',
#    'resident',
#    'demographic',
#    'market',
#    'residents',
#    'condo',
#    'ultimately',
#    'determines',
#    'property',
#    'goes',
#    'see',
#    'residents',
#    'like',
#    'know',
#    'good',
#    'property',
#    'developers',
#    'desperately',
#    'waiting',
#    'good',
#    'location',
#    'also',
#    'reason',
#    'residents',
#    'refuse',
#    'plus',
#    'residents',
#    'enough',
#    'holding',
#    'power',
#    'want',
#    'know',
#    'many',
#    'people',
#    'lost',
#    'much',
#    'money',
#    'buying',
#    'kind',
#    'property',
#    'stuck',
#    'years',
#    'trend',
#    'factor',
#    'long',
#    'similar',
#    'previous',
#    'point',
#    'location',
#    'double',
#    'edged',
#    'sword',
#    'developments',
#    'around',
#    'condo',
#    'might',
#    'increase',
#    'chances',
#    'also',
#    'lead',
#    'residents',
#    'resisting',
#    'made',
#    'even',
#    'worse',
#    'whenever',
#    'government',
#    'announce',
#    'certain',
#    'plans',
#    'area',
#    'makes',
#    'residents',
#    'demand',
#    'higher',
#    'prices',
#    'developers',
#    'refuse',
#    'muchthis',
#    'key',
#    'question',
#    'need',
#    'ask',
#    'property',
#    'high',
#    'return',
#    'potential',
#    'worth',
#    'waiting',
#    'return',
#    'comes',
#    'freehold',
#    'vs',
#    'leaseholdcondo',
#    'footprint',
#    'vs',
#    'land',
#    'areanumber',
#    'residents',
#    'per',
#    'land',
#    'areaif',
#    'original',
#    'plot',
#    'ratio'],
#   [],
#   ['low',
#    'flats',
#    'unitswhen',
#    'developers',
#    'redevelop',
#    'properties',
#    'acquire',
#    'rebuild',
#    'great',
#    'opportunity',
#    'increase',
#    'number',
#    'units',
#    'build',
#    'higher',
#    'blocks',
#    'therefore',
#    'plab',
#    'shifting',
#    'height',
#    'restrictions',
#    'lifted',
#    'east',
#    'area',
#    'foresee',
#    'enblocks',
#    'happening',
#    'reasoning',
#    'coupled',
#    'good',
#    'location',
#    'near',
#    'upcoming',
#    'malls',
#    'mrt',
#    'stations',
#    'motivation',
#    'factor',
#    'transactions',
#    'happenpast',
#    'enblocsmandarin',
#    'garden',
#    'developer',
#    'twiced',
#    'tried',
#    'enbloc',
#    'condo',
#    'unfortunately',
#    'tenants',
#    'agree',
#    'https',
#    'reasons',
#    'cited',
#    'article',
#    'might',
#    'want',
#    'check',
#    'article'],
#   []],
#  [['condo',
#    'launch',
#    'recently',
#    'property',
#    'agent',
#    'recommended',
#    'banker',
#    'trust',
#    'settle',
#    'mortgage',
#    'look',
#    'know',
#    'whether',
#    'overthinking',
#    'property',
#    'agent',
#    'recommend',
#    'go',
#    'banker',
#    'something'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'pretty',
#    'ok',
#    'rely',
#    'mortgage',
#    'banker',
#    'recommended',
#    'though',
#    'choice',
#    'entirely',
#    'source',
#    'clients',
#    'rely',
#    'mortgage',
#    'bankers',
#    'others',
#    'rely',
#    'long',
#    'time',
#    'mortgage',
#    'bankers',
#    'esp',
#    'high',
#    'net',
#    'worth',
#    'clients',
#    'already',
#    'private'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['first',
#    'time',
#    'buyer',
#    'couple',
#    'wait',
#    'ecs',
#    'jump',
#    'straight',
#    'condominiums',
#    'first',
#    'home'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'ec',
#    'qualify',
#    'since',
#    'usually',
#    'priced',
#    'cheaper',
#    'comparable',
#    'new',
#    'launched',
#    'mass',
#    'market'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['second', 'speaker', 'mentioned', 'leverage', 'could', 'elaborate'],
#   ['financial',
#    'leverage',
#    'money',
#    'borrowed',
#    'ie',
#    'debt',
#    'buy',
#    'assets',
#    'corporate',
#    'terms',
#    'leverage',
#    'used',
#    'avoid',
#    'using',
#    'much',
#    'equity',
#    'fund',
#    'operations',
#    'excessive',
#    'amount',
#    'financial',
#    'leverage',
#    'increases',
#    'risk',
#    'failure',
#    'since',
#    'becomes',
#    'difficult',
#    'repay',
#    'stock',
#    'investing',
#    'terms',
#    'investors',
#    'use',
#    'leverage',
#    'increase',
#    'exposure',
#    'market',
#    'allowing',
#    'pay',
#    'less',
#    'full',
#    'amount',
#    'investment',
#    'downside',
#    'stock',
#    'tanks',
#    'investor',
#    'loses',
#    'principal',
#    'also',
#    'pay',
#    'back',
#    'debt',
#    'took',
#    'buying',
#    'stocks',
#    'margin',
#    'would',
#    'constitute',
#    'example'],
#   [],
#   ['leverage',
#    'put',
#    'simpliy',
#    'borrowing',
#    'buy',
#    'something',
#    'expect',
#    'earn',
#    'cost',
#    'borrowing',
#    'interest',
#    'ideal',
#    'scenario',
#    'also',
#    'chance',
#    'investment',
#    'losses',
#    'money',
#    'leverage',
#    'double',
#    'edged',
#    'sword',
#    'used',
#    'wisely',
#    'help',
#    'profit',
#    'used',
#    'rashly',
#    'end',
#    'whether',
#    'housing',
#    'investment'],
#   []],
#  [['choose',
#    'good',
#    'bto',
#    'sell',
#    'upon',
#    'mop',
#    'use',
#    'first',
#    'investment',
#    'property',
#    'think',
#    'wise',
#    'choice'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'sell',
#    'fund',
#    'next',
#    'property',
#    'assume',
#    'going',
#    'stay',
#    'next',
#    'property',
#    'yeah',
#    'many',
#    'singaporeans',
#    'since',
#    'selling',
#    'bto',
#    'mop',
#    'years',
#    'gtes',
#    'profit',
#    'use',
#    'upgrade',
#    'private',
#    'said',
#    'life',
#    'plans',
#    'may',
#    'change',
#    'circumstances',
#    'change',
#    'might',
#    'acutally',
#    'prefer',
#    'stay',
#    'bto',
#    'even',
#    'years',
#    'example',
#    'close',
#    'ageing',
#    'parents',
#    'within',
#    'km',
#    'child',
#    'future',
#    'pri',
#    'school'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['even',
#    'enough',
#    'money',
#    'buy',
#    'first',
#    'bto',
#    'live',
#    'invest',
#    'another',
#    'property',
#    'looking',
#    'invest',
#    'property',
#    'dont',
#    'even',
#    'money',
#    'buy',
#    'first',
#    'bto',
#    'way',
#    'around'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'cheapest',
#    'property',
#    'u',
#    'buy',
#    'singapore',
#    'u',
#    'ca',
#    'afford',
#    'yet',
#    'save',
#    'u',
#    'might',
#    'want',
#    'invest',
#    'overseas',
#    'properties',
#    'risks',
#    'involved',
#    'would',
#    'recommend'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['phase',
#    'getting',
#    'married',
#    'soon',
#    'prioritising',
#    'getting',
#    'bto',
#    'investing',
#    'property',
#    'limited',
#    'money',
#    'choose',
#    'one',
#    'one',
#    'prioritise'],
#   ['really',
#    'depends',
#    'situation',
#    'want',
#    'stay',
#    'yes',
#    'place',
#    'stay',
#    'staying',
#    'parent',
#    'house',
#    'comfortable',
#    'sharing',
#    'house',
#    'parents',
#    'answered',
#    'questions',
#    'would',
#    'strongly',
#    'suggest',
#    'getting',
#    'bto',
#    'point',
#    'sacrificing',
#    'comfort',
#    'home',
#    'material'],
#   []],
#  [['already',
#    'one',
#    'hdb',
#    'still',
#    'owe',
#    'private',
#    'property',
#    'get',
#    'loan',
#    'second',
#    'property'],
#   ['yes',
#    'requirements',
#    'take',
#    'note',
#    'fufill',
#    'minimum',
#    'occupancy',
#    'periodbe',
#    'singaporean',
#    'else',
#    'sell',
#    'hdbtake',
#    'note',
#    'lower',
#    'loan',
#    'value',
#    'ratio',
#    'additional',
#    'stamp',
#    'dutytotal',
#    'debt',
#    'servicing',
#    'ratio',
#    'fully',
#    'repaid',
#    'loan',
#    'credit',
#    'bills',
#    'etc'],
#   []],
#  [['invest',
#    'property',
#    'rent',
#    'sell',
#    'eventually',
#    'sell',
#    'best',
#    'time',
#    'frame',
#    'sell',
#    'new',
#    'launched',
#    'property'],
#   ['hola',
#    'douglas',
#    'keynote',
#    'speaker',
#    'qn',
#    'kinda',
#    'open',
#    'ended',
#    'give',
#    'concise',
#    'advisory',
#    'assuming',
#    'property',
#    'market',
#    'continues',
#    'steady',
#    'growth',
#    'government',
#    'prefers',
#    'price',
#    'purchased',
#    'new',
#    'launch',
#    'appreciate',
#    'top',
#    'folks',
#    'choose',
#    'sell',
#    'rightaway',
#    'top',
#    'profit',
#    'passed',
#    'window',
#    'pay',
#    'seller',
#    'stamp',
#    'duty',
#    'want',
#    'hold',
#    'long',
#    'term',
#    'asset',
#    'rental',
#    'income',
#    'anticipating',
#    'future',
#    'price',
#    'choice',
#    'pretty',
#    'subjective',
#    'depending',
#    'choice',
#    'investment',
#    'strategy',
#    'nimble',
#    'understand',
#    'personal',
#    'circumstances'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['various',
#    'strategies',
#    'multiple',
#    'properties',
#    'without',
#    'paying',
#    'absd'],
#   ['way',
#    'buying',
#    'industrial',
#    'commercial',
#    'properties',
#    'classes',
#    'properties',
#    'attract',
#    'absd',
#    'u',
#    'need',
#    'fire',
#    'power',
#    'aka',
#    'ammo',
#    'since',
#    'ca',
#    'use',
#    'cpf',
#    'total',
#    'debt',
#    'servicing',
#    'ratio',
#    'tdsr',
#    'still',
#    'apply',
#    'buying',
#    'individual',
#    'u',
#    'buy',
#    'company',
#    'financials',
#    'company',
#    'must',
#    'strong',
#    'enough',
#    'secure',
#    'bank'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['alot',
#    'talk',
#    'affordable',
#    'private',
#    'property',
#    'good',
#    'actually',
#    'get',
#    'one',
#    'bedroom',
#    'rental',
#    'investment'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'budget',
#    'like',
#    'always',
#    'advise',
#    'clients',
#    'go',
#    'bedder',
#    'gives',
#    'wider',
#    'pool',
#    'buyers',
#    'budget',
#    'bedder',
#    'still',
#    'workable',
#    'make',
#    'sure',
#    'location',
#    'accessibility',
#    'amenities',
#    'around',
#    'makes'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['many',
#    'gurus',
#    'boasting',
#    'owning',
#    'multiple',
#    'properties',
#    'money',
#    'using',
#    'investment',
#    'strategies',
#    'need',
#    'watch',
#    'property',
#    'investment',
#    'seminars'],
#   ['yes',
#    'blood',
#    'boil',
#    'misleading',
#    'ads',
#    'money',
#    'means',
#    'taking',
#    'enquity',
#    'loan',
#    'based',
#    'current',
#    'fully',
#    'paid',
#    'partially',
#    'paid',
#    'property',
#    'sometimes',
#    'means',
#    'using',
#    'illegal',
#    'means',
#    'get',
#    'full',
#    'loans',
#    'case',
#    'project',
#    'valuation',
#    'artificially',
#    'inflated',
#    'get',
#    'larger',
#    'loan',
#    'based',
#    'inflated',
#    'valuation',
#    'rather',
#    'actual',
#    'lower',
#    'cost',
#    'thing',
#    'money',
#    'bait',
#    'hook',
#    'u',
#    'attend',
#    'pay',
#    'gotten',
#    'big',
#    'trouble',
#    'investing',
#    'dubious',
#    'property',
#    'seminars',
#    'google',
#    'eco',
#    'house',
#    'singapore',
#    'scam',
#    'many',
#    'examples',
#    'rah',
#    'rah',
#    'come',
#    'go',
#    'keep',
#    'resurfacing',
#    'mas',
#    'clamp',
#    'rah',
#    'rah',
#    'seminars',
#    'mainly',
#    'conduit',
#    'rah',
#    'rah',
#    'workshop',
#    'organisers',
#    'offload',
#    'properties',
#    'participants',
#    'earn',
#    'ridiculously',
#    'priced',
#    'workshop',
#    'bait',
#    'linked',
#    'fellow',
#    'investors',
#    'qualified',
#    'professionals',
#    'market',
#    'know',
#    'done',
#    'done'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regardsdouglas'],
#   [],
#   ['say',
#    'money',
#    'mean',
#    'debt',
#    'funded',
#    'rather',
#    'cough',
#    'cash',
#    'say',
#    'multiple',
#    'properties',
#    'mean',
#    'group',
#    'investors',
#    'pool',
#    'money',
#    'together',
#    'multiple',
#    'method',
#    'teach',
#    'illegal',
#    'complicated',
#    'manage',
#    'success',
#    'investment',
#    'opinion',
#    'highly',
#    'dependent'],
#   [],
#   ['pay'],
#   []],
#  [['buy',
#    'resale',
#    'new',
#    'launch',
#    'looking',
#    'get',
#    'first',
#    'investment',
#    'property',
#    'however',
#    'better',
#    'choice',
#    'get',
#    'resale',
#    'new',
#    'launch',
#    'consider',
#    'one'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'fine',
#    'homework',
#    'make',
#    'sure',
#    'upside',
#    'potential',
#    'studying',
#    'future',
#    'developments',
#    'nearby',
#    'accessibiloity'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['would',
#    'recommend',
#    'renting',
#    'buying',
#    'property',
#    'singapore',
#    'prices',
#    'property',
#    'singapore',
#    'high',
#    'renting',
#    'seems',
#    'like',
#    'better',
#    'option',
#    'thoughts'],
#   ['really',
#    'depends',
#    'expat',
#    'looking',
#    'stay',
#    'place',
#    'country',
#    'long',
#    'haul',
#    'renting',
#    'would',
#    'give',
#    'lot',
#    'looking',
#    'place',
#    'stay',
#    'plan',
#    'singapore',
#    'long',
#    'haul',
#    'may',
#    'find',
#    'buying',
#    'property',
#    'paying',
#    'mortgage',
#    'could',
#    'make',
#    'sense',
#    'renting',
#    'maintenance',
#    'miscellaneous',
#    'expenses',
#    'included'],
#   [],
#   ['renting',
#    'buying',
#    'property',
#    'singapore',
#    'individual',
#    'preference',
#    'benefits',
#    'renting',
#    'property',
#    'seems',
#    'lighter',
#    'financial',
#    'commitment',
#    'buying',
#    'property',
#    'huge',
#    'financial',
#    'commitment',
#    'person',
#    'rented',
#    'property',
#    'one',
#    'flexibility',
#    'move',
#    'aywhere',
#    'anyime',
#    'handy',
#    'situations',
#    'one',
#    'feels',
#    'like',
#    'changing',
#    'location',
#    'reason',
#    'buying',
#    'property',
#    'lot',
#    'benefits',
#    'long',
#    'run',
#    'major',
#    'benefit',
#    'related',
#    'income',
#    'generation',
#    'purchasing',
#    'property',
#    'generate',
#    'good',
#    'amount',
#    'income',
#    'future',
#    'also',
#    'customize',
#    'purchased',
#    'property',
#    'anyway',
#    'want',
#    'add',
#    'remove',
#    'anything',
#    'want',
#    'possible',
#    'rented',
#    'property',
#    'also',
#    'purchased',
#    'property',
#    'easily'],
#   []],
#  [['based',
#    'personal',
#    'experience',
#    'seems',
#    'like',
#    'moment',
#    'buy',
#    'property',
#    'breakeven',
#    'point',
#    'another',
#    'true',
#    'thoughts'],
#   [],
#   [],
#   ['hi',
#    'douglas',
#    'keynote',
#    'pretty',
#    'much',
#    'property',
#    'specfic',
#    'depends',
#    'much',
#    'loan',
#    'take',
#    'hard',
#    'conclude',
#    'break',
#    'even',
#    'point',
#    'case',
#    'assuming',
#    'taken',
#    'loan',
#    'would',
#    'surely',
#    'today',
#    'context',
#    'loan',
#    'max',
#    'pte',
#    'properties',
#    'assuming',
#    'one',
#    'takes',
#    'maximum',
#    'loan',
#    'shoud',
#    'profitable',
#    'price',
#    'increase',
#    'launch',
#    'date',
#    'top',
#    'cos',
#    'maket',
#    'conditions',
#    'change',
#    'esp',
#    'singapore',
#    'goernment',
#    'biggest',
#    'landlord',
#    'supplier',
#    'land',
#    'ability',
#    'impact',
#    'market',
#    'cooling'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['second', 'condo', 'investment', 'given', 'payment', 'heavy', 'singapore'],
#   ['hi',
#    'ivy',
#    'douglas',
#    'keynote',
#    'downpayment',
#    'heavy',
#    'since',
#    'take',
#    'loan',
#    'second',
#    'residential',
#    'look',
#    'commercial',
#    'industrial',
#    'sector',
#    'u',
#    'take',
#    'higher',
#    'loan',
#    'quantum',
#    'long',
#    'clear',
#    'tdsr',
#    'individual'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['would',
#    'consider',
#    'diversified',
#    'investment',
#    'portfolio',
#    'would',
#    'consider',
#    'diversified',
#    'investment',
#    'portfolio',
#    'regards',
#    'property'],
#   ['hi',
#    'douglas',
#    'key',
#    'note',
#    'experience',
#    'high',
#    'net',
#    'worth',
#    'clients',
#    'would',
#    'encompass',
#    'property',
#    'different',
#    'types',
#    'high',
#    'net',
#    'worth',
#    'clients',
#    'also',
#    'shifting',
#    'commercial',
#    'industrial',
#    'properties',
#    'avoid',
#    'paying',
#    'absd',
#    'residential',
#    'requires',
#    'lot',
#    'ammo',
#    'much',
#    'depends',
#    'firepower',
#    'firepower',
#    'limited',
#    'start',
#    'reits',
#    'investment',
#    'seduced',
#    'quatererly',
#    'dividends',
#    'depends',
#    'performance',
#    'reits',
#    'well',
#    'anaylse',
#    'reits',
#    'like',
#    'u',
#    'analyse',
#    'stocks',
#    'studying',
#    'assets',
#    'hold',
#    'challenges',
#    'might',
#    'face',
#    'repeat',
#    'mistakes',
#    'folks',
#    'bought',
#    'high',
#    'yield',
#    'hyflux',
#    'bonds',
#    'even',
#    'read',
#    'hyflux',
#    'financial',
#    'statements',
#    'one',
#    'look',
#    'accounts',
#    'startling',
#    'negative',
#    'cash',
#    'flow',
#    'dated',
#    'back',
#    'almost',
#    'years',
#    'advised',
#    'clients',
#    'subscribe',
#    'hyflux',
#    'bonds',
#    'nobody',
#    'got'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['important',
#    'factors',
#    'selecting',
#    'first',
#    'house',
#    'important',
#    'location',
#    'vs',
#    'view'],
#   ['hi',
#    'douglas',
#    'key',
#    'note',
#    'location',
#    'view',
#    'really',
#    'bad',
#    'give',
#    'nice',
#    'views',
#    'expensive',
#    'pretty',
#    'priced'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []],
#  [['decide', 'bto', 'private'],
#   ['hi',
#    'douglas',
#    'keynote',
#    'speaker',
#    'qualify',
#    'go',
#    'ec',
#    'new',
#    'launch',
#    'ec',
#    'priced',
#    'discount',
#    'comparable',
#    'mass',
#    'market',
#    'condos',
#    'lot',
#    'also',
#    'depends',
#    'life',
#    'plans',
#    'lifestyle',
#    'many',
#    'new',
#    'ec',
#    'launches',
#    'ok',
#    'locations',
#    'budget',
#    'must',
#    'allow'],
#   ['one',
#    'coming',
#    'sumang',
#    'walk',
#    'punggol',
#    'prob',
#    'launching',
#    'june',
#    'another',
#    'canberra',
#    'link',
#    'late',
#    'anchorvale',
#    'crescent',
#    'opposite',
#    'sengkang',
#    'general',
#    'hospital',
#    'one',
#    'tampines',
#    'ave',
#    'launched',
#    'later',
#    'ec',
#    'consideration',
#    'budget',
#    'bto'],
#   ['always', 'connect', 'via', 'https', 'simply', 'company', 'hotline'],
#   ['remember',
#    'plan',
#    'finances',
#    'properly',
#    'overstretch',
#    'homework',
#    'enjoy',
#    'property',
#    'investment',
#    'journey'],
#   ['regards'],
#   ['douglas'],
#   []]]

# %% [markdown]
# # Prepare model inputs

# %% [markdown]
# Prepare the inputs the LDA model needs to train on. Create the dictionary and term document frequency.

# %%
# Create dictionary
dictionary = gensim.corpora.Dictionary()
for thread in cleaned_corpus:
    dictionary.add_documents(thread)
#     print(dictionary.token2id)

# Collapse thread into bow
corpus_bow = []
for thread in cleaned_corpus:
    thread_bow = []
    for post in thread:
        for word in post:
            thread_bow.append(word)
    corpus_bow.append(thread_bow)

# Term document frequency
tdf = [dictionary.doc2bow(thread) for thread in corpus_bow]
tdf
# Out:
# [[(0, 2),
#   (1, 2),
#   (2, 3),
#   (3, 1),
#   (4, 1),
#   (5, 1),
#   (6, 1),
#   (7, 3),
#   (8, 1),
#   (9, 1),
#   (10, 1),
#   (11, 1),
#   (12, 2),
#   (13, 1),
#   (14, 1),
#   (15, 1),
#   (16, 1),
#   (17, 2),
#   (18, 1),
#   (19, 1),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1)],
#  [(3, 2),
#   (7, 5),
#   (11, 2),
#   (19, 2),
#   (29, 1),
#   (42, 2),
#   (43, 1),
#   (44, 3),
#   (45, 2),
#   (46, 1),
#   (47, 2),
#   (48, 1),
#   (49, 1),
#   (50, 1),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 3),
#   (57, 1),
#   (58, 1),
#   (59, 1),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 3),
#   (64, 1),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 2),
#   (69, 1),
#   (70, 2),
#   (71, 1),
#   (72, 1),
#   (73, 1),
#   (74, 1),
#   (75, 3),
#   (76, 1),
#   (77, 1),
#   (78, 2),
#   (79, 1),
#   (80, 1),
#   (81, 2),
#   (82, 2),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 3),
#   (87, 2),
#   (88, 1),
#   (89, 1),
#   (90, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (94, 2),
#   (95, 1),
#   (96, 2),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 1),
#   (104, 1),
#   (105, 1),
#   (106, 1),
#   (107, 1),
#   (108, 1),
#   (109, 2),
#   (110, 1),
#   (111, 1),
#   (112, 2),
#   (113, 1),
#   (114, 7),
#   (115, 1),
#   (116, 2),
#   (117, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 1),
#   (123, 1),
#   (124, 1),
#   (125, 2),
#   (126, 2),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 2),
#   (134, 1),
#   (135, 1),
#   (136, 1),
#   (137, 1),
#   (138, 1),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 1),
#   (143, 1),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 1),
#   (152, 1),
#   (153, 1),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 1),
#   (161, 1),
#   (162, 1),
#   (163, 1),
#   (164, 1),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 1),
#   (174, 1),
#   (175, 1)],
#  [(7, 3),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (56, 1),
#   (77, 1),
#   (81, 1),
#   (87, 1),
#   (129, 1),
#   (176, 2),
#   (177, 3),
#   (178, 1),
#   (179, 1),
#   (180, 1),
#   (181, 4),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 2),
#   (186, 1),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 1),
#   (191, 2),
#   (192, 1),
#   (193, 2),
#   (194, 1),
#   (195, 1),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 3),
#   (202, 1),
#   (203, 1),
#   (204, 1)],
#  [(7, 1),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (93, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 2),
#   (210, 1),
#   (211, 1),
#   (212, 1),
#   (213, 1),
#   (214, 1),
#   (215, 1),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 1),
#   (221, 1),
#   (222, 1),
#   (223, 1)],
#  [(0, 2),
#   (1, 2),
#   (3, 1),
#   (10, 1),
#   (35, 3),
#   (45, 2),
#   (52, 1),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (93, 1),
#   (95, 2),
#   (96, 1),
#   (120, 1),
#   (187, 1),
#   (189, 1),
#   (222, 1),
#   (224, 1),
#   (225, 1),
#   (226, 7),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 1),
#   (238, 2),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 1),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 2),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 2),
#   (259, 1),
#   (260, 1),
#   (261, 1),
#   (262, 2),
#   (263, 1),
#   (264, 1),
#   (265, 2),
#   (266, 1),
#   (267, 3),
#   (268, 1),
#   (269, 1),
#   (270, 2),
#   (271, 1),
#   (272, 1),
#   (273, 1),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 1),
#   (279, 1),
#   (280, 1),
#   (281, 1),
#   (282, 1),
#   (283, 1),
#   (284, 1),
#   (285, 1)],
#  [(7, 4),
#   (10, 2),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (69, 1),
#   (75, 1),
#   (92, 1),
#   (94, 1),
#   (102, 1),
#   (130, 2),
#   (192, 1),
#   (200, 1),
#   (209, 1),
#   (222, 1),
#   (242, 1),
#   (248, 1),
#   (280, 1),
#   (286, 3),
#   (287, 1),
#   (288, 2),
#   (289, 2),
#   (290, 1),
#   (291, 1),
#   (292, 1),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 2),
#   (297, 1),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 2),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 1),
#   (311, 1),
#   (312, 1),
#   (313, 1),
#   (314, 2),
#   (315, 1),
#   (316, 1),
#   (317, 1)],
#  [(1, 3),
#   (7, 4),
#   (11, 1),
#   (12, 1),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (50, 1),
#   (68, 1),
#   (69, 2),
#   (94, 1),
#   (95, 2),
#   (159, 1),
#   (184, 1),
#   (209, 2),
#   (269, 1),
#   (286, 2),
#   (318, 1),
#   (319, 1),
#   (320, 3),
#   (321, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 1),
#   (331, 3),
#   (332, 1)],
#  [(6, 2),
#   (7, 1),
#   (11, 1),
#   (60, 1),
#   (95, 1),
#   (105, 1),
#   (210, 1),
#   (251, 1),
#   (269, 1),
#   (286, 2),
#   (287, 1),
#   (307, 1),
#   (314, 2),
#   (333, 3),
#   (334, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1),
#   (343, 2),
#   (344, 1),
#   (345, 1),
#   (346, 1),
#   (347, 1),
#   (348, 1),
#   (349, 1),
#   (350, 1),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (355, 1)],
#  [(5, 3),
#   (6, 1),
#   (7, 2),
#   (110, 2),
#   (190, 1),
#   (200, 1),
#   (228, 1),
#   (238, 1),
#   (289, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 1),
#   (360, 1),
#   (361, 1),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1),
#   (370, 1),
#   (371, 2),
#   (372, 1),
#   (373, 1),
#   (374, 1),
#   (375, 1),
#   (376, 1),
#   (377, 1),
#   (378, 1),
#   (379, 1),
#   (380, 1)],
#  [(7, 4),
#   (11, 1),
#   (14, 1),
#   (17, 2),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (76, 1),
#   (87, 1),
#   (93, 1),
#   (179, 1),
#   (192, 2),
#   (199, 1),
#   (204, 1),
#   (217, 1),
#   (219, 2),
#   (229, 1),
#   (258, 1),
#   (280, 1),
#   (287, 1),
#   (289, 4),
#   (298, 1),
#   (300, 1),
#   (320, 1),
#   (378, 1),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 1),
#   (390, 1),
#   (391, 1),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 1),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 1),
#   (405, 1),
#   (406, 2),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 1),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 2),
#   (417, 1),
#   (418, 1)],
#  [(1, 1),
#   (2, 1),
#   (7, 1),
#   (10, 1),
#   (12, 1),
#   (17, 1),
#   (23, 1),
#   (25, 1),
#   (26, 3),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (52, 2),
#   (68, 1),
#   (98, 1),
#   (106, 1),
#   (110, 1),
#   (159, 3),
#   (222, 1),
#   (238, 1),
#   (324, 1),
#   (331, 2),
#   (359, 1),
#   (376, 1),
#   (419, 2),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 1),
#   (424, 1),
#   (425, 1),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 1),
#   (430, 1),
#   (431, 1),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 1),
#   (436, 1),
#   (437, 1),
#   (438, 1),
#   (439, 1)],
#  [(6, 1),
#   (7, 2),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 2),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (50, 1),
#   (75, 1),
#   (85, 1),
#   (86, 1),
#   (91, 1),
#   (178, 1),
#   (193, 1),
#   (200, 1),
#   (356, 1),
#   (359, 1),
#   (409, 1),
#   (440, 1),
#   (441, 1),
#   (442, 1),
#   (443, 1),
#   (444, 1),
#   (445, 1),
#   (446, 1),
#   (447, 1),
#   (448, 2),
#   (449, 2),
#   (450, 1),
#   (451, 1),
#   (452, 1),
#   (453, 1),
#   (454, 1),
#   (455, 1),
#   (456, 1)],
#  [(5, 2),
#   (7, 4),
#   (8, 2),
#   (9, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 4),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (66, 1),
#   (81, 1),
#   (92, 2),
#   (93, 1),
#   (95, 5),
#   (98, 1),
#   (159, 3),
#   (178, 1),
#   (220, 1),
#   (238, 1),
#   (247, 1),
#   (251, 1),
#   (253, 2),
#   (258, 2),
#   (268, 2),
#   (272, 1),
#   (330, 1),
#   (331, 1),
#   (343, 1),
#   (355, 1),
#   (356, 2),
#   (367, 1),
#   (369, 1),
#   (420, 3),
#   (421, 1),
#   (453, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 3),
#   (461, 1),
#   (462, 1),
#   (463, 1),
#   (464, 1),
#   (465, 1),
#   (466, 2),
#   (467, 2),
#   (468, 1),
#   (469, 1),
#   (470, 1),
#   (471, 1),
#   (472, 1),
#   (473, 1),
#   (474, 1),
#   (475, 1),
#   (476, 2),
#   (477, 1),
#   (478, 1),
#   (479, 1),
#   (480, 1),
#   (481, 1),
#   (482, 1),
#   (483, 1),
#   (484, 1),
#   (485, 2),
#   (486, 2),
#   (487, 1),
#   (488, 1),
#   (489, 1),
#   (490, 1),
#   (491, 1),
#   (492, 1),
#   (493, 3),
#   (494, 1),
#   (495, 1),
#   (496, 1),
#   (497, 2),
#   (498, 1),
#   (499, 1),
#   (500, 1),
#   (501, 1),
#   (502, 1),
#   (503, 6),
#   (504, 1),
#   (505, 1),
#   (506, 1),
#   (507, 1),
#   (508, 1),
#   (509, 1),
#   (510, 2),
#   (511, 2),
#   (512, 1),
#   (513, 1),
#   (514, 1),
#   (515, 1),
#   (516, 1),
#   (517, 1),
#   (518, 1),
#   (519, 1),
#   (520, 1),
#   (521, 2),
#   (522, 1),
#   (523, 1),
#   (524, 2),
#   (525, 1),
#   (526, 1),
#   (527, 1)],
#  [(1, 1),
#   (6, 1),
#   (7, 2),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 2),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (44, 1),
#   (64, 1),
#   (179, 2),
#   (192, 1),
#   (209, 1),
#   (219, 2),
#   (300, 1),
#   (322, 1),
#   (356, 2),
#   (452, 1),
#   (454, 1),
#   (528, 1),
#   (529, 1),
#   (530, 1),
#   (531, 2),
#   (532, 1),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1)],
#  [(0, 1),
#   (6, 2),
#   (7, 12),
#   (11, 2),
#   (23, 1),
#   (38, 1),
#   (45, 2),
#   (52, 5),
#   (60, 1),
#   (75, 1),
#   (77, 1),
#   (85, 2),
#   (86, 1),
#   (87, 3),
#   (108, 1),
#   (111, 1),
#   (181, 1),
#   (184, 1),
#   (224, 1),
#   (246, 2),
#   (269, 2),
#   (300, 1),
#   (305, 1),
#   (314, 2),
#   (322, 2),
#   (330, 4),
#   (346, 2),
#   (348, 1),
#   (395, 1),
#   (399, 2),
#   (407, 2),
#   (433, 1),
#   (452, 1),
#   (528, 1),
#   (537, 1),
#   (538, 6),
#   (539, 2),
#   (540, 1),
#   (541, 1),
#   (542, 1),
#   (543, 1),
#   (544, 1),
#   (545, 2),
#   (546, 1),
#   (547, 2),
#   (548, 1),
#   (549, 1),
#   (550, 1),
#   (551, 1),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 2),
#   (558, 1),
#   (559, 2),
#   (560, 1),
#   (561, 1),
#   (562, 1),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1),
#   (569, 1),
#   (570, 1),
#   (571, 1),
#   (572, 1),
#   (573, 1),
#   (574, 1),
#   (575, 1),
#   (576, 1),
#   (577, 2),
#   (578, 1),
#   (579, 1)],
#  [(1, 1),
#   (3, 1),
#   (5, 4),
#   (6, 1),
#   (7, 3),
#   (14, 2),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (60, 1),
#   (69, 1),
#   (82, 1),
#   (85, 1),
#   (93, 1),
#   (96, 2),
#   (105, 2),
#   (159, 1),
#   (179, 1),
#   (195, 1),
#   (199, 1),
#   (269, 1),
#   (296, 1),
#   (318, 1),
#   (330, 1),
#   (379, 1),
#   (404, 1),
#   (406, 1),
#   (416, 1),
#   (467, 1),
#   (471, 1),
#   (539, 1),
#   (540, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 1),
#   (586, 1),
#   (587, 1),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 1),
#   (594, 1),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 1),
#   (606, 1),
#   (607, 1),
#   (608, 1)],
#  [(5, 2),
#   (7, 1),
#   (17, 2),
#   (18, 1),
#   (19, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 2),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (56, 1),
#   (87, 1),
#   (180, 1),
#   (222, 1),
#   (228, 2),
#   (330, 1),
#   (331, 1),
#   (379, 2),
#   (430, 1),
#   (433, 1),
#   (434, 1),
#   (438, 1),
#   (609, 1),
#   (610, 2),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1)],
#  [(6, 1),
#   (7, 3),
#   (17, 2),
#   (18, 1),
#   (23, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 4),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 2),
#   (45, 1),
#   (60, 2),
#   (69, 1),
#   (77, 3),
#   (79, 1),
#   (85, 1),
#   (94, 1),
#   (96, 1),
#   (129, 2),
#   (130, 1),
#   (159, 1),
#   (165, 1),
#   (180, 1),
#   (193, 3),
#   (196, 2),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (246, 1),
#   (263, 1),
#   (269, 3),
#   (331, 1),
#   (334, 1),
#   (371, 1),
#   (394, 1),
#   (398, 1),
#   (419, 1),
#   (425, 1),
#   (430, 1),
#   (434, 1),
#   (513, 1),
#   (529, 2),
#   (535, 1),
#   (547, 1),
#   (581, 1),
#   (616, 1),
#   (618, 2),
#   (619, 2),
#   (620, 1),
#   (621, 1),
#   (622, 1),
#   (623, 1),
#   (624, 1),
#   (625, 2),
#   (626, 1),
#   (627, 1),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 1),
#   (633, 2),
#   (634, 1),
#   (635, 1),
#   (636, 3),
#   (637, 1),
#   (638, 1),
#   (639, 1),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 3),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 1)],
#  [(7, 1),
#   (17, 2),
#   (18, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (71, 1),
#   (79, 1),
#   (86, 2),
#   (125, 1),
#   (199, 1),
#   (209, 1),
#   (220, 1),
#   (343, 1),
#   (348, 1),
#   (371, 1),
#   (395, 1),
#   (654, 2),
#   (655, 1),
#   (656, 2),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1)],
#  [(6, 2),
#   (7, 1),
#   (17, 2),
#   (18, 1),
#   (22, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 1),
#   (30, 1),
#   (31, 1),
#   (32, 1),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 1),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 1),
#   (41, 1),
#   (45, 1),
#   (57, 1),
#   (60, 1),
#   (92, 1),
#   (93, 1),
#   (102, 1),
#   (178, 1),
#   (179, 1),
#   (197, 1),
#   (200, 1),
#   (215, 1),
#   (216, 4),
#   (217, 1),
#   (218, 1),
#   (219, 2),
#   (220, 1),
#   (221, 1),
#   (229, 1),
#   (286, 2),
#   (304, 1),
#   (318, 1),
#   (435, 1),
#   (449, 2),
#   (547, 1),
#   (661, 1),
#   (662, 1),
#   (663, 1),
#   (664, 1),
#   (665, 1),
#   (666, 1),
#   (667, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 1),
#   (674, 1),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1)]]

# %% [markdown]
# # Build LDA model

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=tdf,
                                           id2word=dictionary,
                                           num_topics=3, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=3,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the 10 topics
print(lda_model.print_topics())
# Out:
# [(0, '0.014*"rah" + 0.014*"renting" + 0.013*"money" + 0.010*"investment" + 0.007*"leverage" + 0.007*"seminars" + 0.007*"means" + 0.007*"buying" + 0.007*"financial" + 0.007*"pay"'), (1, '0.025*"property" + 0.018*"loan" + 0.011*"buying" + 0.010*"take" + 0.009*"one" + 0.009*"point" + 0.008*"much" + 0.007*"long" + 0.007*"depends" + 0.007*"seems"'), (2, '0.031*"property" + 0.024*"douglas" + 0.020*"investment" + 0.014*"company" + 0.014*"homework" + 0.014*"plan" + 0.014*"always" + 0.014*"regards" + 0.013*"overstretch" + 0.013*"simply"')]
