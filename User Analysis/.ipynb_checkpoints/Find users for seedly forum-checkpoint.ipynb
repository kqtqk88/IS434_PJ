# %%
import pandas as pd
import glob

csv_dir_path = "../WebScraper/seedly-forum/*.csv"

# %%
user_list = []
question_user_list = []

for filename in glob.glob(csv_dir_path):
    files.append(filename)
    question_asked, users = read_csv(filename)
    user_list.extend(users)
    question_user_list.append(question_asked)

# %%
class User:
    
    def __init__(self, name, level):
        self.name = name
        self.level = level
    
    def get_level(self):
        return self.level
    
    def get_name(self):
        return self.name
    
    def set_name(name):
        self.name = name
    
    def to_string(self):
        return self.name + " " + self.level

# %%
def read_csv(filename):
    
    file_df = pd.read_csv(filename)
    return get_users(file_df)

# %%
def get_users(df):
    user_list = []
    
    for i,content in enumerate(df.content):
        if i == 0:
            substr_index = content.find("Asked by")
            user_details = content[substr_index:]
            new_sub_index = user_details.find("Asked on")
            question_name = user_details[:new_sub_index].replace("Asked by","").strip()
            if question_name.find("Asked")!= -1:
                question_name = question_name[:question_name.find("Asked")]
                
        elif i > 1:
            substr_index = content.find("Answered")
            user_details = content[:substr_index]
            commar_index = user_details.find(",")
            level_index = user_details.find("Level")
            rank_index = user_details.find(".")
            user_list.append(User(user_details[:commar_index],user_details[level_index:rank_index].replace("Level","").strip()))
            
    return question_name, user_list

# %%
user_dict = {}

for user in user_list:
    user_name = user.get_name()
    if user_name in user_dict.keys():
        user_dict[user_name] += 1
    else:
        user_dict[user_name] = 1
        
print(user_dict)
print(len(user_dict))
# Out:
# {'Jason Yip': 2, 'Billy Ko': 122, 'Douglas Chow': 61, 'Junus EuTop Contributor (Sep)Level 8. Wizar': 420, 'Lok Yang TengLevel 6. Maste': 250, 'Yong Kah HweeLevel 6. Maste': 576, 'Goh Kah Kiat': 22, 'Darius MCLevel 1. Freshi': 2, 'Ashley Wong': 116, 'Cedric Jamie Soh': 422, 'Ryan OngLevel 2. Rooki': 11, 'Yixiong ChangLevel 5. Geniu': 216, 'Clarence Chua': 217, 'Krristy LamLevel 2. Rooki': 1, 'Teo See Hwa': 126, 'Nguyen Thu HaLevel 1. Freshi': 2, 'Ang Yee Gary27 May 2019Any ball park figure on the expected growth in property price in next few yea': 2, 'Ang Yee Gary': 47, 'Krristy Lam': 2, 'Paul HoLevel 2. Rooki': 1, 'Loh Tat Tian': 400, 'Question Poster04 Aug 2019Basically': 1, 'Loo Cheng Chuan': 141, 'Kenneth Lou07 Nov 2018DeleteEdit100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres': 1, 'Luke Ho': 287, 'Gabriel LeeLevel 6. Maste': 293, 'Kenneth Lou07 Nov 2018100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres': 2, 'Hariz Arthur Maloy': 1285, 'Loo Cheng Chuan05 Nov 2018Hi. It is a good question. Commonly asked by aspiring home owners. Also similar to this question is that of : should one use OA and pay up their home loan compared to transferring to SA': 2, 'Kok KoonLevel 5. Geniu': 12, 'Lim Tian ShangLevel 3. Wonderki': 10, 'Loo Cheng ChuanLevel 6. Maste': 8, 'Ck ChaiLevel 4. Prodig': 58, "Elsa GohLevel 5. GeniusUpdated on 11 Dec 2018Work 2 jobs. Or take up more freelance work if possible. This is not sustainable. Math doesn't lie. All our investment tips depend on people having spare cash in the first place.0 comment": 3, 'Daniel LingLevel 4. Prodig': 77, 'Good Day Every DayLevel 6. Maste': 334, 'Nicholes Wong': 531, 'Png Cheng Xi Damien': 74, "Teo See Hwa10 Dec 2018Risk is about how much one know about what one is doing. e.g. if a person don't go for driving lesson and chose to drive without a licence what is the risk compare to a person who got a licence. Both driving the same ca": 2, 'Good Day Every DayLevel 6. MasterUpdated on 07 Jun 2019Nothing is certain in investment. The political parties or climate may change. The interest rate of 2.5% for OA': 2, "See all 3 comments Good Day Every Day10 Dec 2018I don't understand the relevance of your answer to the question. Please enlighten me. Thanks. Teo See Hwa18 Dec 2018Risk is high when you got limited info or data. Leverage is Risky when you do it the wrong way": 2, 'Leong Wen Fong10 Dec 2018Hi See Hwa': 2, "Steph Yeo14 Nov 2018But you'll have to wait until you're old enough to take out money from cpf": 3, 'Gabriel Tham': 927, 'Question Poster07 Nov 2018Thanks for sharing with me your answer. I think helps me shape how I think I want to retire next time. And what I will need to do to get there as well. Appreciate you helping all of us younger audience': 3, 'Jim NgLevel 5. GeniusUpdated on 07 Jun 2019Pros:Have more interaction amongst family members': 1, 'Question Poster11 Nov 2018That is true. Thanks for sharin': 1, 'Gabriel LeeLevel 6. MasterUpdated on 07 Jun 2019It makes the home more lively': 1, 'See all 3 comments Question Poster11 Nov 2018Thanks for sharingGabriel Lee11 Nov 2018Nice to hear that': 1, 'Loh Tat TianLevel 6. MasterUpdated on 21 Nov 2018As a fresh grad': 1, 'Jim NgLevel 5. Geniu': 28, 'Pat08 Nov 2018Hi just to clarify': 1, 'Chong Learn KhangLevel 2. RookieUpdated on 07 Jun 2019Hi Danial': 1, 'Leong Wen Fong15 Nov 2018Good advice': 1, 'Jonathan Chia Guangrong': 624, 'Jeff Yeo': 331, 'Yeap Ming Feng': 17, 'Kenneth Lou': 416, 'Yeap Ming FengLevel 5. Geniu': 18, 'DeleteEditKenneth Lou': 14, 'Yixiong ChangLevel 5. GeniusUpdated on 07 Jun 2019I depends what would you do with your cash': 1, 'See all 3 comments Yixiong Chang05 Nov 2018Hi': 1, 'Christopher Tan': 86, 'Question Poster24 Jan 2019Thank you for ...
# 5652

# %%
for user in user_list:
    print(user.get_name())
    user
    print(user.get_level())
# Out:
# Jason Yip
#
# 2
# Billy Ko
#
# 6
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Lok Yang TengLevel 6. Maste
#
# 6
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Yong Kah HweeLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Goh Kah Kiat
#
#
# Darius MCLevel 1. Freshi
#
# 1
# Douglas Chow
#
# 3
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Ashley Wong
#
# 4
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Cedric Jamie Soh
#
#
# Ryan OngLevel 2. Rooki
#
# 2
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Yixiong ChangLevel 5. Geniu
#
# 5
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Clarence Chua
#
# 7
# Krristy LamLevel 2. Rooki
#
# 2
# Douglas Chow
#
# 3
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Lok Yang TengLevel 6. Maste
#
# 6
# Douglas Chow
#
# 3
# Teo See Hwa
#
# 3
# Nguyen Thu HaLevel 1. Freshi
#
# 1
# Douglas Chow
#
# 3
# Douglas Chow
#
# 3
# Ang Yee Gary27 May 2019Any ball park figure on the expected growth in property price in next few yea
#
#
# Ang Yee Gary
#
# 4
# Krristy Lam
#
#
# Douglas Chow
#
# 3
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Paul HoLevel 2. Rooki
#
# 2
# Douglas Chow
#
# 3
# Loh Tat Tian
#
# 6
# Question Poster04 Aug 2019Basically
#
#
# Loo Cheng Chuan
#
# 6
# Kenneth Lou07 Nov 2018DeleteEdit100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres
#
#
# Luke Ho
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Kenneth Lou07 Nov 2018100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres
#
#
# Luke Ho
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Hariz Arthur Maloy
#
# 9
# Loo Cheng Chuan05 Nov 2018Hi. It is a good question. Commonly asked by aspiring home owners. Also similar to this question is that of : should one use OA and pay up their home loan compared to transferring to SA
#
#
# Kok KoonLevel 5. Geniu
#
# 5
# Lim Tian ShangLevel 3. Wonderki
#
# 3
# Yixiong ChangLevel 5. Geniu
#
# 5
# Loo Cheng Chuan
#
# 6
# Teo See Hwa
#
# 3
# Loo Cheng ChuanLevel 6. Maste
#
# 6
# Ck ChaiLevel 4. Prodig
#
# 4
# Elsa GohLevel 5. GeniusUpdated on 11 Dec 2018Work 2 jobs. Or take up more freelance work if possible. This is not sustainable. Math doesn't lie. All our investment tips depend on people having spare cash in the first place.0 comment
#
# 5
# Daniel LingLevel 4. Prodig
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Png Cheng Xi Damien
#
# 4
# Good Day Every DayLevel 6. Maste
#
# 6
# Loo Cheng ChuanLevel 6. Maste
#
# 6
# Teo See Hwa
#
# 3
# Luke Ho
#
# 6
# Yixiong ChangLevel 5. Geniu
#
# 5
# Hariz Arthur Maloy
#
# 9
# Loo Cheng Chuan
#
# 6
# Teo See Hwa10 Dec 2018Risk is about how much one know about what one is doing. e.g. if a person don't go for driving lesson and chose to drive without a licence what is the risk compare to a person who got a licence. Both driving the same ca
#
#
# Good Day Every DayLevel 6. MasterUpdated on 07 Jun 2019Nothing is certain in investment. The political parties or climate may change. The interest rate of 2.5% for OA
#
# 6
# See all 3 comments Good Day Every Day10 Dec 2018I don't understand the relevance of your answer to the question. Please enlighten me. Thanks. Teo See Hwa18 Dec 2018Risk is high when you got limited info or data. Leverage is Risky when you do it the wrong way
#
#
# Teo See Hwa
#
# 3
# Leong Wen Fong10 Dec 2018Hi See Hwa
#
#
# Good Day Every DayLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Steph Yeo14 Nov 2018But you'll have to wait until you're old enough to take out money from cpf
#
#
# Loo Cheng Chuan
#
# 6
# Gabriel Tham
#
# 8
# Loo Cheng Chuan
#
# 6
# Question Poster07 Nov 2018Thanks for sharing with me your answer. I think helps me shape how I think I want to retire next time. And what I will need to do to get there as well. Appreciate you helping all of us younger audience
#
#
# Hariz Arthur Maloy
#
# 9
# Loo Cheng Chuan
#
# 6
# Jim NgLevel 5. GeniusUpdated on 07 Jun 2019Pros:Have more interaction amongst family members
#
# 5
# Question Poster11 Nov 2018That is true. Thanks for sharin
#
#
# Gabriel LeeLevel 6. MasterUpdated on 07 Jun 2019It makes the home more lively
#
# 6
# See all 3 comments Question Poster11 Nov 2018Thanks for sharingGabriel Lee11 Nov 2018Nice to hear that
#
#
# Hariz Arthur Maloy
#
# 9
# Loo Cheng Chuan
#
# 6
# Yixiong ChangLevel 5. Geniu
#
# 5
# Loh Tat TianLevel 6. MasterUpdated on 21 Nov 2018As a fresh grad
#
# 6
# Jim NgLevel 5. Geniu
#
# 5
# Loo Cheng Chuan
#
# 6
# Pat08 Nov 2018Hi just to clarify
#
#
# Hariz Arthur Maloy
#
# 9
# Yixiong ChangLevel 5. Geniu
#
# 5
# Jim NgLevel 5. Geniu
#
# 5
# Loo Cheng Chuan
#
# 6
# Chong Learn KhangLevel 2. RookieUpdated on 07 Jun 2019Hi Danial
#
# 2
# Leong Wen Fong15 Nov 2018Good advice
#
#
# Good Day Every DayLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Gabriel Tham
#
# 8
# Jeff Yeo
#
# 6
# Loo Cheng Chuan
#
# 6
# Nicholes Wong
#
# 6
# Yeap Ming Feng
#
# 5
# Kenneth Lou
#
# 8
# Loo Cheng Chuan
#
# 6
# Yeap Ming FengLevel 5. Geniu
#
# 5
# Loo Cheng Chuan
#
# 6
# DeleteEditKenneth Lou
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Kenneth Lou
#
# 8
# Teo See Hwa
#
# 3
# Good Day Every DayLevel 6. Maste
#
# 6
# Yixiong ChangLevel 5. GeniusUpdated on 07 Jun 2019I depends what would you do with your cash
#
# 5
# See all 3 comments Yixiong Chang05 Nov 2018Hi
#
#
# Loo Cheng Chuan
#
# 6
# Loo Cheng Chuan
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Loo Cheng Chuan
#
# 6
# Loo Cheng Chuan
#
# 6
# Loo Cheng Chuan
#
# 6
# Yixiong ChangLevel 5. Geniu
#
# 5
# Christopher Tan
#
# 6
# Hariz Arthur Maloy
#
# 9
# Christopher Tan
#
# 6
# Question Poster24 Jan 2019Thank you for your honest answer!
#
#
# Gabriel Tham
#
# 8
# Christopher Tan23 Jan 2019Thank you Gabriel! Yes you are right. We definitely don’t “prospect” you and pressure sell you anything. This you can be sure.
#
# But I would like to correct the misconception that when one uses MoneyOwl
#
#
# Luke HoLevel 6. MasterUpdated on 07 Jun 2019Hah. I gotta try this. But I could still be wrong
#
# 6
# Christopher Tan25 Jan 2019Hi Luke
#
#
# Christopher Tan
#
# 6
# Nicholes Wong
#
# 6
# Lim Dewei Nicholas
#
# 1
# Yong Kah HweeLevel 6. Maste
#
# 6
# Christopher Tan
#
# 6
# Christopher Tan
#
# 6
# Devanshi Singh
#
# 3
# Ashley Wong
#
# 4
# Christopher Tan
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Kenneth Lou
#
# 8
# Jonathan Chia Guangrong17 Sep 2019Hi Kenneth. The link you provided does not seem to be workin
#
#
# Cedric Jamie Soh
#
#
# DeleteEditKenneth Lou
#
# 8
# Jonathan Chia Guangrong17 Sep 2019Hi Kenneth. The link you provided does not seem to be workin
#
#
# Cedric Jamie Soh
#
#
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Isaac ChanLevel 8. Wizar
#
# 8
# Brandan Chen
#
# 6
# Gibson JunxunLevel 3. Wonderki
#
# 3
# Jonathan Chia Guangrong
#
# 6
# Loh Tat Tian
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Jonathan Chia Guangrong
#
# 6
# See all 6 comments Question Poster30 Jan 2019Hi thank you Jonathan you have been a great help. Will call them tomorrow to ask more about itCk Chai01 Feb 2019Thanks for sharing Jonatha
#
#
# Gabriel Tham
#
# 8
# Lok Yang Teng29 Jan 2019Which market would you recommend for a not so advanced investor not seeking short term gains?Gabriel Tham29 Jan 2019Start with your local country market
#
#
# Jonathan Chia Guangrong
#
# 6
# See all 3 comments Jonathan Chia Guangrong29 Jan 2019Nicholas has mentioned this here https://seedly.sg/questions/how-do-i-invest-in-a-fund-that-tracks-s-p500-if-i-don-t-have-a-cdp-accountLok Yang Teng30 Jan 2019Thank
#
#
# Ashley Wong
#
# 4
# Hariz Arthur Maloy
#
# 9
# Yong Kah HweeLevel 6. MasterUpdated on 07 Jun 2019You can start with ETFs/roboadvisors. Or Regular Saving Plans!1 commen
#
# 6
# Question Poster28 Jan 2019How much should I roughly invest in ETFs and roboadvisors? I understand for roboadvisors is better to put in money every month (not sure for how long
#
#
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019Keep emergency funds of at least 6 months' worth of salary:e.g 4
#
# 6
# Question Poster28 Jan 2019100 - age = percentage of the lump sum I assume?
#
# Also
#
#
# Ng Lip Hong Kyith
#
# 5
# Kenneth Lou21 Aug 2018DeleteEditInteresting! Thanks for your thoughts :) indeed it’s a world which is always evolving quickly. And also read about the soverign deposits one. I think along with many other bloggers
#
#
# Heng Kai LeLevel 4. Prodig
#
# 4
# Charmaine Ng
#
# 6
# Eric Chia
#
# 4
# Luke Ho
#
# 6
# Ng Lip Hong Kyith
#
# 5
# Jeff Yeo
#
# 6
# Brandan Chen
#
# 6
# Luke Ho
#
# 6
# Ng Lip Hong Kyith
#
# 5
# Changzhong Zhuang
#
# 3
# See all 3 comments Kenneth Lou20 Aug 2018This is pretty cool thanks for sharing :) And in case you are wondering
#
#
# Alan KorLevel 5. Geniu
#
# 5
# Gabriel ThamLevel 8. Wizar
#
# 8
# Colin LimLevel 3. Wonderki
#
# 3
# Charmaine Ng
#
# 6
# See all 4 comments Charmaine Ng24 Aug 2018Thanks Low! I'll check in with you if I need help! 😉Charmaine Ng24 Aug 2018Yeah Alan
#
#
# Loh Tat TianLevel 6. Maste
#
# 6
# Ng Lip Hong Kyith
#
# 5
# Chris Lee Susanto
#
# 2
# Dwivid SharmaLevel 3. Wonderki
#
# 3
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Devanshi Singh
#
# 3
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Luke Ho
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# HC Tang
#
# 8
# Jonathan Chia Guangrong
#
# 6
# Kenichi Xi
#
# 6
# Choon Yuan Chan
#
# 4
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong Kyith
#
# 5
# See all 3 comments Ng Lip Hong Kyith07 May 2019Hi Chee Hoe
#
#
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Ng Lip Hong Kyith
#
# 5
# Say Kiat21 Aug 2018Thank you for the effort of long explanation ! Your are just one of those kind soul that bring me one step closer to investing. God bless u! Is there any way to reach u other than this foru
#
#
# Ng Lip Hong Kyith
#
# 5
# Ng Lip Hong KyithLevel 5. Geniu
#
# 5
# Jeff Yeo
#
# 6
# Eric Chia16 Aug 2018Do note you'll need to spend at least $500 on uob credit cards for that month to qualify for bonus interest
#
#
# Isabella JoLevel 4. Prodig
#
# 4
# Tee-Ming Chew
#
# 6
# Dawn FionaLevel 5. Geniu
#
# 5
# Dawn FionaLevel 5. Geniu
#
# 5
# Dawn FionaLevel 5. Geniu
#
# 5
# Leong Wen FongLevel 6. Maste
#
# 6
# Jeff Yeo
#
# 6
# JianHao SooLevel 4. Prodig
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# Tan Siak Lim
#
#
# Charmaine Ng
#
# 6
# Eric Chia
#
# 4
# Dawn FionaLevel 5. Geniu
#
# 5
# Dawn FionaLevel 5. Geniu
#
# 5
# JianHao SooLevel 4. Prodig
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# Ernest Yeam Wee LeongLevel 5. Geniu
#
# 5
# Dawn FionaLevel 5. Geniu
#
# 5
# Lawrence YipLevel 2. Rooki
#
# 2
# Dawn FionaLevel 5. Geniu
#
# 5
# Daniel LingLevel 4. Prodig
#
# 4
# Ck ChaiLevel 4. Prodig
#
# 4
# Kenichi Xi
#
# 6
# HC Tang
#
# 8
# Jonathan Chia Guangrong
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# ZeeeeeLevel 4. Prodig
#
# 4
# Dawn FionaLevel 5. Geniu
#
# 5
# Gabriel LeeLevel 6. Maste
#
# 6
# Alan KorLevel 5. Geniu
#
# 5
# James YeoLevel 4. Prodig
#
# 4
# Jeff Yeo
#
# 6
# Yeap Ming Feng
#
# 5
# Dawn FionaLevel 5. Geniu
#
# 5
# Brandan Chen
#
# 6
# Charmaine Ng
#
# 6
# Daryl Koh | TeamFatherAndSon.com
#
#
# Jeff Yeo
#
# 6
# Dawn FionaLevel 5. Geniu
#
# 5
# Yeap Ming FengLevel 5. Geniu
#
# 5
# HC Tang
#
# 8
# Hariz Arthur Maloy
#
# 9
# Npm AdeleLevel 3. Wonderki
#
# 3
# Good Day Every DayLevel 6. Maste
#
# 6
# Serene TohLevel 5. Geniu
#
# 5
# Kenichi Xi
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Huang YixuanLevel 6. MasterUpdated on 28 Sep 2018I think it's perfectly fine to take up an internship after graduation
#
# 6
# YMYeap Ming FengLevel 5. Geniu
#
# 5
# HC Tang
#
# 8
# Hariz Arthur Maloy
#
# 9
# Npm AdeleLevel 3. Wonderki
#
# 3
# Good Day Every DayLevel 6. Maste
#
# 6
# Serene TohLevel 5. Geniu
#
# 5
# Kenichi Xi
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Huang YixuanLevel 6. MasterUpdated on 28 Sep 2018I think it's perfectly fine to take up an internship after graduation
#
# 6
# Kok KoonLevel 5. GeniusUpdated on 07 Jun 2019I don't know how much you owe but I got $11k student debt when I graduated.The upside was that the economy so bad in 2008 that all banks were requested by the Government to suspended interest charge on study loans:​​What I do to clear my debts:​1. Work like there's no day no night. Hustles
#
# 5
# See all 3 comments Kok Koon12 Sep 2018Agree with you
#
#
# Soh Sing Heng
#
# 4
# Singchang TohLevel 2. Rooki
#
# 2
# William SeahLevel 3. Wonderki
#
# 3
# Kenneth Lou
#
# 8
# See all 3 comments Kenneth Lou13 Sep 2018Yeah haha
#
#
# Colin LimLevel 3. Wonderki
#
# 3
# Good Day Every DayLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# HC Tang
#
# 8
# Gabriel LeeLevel 6. Maste
#
# 6
# Kenichi Xi
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Gabriel Tham
#
# 8
# Jeff Yeo
#
# 6
# Soh Sing Heng
#
# 4
# Tan Siak Lim
#
#
# Teo See Hwa
#
# 3
# Question Poster09 Oct 2018cool thank you for your sharing and pointing in the right directi
#
#
# Soh Sing HengLevel 4. Prodig
#
# 4
# Nicholas ChanLevel 5. Geniu
#
# 5
# Jay Liu
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Soh Sing Heng
#
# 4
# Serene TohLevel 5. Geniu
#
# 5
# Soh Sing HengLevel 4. Prodig
#
# 4
# Kenichi Xi
#
# 6
# Jay Liu
#
# 6
# Soh Sing Heng
#
# 4
# Jeff Yeo
#
# 6
# Kenneth Lou
#
# 8
# Nicholas ChanLevel 5. Geniu
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Soh Sing Heng
#
# 4
# Luke Ho
#
# 6
# Loh Tat Tian
#
# 6
# Eric Chia
#
# 4
# Alex NgLevel 1. Freshi
#
# 1
# Choon Yuan ChanLevel 4. Prodig
#
# 4
# Hariz Arthur Maloy
#
# 9
# Soh Sing HengLevel 4. Prodig
#
# 4
# Soh Sing Heng
#
# 4
# Serene TohLevel 5. Geniu
#
# 5
# Soh Sing Heng
#
# 4
# Serene Toh18 Oct 2018Alamak just realised roughly the same answer after I poste
#
#
# Gabriel LeeLevel 6. Maste
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Soh Sing Heng
#
# 4
# Nicholas ChanLevel 5. Geniu
#
# 5
# Good Day Every DayLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Choon Yuan ChanLevel 4. Prodig
#
# 4
# Good Day Every DayLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Dwivid SharmaLevel 3. Wonderki
#
# 3
# Nicholes WongLevel 6. Maste
#
# 6
# Kenichi Xi
#
# 6
# Jay Liu
#
# 6
# Hao YuLevel 3. Wonderki
#
# 3
# Jeff Yeo
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# HC Tang
#
# 8
# Lee JiahuiLevel 5. Geniu
#
# 5
# Chen ZhirongLevel 4. Prodig
#
# 4
# Nicholes Wong
#
# 6
# Dwivid SharmaLevel 3. WonderkidUpdated on 07 Jun 2019I follow the golden rule of Warren Buffet that "Never put all eggs in one basket". That's why I would love to suggest you to put 5k in capital gains and 5k in dividend paying investment.Moreover you can also try for REIT's
#
# 3
# Hao Yu08 Sep 2018Hi Dwivid
#
#
# Nicholes WongLevel 6. Maste
#
# 6
# Eric Chia
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Dwivid SharmaLevel 3. Wonderki
#
# 3
# Rave Ong Ci DeLevel 5. Geniu
#
# 5
# Kenneth Lou
#
# 8
# Soh Sing Heng
#
# 4
# Soh Sing Heng
#
# 4
# Jen Kho11 Sep 2018Know stocks return and SSB then add up together to get that year return?
#
#
# Soh Sing Heng
#
# 4
# Gabriel Tham
#
# 8
# Soh Sing HengLevel 4. Prodig
#
# 4
# Kenichi Xi
#
# 6
# Junda HuangLevel 2. Rooki
#
# 2
# Hariz Arthur Maloy
#
# 9
# Kevin HoLevel 2. Rooki
#
# 2
# Kenneth Lou
#
# 8
# Ck ChaiLevel 4. Prodig
#
# 4
# Gabriel LeeLevel 6. Maste
#
# 6
# Soh Sing Heng
#
# 4
# Soh Sing Heng
#
# 4
# Soh Sing Heng
#
# 4
# Soh Sing Heng
#
# 4
# Kenneth Lou
#
# 8
# Junus EuTop Contributor (Sep)Level 8. WizardUpdated on 30 May 2019Gosh
#
# 8
# Anant ShivaLevel 2. RookieUpdated on 07 Jun 2019Your money needs to earn 5% annually to hit $375K
#
# 2
# Leong Wen Fong03 Oct 2018What's your experience with Autowealth? Is it a good platform to us
#
#
# Chen QijianLevel 3. Wonderki
#
# 3
# Gabriel Tham
#
# 8
# Leong Wen Fong11 Sep 2018I guess if he invests the wait can be shortened by about a year?Gabriel Tham11 Sep 2018depends what is the rate of return. And investment also carry risk of loss unless is FD or S
#
#
# Jay Liu
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Kenichi Xi
#
# 6
# Yeap Ming Feng
#
# 5
# Teo See Hwa
#
# 3
# Kenneth Lou03 Oct 2018Hi there Teo See Hwa
#
#
# Soh Sing Heng
#
# 4
# Kenneth Lou11 Sep 2018Would also add that it could be good to listen to audiobooks! For me
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Kenichi Xi
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Ck ChaiLevel 4. Prodig
#
# 4
# Jeff Yeo
#
# 6
# HC Tang
#
# 8
# Leong Wen FongLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Isabella JoLevel 4. Prodig
#
# 4
# Teresa WuLevel 3. Wonderki
#
# 3
# Soh Sing Heng
#
# 4
# Soh Sing Heng
#
# 4
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Ashley Wong
#
# 4
# Sarah Chan
#
# 6
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Zann ChuaLevel 6. Maste
#
# 6
# Ashley Wong
#
# 4
# Donald Kieran Ang03 Apr 2019Can't do monthly investment by byying ETFs yourself through brokers unlike regular top ups to robo advisors righ
#
#
# Isaac ChanLevel 8. WizardUpdated on 07 Jun 2019In essence
#
# 8
# Alex Chua Cheng En23 Feb 2019Based on circular flow of income
#
#
# Nicholes Wong
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Rich TylerLevel 2. RookieUpdated on 11 Apr 2019Hi Ang
#
# 2
# Victor Chng
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Ang Yee Gary17 Feb 2019Does not help as this is overall returns. Not yearly returns and does not account for increase or decrease in portfolio amount.Ang Yee Gary17 Feb 2019https://www.fundcount.com/portfolio-accounting?gclid=CjwKCAiAqaTjBRAdEiwAOdx9xnoeObuOQTwHLa9gqct0cggydZca-cIQl9SD4-KSkv6C8iA0IjYQfBoC5DoQAvD_B
#
#
# Isaac Chan
#
# 8
# Thaddeus Tan10 Apr 2019Solid use of graphics
#
#
# Terence Tan
#
# 3
# Victor Chng
#
# 4
# HC Tang
#
# 8
# Victor Chng
#
# 4
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Jon LimLevel 2. RookieUpdated on 07 Jun 2019Leverage is GOOD.Investors use leverage (borrow others' money) to make more money.Platforms use leverage (their members' time & insights) to generate content & views for their Search Engine Optimization & selling ads.Are tall buildings bad? No. but people climb on top of tall buildings & jump off.1 commen
#
# 2
# Kenneth Lou21 Feb 2019Wow! Really love that analogy. "Are tall buildings bad? No. but people climb on top of tall buildings & jump off
#
#
# Loh Tat Tian
#
# 6
# See all 3 comments Loh Tat Tian21 Feb 2019Woah. I have a figment of reading it before. But you brought the article out. NiceHC Tang21 Feb 2019:D I heard that during Dr.Wealth preview class. So literally Leverage is as you've shared
#
#
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Hariz Arthur Maloy
#
# 9
# Lee JiahuiLevel 5. Geniu
#
# 5
# Zann ChuaLevel 6. MasterUpdated on 07 Jun 2019Hello! Some of the available places to invest are SSB
#
# 6
# He Jian Hong22 Feb 2019FSM - MAPS also considered robo righ
#
#
# Victor Chng
#
# 4
# Kenneth Lou21 Feb 2019For example STI ETF!Victor Chng21 Feb 2019and Hang Seng ETF
#
#
# Gabriel Tham
#
# 8
# Nicholes Wong
#
# 6
# Cheng You Yi
#
# 3
# Luke Ho27 Feb 2019Concise and well explained. Well don
#
#
# Kishor BhagwatLevel 4. Prodig
#
# 4
# Victor Chng
#
# 4
# Loh Tat Tian
#
# 6
# Isaac Chan
#
# 8
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Kishor BhagwatLevel 4. Prodig
#
# 4
# Richard Woon Tian JunLevel 6. MasterUpdated on 01 Mar 2019There are basically 2 types of risk - systematic and unsystematic risk. Systematic risk is known as the market risk
#
# 6
# Isaac Chan
#
# 8
# Zann ChuaLevel 6. Maste
#
# 6
# Isaac ChanLevel 8. Wizar
#
# 8
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Hariz Arthur Maloy
#
# 9
# Victor Chng
#
# 4
# Isaac ChanLevel 8. Wizar
#
# 8
# Leonard TanLevel 6. MasterUpdated on 20 Feb 2019P/E ratio is one of the most commonly used ratios for assessing company's stock against its EPS- popularised due to its ease of calculation. Ultimately every investor wishes for his invested company to grow its earnings. Though a high P/E ratio might signal a stock is overvalued
#
# 6
# Zann ChuaLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Lok Yang TengLevel 6. Maste
#
# 6
# Leonard TanLevel 6. MasterUpdated on 19 Feb 2019Breaking it downTechnical AnalysisRelies on historical market data- price and volumeRecord past price patterns in pictures
#
# 6
# Gabriel Tham
#
# 8
# Victor Chng
#
# 4
# Isaac ChanLevel 8. Wizar
#
# 8
# Loh Tat Tian
#
# 6
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Glenn Ong21 Feb 2019Which companies do you currently invest in there?Victor Chng21 Feb 2019Hi
#
#
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Luke Ho
#
# 6
# HC Tang
#
# 8
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Luke Ho
#
# 6
# Victor Chng
#
# 4
# Terence Tan22 Feb 2019Are they all from different countrie
#
#
# Jonathan Chia Guangrong
#
# 6
# See all 5 comments Jonathan Chia Guangrong22 Feb 2019No right or wrong. As long as you are comfortable with the returns and risk aspect of your investments. Terence Tan25 Feb 2019True! Congrat
#
#
# Gabriel Tham
#
# 8
# See all 3 comments Gabriel Tham21 Feb 2019Vanguard world index etf
#
#
# Victor Chng
#
# 4
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Isaac ChanLevel 8. Wizar
#
# 8
# Isaac ChanLevel 8. Wizar
#
# 8
# Terence Tan
#
# 3
# Victor Chng
#
# 4
# Victor Chng
#
# 4
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Ryuichi LionHeart21 Feb 2019Noted! Thank you so much!
#
#
# Ericsson TingLevel 3. Wonderki
#
# 3
# Gabriel Tham
#
# 8
# Ryuichi LionHeart21 Feb 2019Alrighty! Thank you! Shall continue with Ssb
#
#
# Victor Chng
#
# 4
# Sandra TeoLevel 6. MasterUpdated on 20 Feb 2019The reason behind the drop in stock price can be attributed to the new dividend policy (cut from current 16% per ordinary share
#
# 6
# Victor Chng
#
# 4
# Isaac ChanLevel 8. Wizar
#
# 8
# Zann ChuaLevel 6. Maste
#
# 6
# Sandra TeoLevel 6. MasterUpdated on 21 Feb 2019Hello! Typically
#
# 6
# Victor Chng
#
# 4
# Lok Yang TengLevel 6. MasterUpdated on 19 Feb 2019This is true up till the beginning of this century. If you compare the graph of gold and other major indices
#
# 6
# Victor Chng
#
# 4
# Zann ChuaLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. MasterUpdated on 19 Feb 2019It depends on what kind of investor you are. Small sum monthly is more ideal for most of us since it prevents impulse buying/selling. Cost per unit will average out over time. For the more seasoned invesor/technical anaylst
#
# 6
# DeleteEditKenneth LouLevel 8. WizardUpdated 3w agoUpdate: I just saw this in my Revolut email (7 October)!Looks like they are planning to do this as well here in SG:As someone who has been pretty active on Revolut lately
#
# 8
# Brandon Chew3w agoI guess fundamentally
#
#
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Isaac ChanLevel 8. Wizar
#
# 8
# Victor Chng
#
# 4
# Ashley Wong
#
# 4
# Zann ChuaLevel 6. Maste
#
# 6
# Leonard TanLevel 6. MasterUpdated on 20 Feb 2019SG's main spending- our defence budget has risen to 30%. I would say look towards ST Electronics(parent company of ST Kinetics-which makes weapons for SAF)Merdeka Generation Package- albeit a policy largely similar to Pioneer Generation Package and some would say a pre-election bolster. I would say look at sectors that are to benefit from the increasing ageing population care and service- hospitals
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Victor Chng
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Victor Chng
#
# 4
# Leonard TanLevel 6. MasterUpdated on 20 Feb 2019With recent headlines on progression of discussion talks between US & China
#
# 6
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Leonard TanLevel 6. MasterUpdated on 20 Feb 2019Most individuals will scale back on their risk appetites as the grow older. With increased expected spending in shorter term than longer term horizons
#
# 6
# Sandra TeoLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# See all 4 comments Question Poster19 Feb 2019Thanks a lot. really appreciate...The last query: for example: Schroder asian growth fund mention about Annual Management Fee as 1.125%. Is trailer fee included in AMF  or thats on top of this AMF?Hariz Arthur Maloy19 Feb 2019Included. :
#
#
# Victor Chng
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Ang Yee Gary17 Feb 2019It does not offer options on hk market
#
#
# Yixiong ChangLevel 5. GeniusUpdated on 07 Jun 2019try Interactive brokers.4 comment
#
# 5
# See all 4 comments Ang Yee Gary18 Feb 2019It also has 0.12 percent annual feesYixiong Chang18 Feb 2019Oh
#
#
# Lok Yang TengLevel 6. MasterUpdated on 17 Feb 2019The article assumes appreciation of 5% which can be achievable through stocks in most markets up to the near future. It is rather uncertain how growth rates will be 10-15 years down the road though.0 comment
#
# 6
# Victor Chng
#
# 4
# See all 3 comments Victor Chng20 Feb 2019Personally
#
#
# Nicholes Wong
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Victor Chng
#
# 4
# Leonard Tan18 Feb 2019Hey Victor just curious- are you a believer of efficient-markets hypothesis? If so how do you usually determine a good time to buy in? Eg. after a major selloff
#
#
# Victor Chng
#
# 4
# Reagan Goh
#
# 1
# Gabriel Tham
#
# 8
# Victor Chng
#
# 4
# Yixiong ChangLevel 5. GeniusUpdated on 16 Feb 2019The OA will not decrease. 2.5% is the legislated minimum rate. The rate will be the legislated min or the 3-month local bank interest rate whichever is higher. I do not see the local bank rates will ever exceed 2.5% barring extreme situation. Take note the rate is based on interets rate local bank pay depositers
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Bryant TanLevel 3. Wonderki
#
# 3
# Brandan Chen
#
# 6
# Victor Chng
#
# 4
# Brandan Chen22 Feb 2019May i know why S$500? Have you considered the family's situation before providing such a number of at least S$500?
#
#
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Yixiong ChangLevel 5. GeniusUpdated on 17 Feb 2019Quote " Total Guaranteed Minimum Interest of 11%* of the Principal Amount over 6 years (equivalent to an effective interest rate of 1.84364% _a year)". _This is worst case scenario.The best case scenario (fulfills all requirements) pays extra bonus
#
# 5
# HC Tang
#
# 8
# Victor Chng
#
# 4
# Question Poster21 Feb 2019Hi
#
#
# Nicholes Wong
#
# 6
# Question Poster18 Feb 2019I see. Thanks for your advice! Will read up more before starting out
#
#
# Daniel ChooLevel 1. FreshieUpdated on 07 Jun 2019I think this answers your question on the cash upfront brokerage account.https://seedly.sg/questions/what-is-the-difference-between-dbs-vickers-cash-account-online-and-cash-upfront-account1 commen
#
# 1
# Question Poster18 Feb 2019Thank you for linking the post
#
#
# Victor Chng
#
# 4
# Terence Tan
#
# 3
# Victor Chng
#
# 4
# Zann ChuaLevel 6. Maste
#
# 6
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# DeleteEditKenneth LouLevel 8. Wizar
#
# 8
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Kenneth LouLevel 8. Wizar
#
# 8
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Nicholes Wong
#
# 6
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Victor Chng
#
# 4
# Sandra TeoLevel 6. MasterUpdated on 19 Feb 2019Here's a quick brief on IREIT Global!Successful refinanced bank borrowings.Interest costs reduced by 15%. Concurrent with the debt drawdown
#
# 6
# Sandra TeoLevel 6. Maste
#
# 6
# Richard Woon Tian JunLevel 6. MasterUpdated on 18 Feb 2019Hi
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Luke Ho
#
# 6
# Victor Chng
#
# 4
# Zlao XieLevel 1. Freshi
#
# 1
# Nicholes Wong
#
# 6
# Gabriel Tham
#
# 8
# Kenneth Lou15 Feb 2019Really shag market indeed... tough to survive and thrive as Telcos in today's worl
#
#
# Victor Chng
#
# 4
# Leonard TanLevel 6. MasterUpdated on 15 Feb 2019Looking macro level at the big 3(Singtel
#
# 6
# Kenneth Lou
#
# 8
# Nicholes Wong
#
# 6
# Hariz Arthur Maloy18 Feb 2019And liquid!
#
#
# Zann ChuaLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Zann ChuaLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Victor Chng
#
# 4
# Terence Tan
#
# 3
# Sandra TeoLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Isaac ChanLevel 8. WizardUpdated on 21 Feb 2019There are multiple ways that you can value a company's stocks. The "trading comparables" (or short for comps) approach is one of the most commonly used methods that Sandra has mentioned.To add to her point
#
# 8
# Victor Chng
#
# 4
# Isaac ChanLevel 8. WizardUpdated on 21 Feb 2019The entrace of Grab and GoJek has certainly made the business environment way more competitive. However
#
# 8
# Isaac ChanLevel 8. WizardUpdated on 21 Feb 2019Hi!I would pay attention to a company's cashflows. I believe that cashflow is king for any company and it is the main driver of value in a company. I will probably focus my attention on a company's cashflow statements
#
# 8
# Zann ChuaLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Ashley Wong
#
# 4
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Zann ChuaLevel 6. Maste
#
# 6
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Aik KaiLevel 6. MasterUpdated on 01 Aug 2019Just get the Krisflyer AMEX first for their sign up bonus.After which
#
# 6
# Valentina Tan01 Aug 2019Hi
#
#
# Jeff Yeo
#
# 6
# Png Cheng Xi Damien
#
# 4
# Sa RahLevel 1. Freshi
#
# 1
# Chupeng DaiLevel 2. Rooki
#
# 2
# Aik KaiLevel 6. Maste
#
# 6
# Kenneth Lou
#
# 8
# Question Poster08 Nov 2018Hi Kenneth! Thanks for answering my question. But when I start spending on my Amex card
#
#
# Aik KaiLevel 6. Maste
#
# 6
# Gabriel ThamLevel 8. Wizar
#
# 8
# Xin YingLevel 2. Rooki
#
# 2
# Brandan ChenLevel 6. Maste
#
# 6
# Isaac Chan
#
# 8
# Leonard TanLevel 6. Maste
#
# 6
# Clarence Chua
#
# 7
# Ang Yee Gary
#
# 4
# Gabriel Tham
#
# 8
# Chin Guo QiangLevel 3. Wonderki
#
# 3
# Hariz Arthur Maloy
#
# 9
# Elijah Lee
#
# 9
# Zeal OngLevel 2. Rooki
#
# 2
# See all 3 comments T@Takingstock @3w agoI like these comments. Harvey
#
#
# Loh Tat Tian
#
# 6
# Cedric Jamie Soh
#
#
# Cedric Jamie Soh
#
#
# Question Poster3w agoThat’s what I wanted to know.  Any good recommendations? A few extra thousands would be great for putting that amou
#
#
# Cedric Jamie Soh
#
#
# Kelly Trinh4w agoI was hoping to avoid the TT route
#
#
# Cedric Jamie Soh
#
#
# Cedric Jamie Soh
#
#
# Kenneth Lou
#
# 8
# SWShaun Wq Lim03 Sep 2019Ok that’s good! Don’t want to lose the old dataKenneth Lou03 Sep 2019Thank You! and yes! let me know if you have any problems with this method
#
#
# Kenneth Lou
#
# 8
# AAAmi Atm02 Sep 2019Yes that works out. transaction get duplicated though.Kenneth Lou03 Sep 2019Hey Ami! Yes there will be some which will become duplicated. U will have to manually go to the transaction list and remove each of the
#
#
# Loh Tat Tian
#
# 6
# Jay Liu
#
# 6
# Isabella JoLevel 4. Prodig
#
# 4
# Jeff Yeo
#
# 6
# ZeeeeeLevel 4. Prodig
#
# 4
# JianHao SooLevel 4. Prodig
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Kenneth Lou
#
# 8
# Ryan Tham30 Jun 2019Yupp! I too have 2 dbs account and one OCBC (credit card)
#
#
# Jonathan Ng
#
# 5
# Charmaine Ng
#
# 6
# Tan Wei MingLevel 5. Geniu
#
# 5
# Gabriel Tham
#
# 8
# Question Poster14 Jun 2019Hey
#
#
# Jacky YapLevel 4. Prodig
#
# 4
# Kenneth Lou
#
# 8
# HC Tang13 May 2019Thanks bro. Just in time :P ha
#
#
# HC Tang
#
# 8
# See all 4 comments HC Tang13 May 2019I'll ask seedly help to contact you...Kenneth Lou13 May 2019Thanks HC! Yup @Benn if you need help on the other banks
#
#
# Xinyi Lum
#
# 5
# Ang Yee Gary
#
# 4
# Gabriel Tham
#
# 8
# Gabriel Tham
#
# 8
# ALAndy Lee21 Apr 2019Consider developing Malaysia market
#
#
# Gabriel Tham
#
# 8
# FAFrenando Ansari03 Sep 2019Understandable
#
#
# Luke Ho
#
# 6
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Jasmine TsoiLevel 3. Wonderki
#
# 3
# Jay Liu
#
# 6
# HC Tang
#
# 8
# Nicholes WongLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Jessica Ann LeeLevel 4. Prodig
#
# 4
# Junus EuTop Contributor (Sep)Level 8. WizardUpdated on 04 Jun 2019The good news is
#
# 8
# Gabriel Tham
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Lok Yang TengLevel 6. MasterUpdated on 09 Feb 2019Select the transaction you wish to changeClick on the change icon at the top left corner (below the icon)Choose a suitable catergory under 'Expenses'and there you have it!0 comment
#
# 6
# Nicholes Wong
#
# 6
# Charmaine Lim XiaomeiLevel 4. ProdigyUpdated on 01 Feb 2019According to CIMB's website
#
# 4
# Nicholes Wong
#
# 6
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Adrian Goh Jun Wei
#
# 4
# Nicholes Wong
#
# 6
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# HC Tang
#
# 8
# Npm AdeleLevel 3. Wonderki
#
# 3
# Lok Yang TengLevel 6. Maste
#
# 6
# Jerry TanLevel 2. Rooki
#
# 2
# Gabriel LeeLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019I think it'll be helpful if you can provide info on how much you spend
#
# 6
# Question Poster19 Dec 2018Hi
#
#
# Gabriel LeeLevel 6. Maste
#
# 6
# Leong Wen Fong
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019You can look through the benefits here: https://theshutterwhale.com/blog/2016/2/4/a-guide-to-priority-banking-in-singapore if it interest you. If it doesn't
#
# 6
# Question Poster05 Dec 2018Thank you for the link! I read it up and apparently it requires me having cold hard cash of 250k which i am unable to do so.. So i decide to continue normal banking and work harder towards that goal now! On a side note.. what is the 175k not insured information that you are referring to? I cannot seem to find it..Lok Yang Teng05 Dec 2018Singapore Deposit Insurance (SDI) only insurers up to 75k in each bank account (up from 50k previously). In the unlikely event money is lost
#
#
# Yixiong ChangLevel 5. Geniu
#
# 5
# Yixiong ChangLevel 5. GeniusUpdated on 07 Nov 2018The required daily minimum to earn the base interest is $10k. You can open the account with zero dollars but for that month will not earn any interest as as long any of the day the daily balance is under 10k
#
# 5
# Kenneth LouLevel 8. Wizar
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Gerard Ong
#
# 4
# Nicholas ChanLevel 5. Geniu
#
# 5
# Gabriel Tham
#
# 8
# Good Day Every DayLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Jeff Yeo
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Nicholas Chan07 Oct 2018Are that sg banks that don't charge for over the counter usd deposits? Jonathan Chia Guangrong07 Oct 2018Dbs charges 1.5% for this service. Not sure about other bank
#
#
# Isabella JoLevel 4. Prodig
#
# 4
# Jay Liu
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Randall TanLevel 4. Prodig
#
# 4
# Gabriel ThamLevel 8. Wizar
#
# 8
# Daniel LeeLevel 3. WonderkidUpdated on 07 Jun 2019I second the opinion provided by Gabriel Tham. SSB is a good SAVINGS instrument for the following reasons.​1) it provides the interest rate of a 10 year bond 2) behaves like a saving accounts (withdrawal without penalty)3) $2 transaction cost allows for re-investment especially in an rising interest rate environment. This elimates any interest rate risk that you might encounter in the future. (for every $1
#
# 3
# Eric Chia18 Sep 2018Also agree with Gabriel and Daniel. Just adding on if you're not looking at SSB
#
#
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# HC Tang
#
# 8
# Esther Esther07 Feb 2019What's DCA? HC Tang07 Feb 2019Oh it stands for Dollar Cost Averaging. It means monthly invest a fix amount automatically via giro to the investment regardless of situations usually using regular savings plan account. Due to the nature of buying consistently regardless of higher or lower price
#
#
# Jay Liu
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Good Day Every DayLevel 6. Maste
#
# 6
# Isabella JoLevel 4. Prodig
#
# 4
# Jeff YeoLevel 6. Maste
#
# 6
# Luke HoLevel 6. Maste
#
# 6
# Eric Chia
#
# 4
# Kenneth Lou
#
# 8
# Isabella JoLevel 4. Prodig
#
# 4
# Eric Chia
#
# 4
# Steph YeoLevel 5. Geniu
#
# 5
# Randall TanLevel 4. Prodig
#
# 4
# Gabriel ThamLevel 8. Wizar
#
# 8
# Gabriel LeeLevel 6. Maste
#
# 6
# LBLeo Boon YeowLevel 1. Freshi
#
# 1
# Kenneth Lou
#
# 8
# Kalpesh08 Aug 2018Thanks a lot and appreciate you taking time to revert back... Cheers and have a great National Day week ahead!
#
# Kenneth Kalpesh08 Aug 2018Kenneth one more question.. Can seedly consume previous data of SB account & share dashboard
#
#
# Randall TanLevel 4. ProdigyUpdated on 11 Jul 2019Method 1: Seedly AppUse DBS Multiplier for Savings
#
# 4
# Jared Ho11 Jul 2019Hi there
#
#
# Amanda PhuaLevel 3. Wonderki
#
# 3
# Kenneth LouLevel 8. Wizar
#
# 8
# Ck ChaiLevel 4. ProdigyUpdated on 07 Jun 2019If your salary credit through POSB
#
# 4
# Zach Howe14 Jun 2018It seems that TS is mostly transferring the funds for his/ her Overseas bank to Singapore bank
#
#
# Ric Wang Poh PengLevel 2. Rooki
#
# 2
# Zi Song LimLevel 2. Rooki
#
# 2
# Kenneth LouLevel 8. Wizar
#
# 8
# Gabriel ThamLevel 8. Wizar
#
# 8
# Steph YeoLevel 5. Geniu
#
# 5
# Aik KaiLevel 6. Maste
#
# 6
# Gabriel ThamLevel 8. Wizar
#
# 8
# Cherie Julianne TanLevel 6. Maste
#
# 6
# YMYeap Ming FengLevel 5. Geniu
#
# 5
# Kenneth LouLevel 8. Wizar
#
# 8
# Elijah Lee
#
# 9
# Hariz Arthur Maloy
#
# 9
# Loh Tat Tian
#
# 6
# Kenneth Lou
#
# 8
# NENat E14 Sep 2019Ah I still can’t though! Will reach out to the support email w a screenshot. Thanks
#
#
# YCYewFong ChuaLevel 3. WonderkidUpdated on 12 Sep 2019Nope
#
# 3
# See all 3 comments YCYewFong Chua12 Sep 2019Logon using ocbc mobile app
#
#
# Han Jinyuan Larry
#
# 3
# Lu XinLevel 2. Rooki
#
# 2
# Gabriel Tham
#
# 8
# Cedric Jamie Soh
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Cedric Jamie Soh
#
#
# Ernest Yeam Wee LeongLevel 5. GeniusUpdated on 28 Aug 2019For DBS Credit card fees waiver is quite fast.Did it via iBanking and it was done within 3 days.Attached images for references.0 comment
#
# 5
# Aik KaiLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Loh Tat Tian
#
# 6
# Question Poster06 Jan 2019actually may i ask what benefits do UOB one card carry? only cash rebates that's all? not sure if going through all the hassle is worth it for this credit cardLoh Tat Tian06 Jan 2019If you are able to automate payments of at least $500 to the card
#
#
# Yixiong ChangLevel 5. Geniu
#
# 5
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019POSB Save As You Earn (SAYE) gives you additional 2.0% interest rate for the first 2 years. Afterwards you can look at OCBC 360
#
# 6
# Question Poster04 Dec 2018Do you mean I shouldn't go for the 1.85% of DBS Multiplier? I heard SAYE have lock-in period which is a turn off for meLok Yang Teng05 Dec 2018You can go for both actually. SAYE is a second account which debits certain amount from your main account. The X amount is then locked in for 2 years monthl
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Yong Kah HweeLevel 6. Maste
#
# 6
# HC Tang
#
# 8
# Nicholes Wong
#
# 6
# Aik KaiLevel 6. Maste
#
# 6
# Charmaine NgLevel 6. Maste
#
# 6
# Gabriel ThamLevel 8. WizardUpdated on 15 Sep 2018Very simply put
#
# 8
# Brandan ChenLevel 6. Maste
#
# 6
# Anthony OngLevel 3. Wonderki
#
# 3
# Chris ChinLevel 4. Prodig
#
# 4
# Joyce Chan
#
# 3
# Aik KaiLevel 6. MasterUpdated on 03 Aug 2019Call in and ask the CSO to direct you to their fraud team. Then they can investigate for you. Alternatively
#
# 6
# Raymond Koh02 Aug 2019Thanks for your response! However
#
#
# Kenneth LouLevel 8. Wizar
#
# 8
# Jeff Yeo
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Jonathan Chia Guangrong
#
# 6
# HC Tang
#
# 8
# Jeff Yeo
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Kenneth LouLevel 8. Wizar
#
# 8
# Isabella JoLevel 4. Prodig
#
# 4
# Good Day Every DayLevel 6. Maste
#
# 6
# Ordinary YcLevel 1. FreshieUpdated on 21 Mar 2019I believe you are using UOB one account. This question is subjective
#
# 1
# Yinghua LiuLevel 4. Prodig
#
# 4
# Nicholes Wong
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Joyce Chan
#
# 3
# Tee-Ming Chew
#
# 6
# Question Poster18 Aug 2019Hello
#
#
# AmkaesLevel 2. Rooki
#
# 2
# Huang Yixuan
#
# 6
# Ginny YunLevel 1. Freshi
#
# 1
# XYXue Yi HangLevel 2. Rooki
#
# 2
# Chris TangLevel 1. Freshi
#
# 1
# Gabriel Tham
#
# 8
# Eugene WeeLevel 3. WonderkidUpdated on 03 Sep 2019No
#
# 3
# See all 3 comments JWjiajing wang03 Sep 2019If u are referring to the multiplier interest rate... Yes
#
#
# SKShabir KhanLevel 4. ProdigyUpdated on 18 Mar 2019You could try DBS Regular Savings Plan
#
# 4
# JJefremy Level 3. Wonderki
#
# 3
# Kdz2w agoYou may want to explore Brunei market too
#
#
# Fan ZDLevel 3. Wonderki
#
# 3
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019I'm guessing that 3k for equities
#
# 6
# Question Poster15 Nov 2018Yep
#
#
# Nicholes Wong
#
# 6
# Luke Ho
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Junus EuTop Contributor (Sep)Level 8. WizardUpdated on 25 Aug 2019With Citi Maxigain for a year now and it's my favourite no-frills account! I parked a low six-figure there and have been enjoying the step-up interest that has been coming in. Have not touched it at all but I do see the statements coming in monthly.The main change that has come in last December is that the minimum daily ending balance of $70
#
# 8
# John Smith25 Aug 2019So just park $70k & don’t touch it. What is the interest like ? ThanksJunus Eu25 Aug 2019Most accurate info would be straight from the source: https://www.citibank.com.sg/gcb/deposits/mxgn-savacc.h
#
#
# Isabella JoLevel 4. Prodig
#
# 4
# Clarence Chua
#
# 7
# See all 3 comments Clarence Chua18 Jun 2019While in army I don’t use a %
#
#
# Seh Xiong ChongLevel 4. Prodig
#
# 4
# Thaddeus Tan
#
# 6
# Question Poster18 Jun 2019How much of my salary would you advise me to keep aside for savings and how much for spending expenditure?
#
# Also could you elaborate more on RSP if you don’t mind? I don’t like venturing into stuff I’m not very sure of just like investing.Thaddeus Tan19 Jun 2019Hi anon
#
#
# TWTay WenHaoLevel 4. ProdigyUpdated on 18 Jun 2019Hey i guess Clarence have covered most of the points and its damn good points and it works. Just to add on
#
# 4
# Question Poster18 Jun 2019I don’t club or drink so I guess that’s good. Don’t even smoke.
#
# Yes I’m an SCT currently
#
#
# SKShabir Khan
#
# 4
# Gabriel Tham
#
# 8
# Sim Min XuanLevel 3. WonderkidUpdated on 22 Jun 2019Hello there! you might want to set 40% of your income to go to a savings account to park it in there - make your money work for you and earn that sweet interest! i recommend CIMB fast saver as you get 1% interest rate with no strings attached. best of all
#
# 3
# Wilson WilsonLevel 2. Rooki
#
# 2
# Thaddeus Tan
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Colin LimLevel 3. WonderkidUpdated on 07 Jun 2019rbs for sme1 commen
#
# 3
# Kenichi Xi28 Sep 2018Do
#
#
# Gabriel Tham
#
# 8
# Hariz Arthur Maloy
#
# 9
# HC Tang
#
# 8
# Gabriel Tham
#
# 8
# Tan Boon HianLevel 1. FreshieUpdated on 07 Jun 2019I tried creating one joint savings account with my girlfriend a few months and apparently the bank told us that we need to have the same resident address to be able to open a joint savings account.. Do take note2 comment
#
# 1
# Question Poster04 Oct 2018Hmm CIMB don't need to i think for me and my bf we have no issue with this :) Tan Boon Hian13 Oct 2018I see
#
#
# Nicholas ChanLevel 5. Geniu
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Ck ChaiLevel 4. Prodig
#
# 4
# Gabriel LeeLevel 6. MasterUpdated on 12 Jun 2019Hey
#
# 6
# Fan ZD12 Jun 2019Just a question - the remix account seems to have been converted. I only see a DBS Savings Plus on the portal. Does it still have the same benefit
#
#
# Gabriel Tham
#
# 8
# Eric Chia
#
# 4
# Gabriel ThamLevel 8. Wizar
#
# 8
# Eric ChiaLevel 1. Freshi
#
# 1
# Kenneth LouLevel 8. WizardUpdated on 17 Jul 2019Hey CS!​Unfortunately for now
#
# 8
# Stanley Teo17 Jul 2019😱 u got over the hurdle of integrating with the banks... but cannot allow export of data?
#
#
# Jay TeeLevel 3. Wonderki
#
# 3
# Hariz Arthur Maloy
#
# 9
# Tan Siak Lim
#
#
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Terence Tan
#
# 3
# Terence Tan
#
# 3
# Isaac Chan
#
# 8
# Josh Tan Jian Liang
#
#
# Lok Yang TengLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019Your CDP Securities account has to be linked to your bank account through direct crediting service (DCS) first. Afterwards then you can apply via ATM or internet banking.2 comment
#
# 6
# Question Poster15 Dec 2018How long will I receive the DCS letter after CDP approval? Lok Yang Teng16 Dec 2018You will receive a letter from SGX informing you on the final status of the application within 2 weeks from the application date (acceptance or rejectio
#
#
# Jonathan Chia Guangrong
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Loh Tat TianLevel 6. Maste
#
# 6
# Lee JiahuiLevel 5. Geniu
#
# 5
# Good Day Every DayLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Prakash KumaraswamiLevel 2. Rooki
#
# 2
# Kenneth Lou
#
# 8
# Jay Liu
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Cedric Jamie Soh
#
#
# Teo Liang WeiLevel 2. Rooki
#
# 2
# Gabriel Tham
#
# 8
# Prakash KumaraswamiLevel 2. Rooki
#
# 2
# Kenneth Lou
#
# 8
# Christopher Tan
#
# 6
# Cedric Jamie Soh
#
#
# Nicholas ChanLevel 5. Geniu
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Lee Chun KiatLevel 3. Wonderki
#
# 3
# Jonathan Chia Guangrong
#
# 6
# Jeff Yeo
#
# 6
# Hariz Arthur Maloy
#
# 9
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Jay Liu
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Gabriel LeeLevel 6. MasterUpdated on 07 Jun 2019Hey
#
# 6
# Ching Shy Lim20 Sep 2018Is US Etf subjected to tax?Gabriel Lee20 Sep 2018Yes
#
#
# Tan Wei MingLevel 5. Geniu
#
# 5
# Yong Kah HweeLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Jonathan Chia Guangrong
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Koh Jun HuiLevel 2. Rooki
#
# 2
# Yong Kah HweeLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Adrian Goh Jun Wei
#
# 4
# Jonathan Chia GuangrongLevel 6. Maste
#
# 6
# Bryan ChongLevel 3. Wonderki
#
# 3
# Png Cheng Xi Damien
#
# 4
# Gabriel LeeLevel 6. Maste
#
# 6
# Isabella JoLevel 4. Prodig
#
# 4
# Christopher HowLevel 4. ProdigyUpdated on 07 Jun 2019Can I just say that very few people (if any) in this community have experience handling this large sum of money. You're really better off speaking to wealth managers (not insurance agents
#
# 4
# See all 5 comments Christopher How19 Sep 2018If the truth is a cheap shot
#
#
# Lim Ren YingLevel 3. WonderkidUpdated on 07 Jun 2019some capital guaranteed options would be:​Singapore savings bonds
#
# 3
# Kenneth Lou19 Sep 2018Another very good answer
#
#
# Siti PutriLevel 5. GeniusUpdated on 07 Jun 2019I can understand your situation somewhat feeling lost not being sure whom to ask or seek advice from financially. Firstly ask yourself if you are genuinely keen to learn to invest because that in itself takes time
#
# 5
# Yi Fong Tan25 Sep 2018Second this!! "$14mil could last 3 generations without even investing since you seem to be very prudent in your lifestyl
#
#
# Elsa GohLevel 5. GeniusUpdated on 07 Jun 2019Edit: Have the estate matters been settled? I assume the moneys were left to you in UK. You may need to appoint a solicitor in the UK or a lawyer in Sg who is able to advise on UK estate law and tax liability. Big name law firms in Sg are Rajah & Tann
#
# 5
# Kenneth Lou19 Sep 2018I love this comment haha "If this is true... congratulations. Also
#
#
# Leck Ting YanLevel 2. RookieUpdated on 07 Jun 2019Please speak to a private banker. In fact
#
# 2
# Leong Wen Fong20 Sep 2018Good advice! Love the thought for the future generatio
#
#
# Gabriel Tham
#
# 8
# Kenichi Xi
#
# 6
# Tan YapShengLevel 2. RookieUpdated on 07 Jun 2019Hi there
#
# 2
# Kenneth Lou19 Sep 2018That is pretty interesting... private placement programs! :
#
#
# Koh Jun HuiLevel 2. Rooki
#
# 2
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Amanda Ho
#
# 2
# Alvin Teo
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Nicholas ChanLevel 5. Geniu
#
# 5
# Jeff Yeo
#
# 6
# William Seah
#
# 3
# Jay Liu
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Nicholes Wong
#
# 6
# Samuel LimLevel 3. WonderkidUpdated on 14 May 2019Just remember this dictum when seeking advice: "Never ask the barber if you need a haircut".0 comment
#
# 3
# Andrew Fong
#
#
# Question Poster19 Nov 2018Hi Andrew
#
#
# Hariz Arthur Maloy
#
# 9
# Aik KaiLevel 6. Maste
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Randy ChaiLevel 4. ProdigyUpdated on 20 Jul 2019Hi Alcander!Taking the assumption that you're a student and thus
#
# 4
# Tan Wei MingLevel 5. GeniusUpdated on 16 Jun 2019Hi
#
# 5
# See all 5 comments Alcander Seow16 Jun 2019Do I need to buy insurance to get the guarantee from SDIC?Tan Wei Ming16 Jun 2019It is not a local bank. However
#
#
# Fan ZDLevel 3. WonderkidUpdated on 16 Jun 2019Seeing as you would have no regular income as a student
#
# 3
# See all 3 comments Fan ZD12 Jun 2019Quite safe. Covered by SDIC up to 75k too. Anyways
#
#
# PatLevel 4. ProdigyUpdated on 17 Jun 2019Hiya
#
# 4
# See all 3 comments Pat17 Jun 2019You can't withdraw fixed deposits during the period which you have placed it with them and you will get a fixed interest rate of 1.5-2.0% (based on current schemes). You can only place fresh funds with the bank for fixed deposits. Most banks require a min of 10/20k placement for the fixed deposits so only consider this option if you have sufficient savings. If not
#
#
# Hariz Arthur Maloy
#
# 9
# Gabriel Tham03 May 2019Haha dang...thought can hack..credit just spend $1 hack. Maybe can find a cheap plan
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Glenn Toh
#
#
# HC Tang
#
# 8
# See all 3 comments Kenneth Lou16 Dec 2018Thanks for sharing your experience too HC!HC Tang16 Dec 2018Thanks b
#
#
# Kenneth Lou
#
# 8
# ...
# 6
# Isaac Chan
#
# 8
# Richard Woon Tian JunLevel 6. MasterUpdated on 11 Apr 2019To be honest
#
# 6
# Goh Kah KiatLevel 4. Prodig
#
# 4
# DeleteEditElijah Lee
#
# 9
# Leslie KohLevel 4. ProdigyUpdated 1d agoBy contributing to SRS
#
# 4
# Kenneth Lou
#
# 8
# DeleteEditElijah Lee
#
# 9
# Leslie KohLevel 4. ProdigyUpdated 1d agoBy contributing to SRS
#
# 4
# Kenneth Lou
#
# 8
# Ashley Wong
#
# 4
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Billy Ko
#
# 6
# Terence Tan
#
# 3
# Wilson Nid A BreakLevel 4. Prodig
#
# 4
# Richard Woon Tian JunLevel 6. MasterUpdated on 07 Apr 2019Actually it depends on alot of factors
#
# 6
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Billy Ko
#
# 6
# Cherie Tan
#
# 4
# Hariz Arthur Maloy
#
# 9
# Hariz Arthur Maloy
#
# 9
# Kenneth Lou18 Oct 2018Solid sharing. (Y) interesting! Hariz Arthur Maloy18 Oct 2018;
#
#
# Luke Ho
#
# 6
# Question Poster15 Oct 2018Thank you for listing down. I was thinking of actually asking what kind of policies the government has and what it matches to? For example. Medisave
#
#
# Brandan Chen
#
# 6
# Hariz Arthur Maloy
#
# 9
# Gabriel LeeLevel 6. Maste
#
# 6
# Dawn FionaLevel 5. Geniu
#
# 5
# Luke HoLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Hariz Arthur Maloy
#
# 9
# Siow Nan
#
# 6
# T@Takingstock @Level 5. Geniu
#
# 5
# Loh Tat Tian
#
# 6
# Eric Chia
#
# 4
# Jonathan Chia Guangrong
#
# 6
# Hariz Arthur Maloy
#
# 9
# Nicholes Wong
#
# 6
# Christopher Tan
#
# 6
# Luke Ho
#
# 6
# Victor Chng
#
# 4
# Gabriel Tham
#
# 8
# Ashley Wong
#
# 4
# Nicholes Wong
#
# 6
# Vanessa Ann04 Apr 2019Thank you Nichol
#
#
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Gabriel Tham
#
# 8
# Terence Tan
#
# 2
# Luke Ho
#
# 6
# Richard Woon Tian JunLevel 6. MasterUpdated on 07 Jun 2019Wow
#
# 6
# See all 3 comments Kenneth Lou15 Mar 2019Oh wow this is intense. Anyway I remember that Business Law book very well! Ravi Chandran was a great professor.Kenneth Lou15 Mar 2019Lol I just read that last line: "It's cheaper than getting fined 50k and going to jail for 7 years
#
#
# Lee JiahuiLevel 5. GeniusUpdated on 15 Mar 2019Not just insider trading... If the information is still not known
#
# 5
# Anthony OngLevel 3. Wonderki
#
# 3
# Dereth TangLevel 2. Rooki
#
# 2
# Billy Ko
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Loh Tat TianLevel 6. MasterUpdated on 07 Jun 2019As their income is fluatuating (Self-employed)
#
# 6
# Gerard Ong22 Oct 2018I think the last 4 points should be non-deductible expenses :) Loh Tat Tian22 Oct 2018Ops. Correct let me edit it
#
#
# Elijah Lee
#
# 9
# Alvin Teo
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# JWjiajing wangLevel 3. Wonderki
#
# 3
# Gabriel Tham
#
# 8
# See all 3 comments Gabriel Tham06 Aug 2019Perhaps can find a hitch
#
#
# Bang HongLevel 4. Prodig
#
# 4
# Vincent Tan Wen Bin
#
# 5
# Loh Tat Tian
#
# 6
# Gabriel LeeLevel 6. Maste
#
# 6
# Tan Guan ChuanLevel 1. Freshi
#
# 1
# Tan Siak Lim
#
#
# Charmaine Lim XiaomeiLevel 4. ProdigyUpdated on 11 Oct 2018Hi Nicholas
#
# 4
# Josh Tan Jian Liang
#
#
# Ck ChaiLevel 4. Prodig
#
# 4
# Alvin Teo
#
# 4
# Siti PutriLevel 5. Geniu
#
# 5
# Brandan ChenLevel 6. Maste
#
# 6
# Clarence Chua
#
# 7
# KKimyesingLevel 1. Freshi
#
# 1
# PatLevel 4. Prodig
#
# 4
# Yong Kah HweeLevel 6. Maste
#
# 6
# T@Takingstock @Level 5. GeniusUpdated on 19 Jun 2019Actually I think the key is whether you are a traveller with more of time or more of money?If you are the former
#
# 5
# Sim Min XuanLevel 3. WonderkidUpdated on 21 Jun 2019try using shopback to earn cashback on your hotel and flight bookings! fairly easy website to navigate on
#
# 3
# MujimoroLevel 4. Prodig
#
# 4
# Ronald SzieLevel 4. Prodig
#
# 4
# Huang Yixuan
#
# 6
# BLBrian LeeLevel 3. Wonderki
#
# 3
# Jolene TanLevel 2. RookieUpdated on 27 Jun 2019I've done a 18 day Vietnam trip under 1k SGD before
#
# 2
# Javier Lim
#
# 5
# DeleteEditKenneth Lou
#
# 8
# Brandan Chen
#
# 6
# Victor Chng
#
# 4
# Hariz Arthur Maloy
#
# 9
# Robin LimLevel 2. Rooki
#
# 2
# Fox AroraLevel 1. Freshi
#
# 1
# Luke Ho
#
# 6
# Luke Ho
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Lok Yang TengLevel 6. Maste
#
# 6
# Sandra TeoLevel 6. MasterUpdated on 13 Mar 2019Hedge fund is a pooled investment structure set up by a money manager or registered investment advistor. The pooled investment structure is either a limited partnership or limited liability company. Hedge funds like mutual funds are pool of underlying securities. The hedge fund is operated by a manager who invests money into different assets to achieve the fund's goal. Depending on the objectives or goals
#
# 6
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Zann ChuaLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Zann ChuaLevel 6. MasterUpdated on 07 Jun 2019Hello! You can look at;1) AlphaIt is the measure of an invesment's performace on a risk-adjusted basis. the higher the alpha the better.2) BetaIt is a measure of volatility of a security or portfolio compared to the market as a whole.  Conservative investors who wish to preserve capital should focus on securities and fund portfolios with low betas while investors willing to take on more risk in search of higher returns should look for high beta investments. 3) R-squaredIt is a statistical measure that represents the percentage of a fund portfolio.  Mutual fund investors should avoid actively managed funds with high R-squared ratios
#
# 6
# Hariz Arthur Maloy10 Mar 2019Great answe
#
#
# Hariz Arthur Maloy
#
# 9
# Zann ChuaLevel 6. Maste
#
# 6
# Luke Ho
#
# 6
# Nicholes Wong
#
# 6
# Hariz Arthur Maloy
#
# 9
# Richard Woon Tian JunLevel 6. Maste
#
# 6
# DeleteEditHariz Arthur Maloy
#
# 9
# Hariz Arthur Maloy
#
# 9
# Hariz Arthur Maloy
#
# 9
# Jonathan Chia Guangrong
#
# 6
# Dominic ChangLevel 3. Wonderki
#
# 3
# Gabriel LeeLevel 6. Maste
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Jeff Yeo
#
# 6
# HC Tang
#
# 8
# Serene TohLevel 5. Geniu
#
# 5
# Kenneth LouLevel 8. Wizar
#
# 8
# PatLevel 4. ProdigyUpdated on 27 Jun 2019Yep it does.If you are looking at the quarterly cash rebate
#
# 4
# See all 3 comments Pat25 Jun 2019I'm not certain about OEM
#
#
# Jonathan Chia Guangrong
#
# 6
# Png Cheng Xi Damien
#
# 4
# Gabriel LeeLevel 6. Maste
#
# 6
# Jay Liu
#
# 6
# Gabriel Tham
#
# 8
# Jeff Yeo
#
# 6
# Yong Kah HweeLevel 6. Maste
#
# 6
# Timothy TanLevel 2. Rooki
#
# 2
# Lam Ka Ying3w agoHSBC will allow insurance paymen
#
#
# Tianshu DaiLevel 2. RookieUpdated on 07 Jun 2019Both cards have limits. My suggestion is to have both of them. For miles calculation. We usually didn't think about the spending block. Which UOB has the block in $5 and CITI is in $1. To simplest the usage. You can use CITI to pay any bill which under $20. And use UOB to pay the bill over $20. You can refer to this chart. And here's the formula if you need. UOB=INT(INT(amount/5)3.5)2
#
# 2
# See all 3 comments Tee-Ming Chew27 Mar 2019I got the UOB Priv Miles and didn’t know about the 2 years expiry. Thanks for the heads up!Wei Ling01 Jun 2019Can I check if online spending considered valid for CITI Mile Car
#
#
# Joel Tan Jun RongLevel 2. RookieUpdated on 07 Jun 2019It really depends on what your are looking out for. For earning rates
#
# 2
# Huang Yixuan27 Mar 2019Citibank has good sign up bonus! 30
#
#
# Aik KaiLevel 6. MasterUpdated on 07 Jun 2019Citi PM Visa. Miles don't expire
#
# 6
# Huang Yixuan06 Mar 2019Oooh I didn't know that
#
#
# Huang YixuanLevel 6. Maste
#
# 6
# Loo Cheng Chuan
#
# 6
# Hariz Arthur Maloy
#
# 9
# Tee-Ming ChewLevel 6. Maste
#
# 6
# Isaac Chan
#
# 8
# Leonard TanLevel 6. Maste
#
# 6
# Isaac Chan
#
# 8
# Isaac Chan
#
# 8
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Zann ChuaLevel 6. Maste
#
# 6
# Guo Hao Teo
#
# 4
# Luke Ho
#
# 6
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Isaac Chan
#
# 8
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Yeo Enk LouiLevel 6. Maste
#
# 6
# Isaac Chan
#
# 8
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Isaac Chan
#
# 8
# Lim Boon Tat
#
# 4
# Lok Yang TengLevel 6. Maste
#
# 6
# Lim Boon Tat
#
# 4
# See all 4 comments Kenneth Lou05 Apr 2019DeleteEditVery good and simple explanation. Thanks! On the concept of surge pricing hahaRichard Tang07 Apr 2019Every good way to explain value investing in an everyday excis
#
#
# Sandra TeoLevel 6. Maste
#
# 6
# Zann ChuaLevel 6. Maste
#
# 6
# Lin MLLevel 3. WonderkidUpdated on 16 Apr 2019The best way to think about value investing is to compare it with discounted shopping.There is a new Smart TV released in the market. As a shopper
#
# 3
# Chris Lee Susanto
#
# 2
# Ang Yee Gary
#
# 4
# Kevin Vincent27 Apr 2019I agree. Retirement savings not to be gambled . I find Non bank short term lending on First Mortgage with low LVRs at around 8-10% attractive. With 20% in Bank Term Deposits. But would love to buy into REITs and Index Funds after a crash. Trouble is when is this next one due
#
#
# SWShaun Wq LimLevel 4. Prodig
#
# 4
# Hariz Arthur Maloy
#
# 9
# Isaac Chan
#
# 8
# Isaac Chan
#
# 8
# Elijah LeeTop Contributor (Sep)Level 9. God of Wisdo
#
# 9
# Cedric Jamie Soh
#
#
# Jasmine Chye Fong YeeLevel 3. WonderkidUpdated on 16 Sep 2019Other than considering what you really want/need for your banquet
#
# 3
# Nurul Afiqah Binti LailiLevel 1. Freshi
#
# 1
# Chin Guo Qiang
#
# 3
# Loh Tat TianLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Kenneth Lou
#
# 8
# Nicholes Wong
#
# 6
# Yixiong ChangLevel 5. Geniu
#
# 5
# Jim NgLevel 5. GeniusUpdated on 07 Jun 2019In order to answer this question...need to find out more information from you.Who are your dependents? Or do you not have any dependents? Is your spouse working? Or not working? How many children do you have
#
# 5
# Question Poster12 Nov 2018Hi
#
#
# Loh Tat TianLevel 6. MasterUpdated on 13 Nov 2018From the way you described
#
# 6
# Brandan Chen
#
# 6
# Question Poster12 Nov 2018Hi
#
#
# Nicholes Wong
#
# 6
# Hariz Arthur Maloy
#
# 9
# Loh Tat TianLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Loh Tat Tian12 Nov 2018Even as an emergency fund
#
#
# Nicholes Wong
#
# 6
# Good Day Every DayLevel 6. Maste
#
# 6
# Jonathan Chia Guangrong
#
# 6
# Lim Chun Long Jimmy
#
# 5
# Boonhow EngLevel 3. WonderkidUpdated on 07 Jun 2019personally
#
# 3
# Carol Tham14 Nov 2018Agree with Boonhow & Hariz..
# Actually life insurance is meant for family. To help deal with situations where you might be permanently disabled and need the funds to pay medical or help with living expenses. Alternatively
#
#
# Josh Tan Jian LiangLevel 4. Prodig
#
# 4
# Yixiong ChangLevel 5. GeniusUpdated on 25 Jan 2019You should consider upgrading your basic plan to the preferred plan along with the assist rider. Having the option to go private care will be very important. I used to work in medical concierge in private and have several personal experience with public healthcare system. I must say timeliness and level of medical care is generally higher in private.Go for a term plan. You are already investing by yourself
#
# 5
# Brandan Chen
#
# 6
# Hariz Arthur Maloy
#
# 9
# Jacob Chong
#
# 3
# Good Day Every DayLevel 6. Maste
#
# 6
# Hariz Arthur Maloy
#
# 9
# Lim Wei Siang
#
# 2
# Yixiong ChangLevel 5. Geniu
#
# 5
# Jonathan Chia Guangrong
#
# 6
# Brandan Chen
#
# 6
# Christopher Tan
#
# 6
# Loh Tat Tian
#
# 6
# KAKelvin AngLevel 3. Wonderki
#
# 3
# Hariz Arthur Maloy
#
# 9
# Jacqueline YanLevel 4. ProdigyUpdated on 05 Sep 2019I was in a similar situation previously too!Unfortunately
#
# 4
# Question Poster05 Sep 2019Totally understand how you feel! But yes you brought up valid points which I’ll think about before making my decisio
#
#
# Jonathan Chia Guangrong
#
# 6
# Question Poster05 Sep 2019Thanks for your reply!
#
# I’m thinking of switching to a term plan (either with or without early CI). And for my endowment plans
#
#
# EEvelynLevel 3. WonderkidUpdated on 05 Sep 2019I’m in the same situation as you... just that mine is an ILP instead of a life insurance.Few things to consider
#
# 3
# Question Poster05 Sep 2019Ah looks like there are many people in the same situation! For me
#
#
# Javier Lim
#
# 5
# NNNicholas NbxLevel 2. RookieUpdated on 23 Aug 2019So far I saw YouTrip is specifically excluded from Citibank and UOB card. But it worked for Standard Chartered Unlimited Cashback. I've tried and gotten 1.5% cashback on all my YouTrip top-ups with that card
#
# 2
# Chin Guo QiangLevel 3. WonderkidUpdated on 09 Jun 2019I personally use DBS SAFRA Credit Card as with $500 credit card spending comes a basic 3% cashback rebates
#
# 3
# M Sim QY09 Jun 2019You sure topup Youtrip pays reward points?
# I checked with DBS. They said their cards do not pay out reward points/ miles for topup to Youtr
#
#
# NNNicholas NbxLevel 2. RookieUpdated on 23 Aug 2019So far I saw YouTrip is specifically excluded from Citibank and UOB card. But it worked for Standard Chartered Unlimited Cashback. I've tried and gotten 1.5% cashback on all my YouTrip top-ups with that card
#
# 2
# Clarence Chua
#
# 7
# BLBrian LeeLevel 3. Wonderki
#
# 3
# Charmaine Ng
#
# 6
# Alex WongLevel 3. Wonderki
#
# 3
# HC Tang
#
# 8
# Junus EuTop Contributor (Sep)Level 8. WizardUpdated on 11 Jun 2019Personally
#
# 8
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019If you're comparing by number of currencies either support
#
# 6
# Lam Ka Ying16 May 2019Personally prefers Youtrip which seems to have smaller margins for their exchange rates (you can check in the app for both accounts). Youtrip also does not charge foreign transaction fees for currencies outside of the listed 1
#
#
# Junus EuTop Contributor (Sep)Level 8. WizardUpdated on 24 Jun 2019Personally
#
# 8
# Png Cheng Xi Damien
#
# 4
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Kenneth Lou
#
# 8
# Kenneth Lou24 Oct 2018You can check out this person's profile also. He's been answering all the YouTrip Related questions as he is from the team itself! https://seedly.sg/profile/kelvin-7382704d-7c68-4094-bbbb-49fd3dc674
#
#
# Eng You GuanLevel 4. ProdigyUpdated on 07 Jun 2019So I'll just use USD as an example.As at 22/08/2018
#
# 4
# Kelvin Lam24 Aug 2018We are glad you like it. Please keep the comments coming in!
#
#
# Wilfred LingLevel 3. WonderkidUpdated on 07 Jun 2019I used the youtrip to purchase an item from Amazon. The currency USD/SGD conversion rate was even better than google rate! So I am quite happy with the card in terms of its currency exchange. I also received the promised $20 after I topped up my card. ​However
#
# 3
# Kelvin Lam24 Aug 2018Hey Wilfred - thanks for the comment! Am from YouTrip and if you don’t mind want to just do a quick response:
#
# 1. Name on card: We do know that this is not the best option for some
#
#
# Kenneth Lou
#
# 8
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Jefferson SohLevel 3. WonderkidUpdated on 07 Jun 2019Im answering this in the area of online shopping on taobao.  My usual drill is to use ratex
#
# 3
# Kelvin Lam28 Aug 2018Hey Jefferson
#
#
# Kelvin LamLevel 2. RookieUpdated on 07 Jun 2019(Disclaimer: Running YouTrip so please discout my comment if you see anything biased. But I only plan to make factual comments here for your reference)​Rate wise from our research so far we are very much on par with some of the most competitive money changer. I also see other comments in this post that our user have done the head to head comparison with money changer to show our rate is better. ​Bottom line is - compare. I run a financial comparison site before so I would always encourage user to compare the rate. There is no fee or obligation to sign up the product so it’s relatively straight forward (though you need to wait for your approval)
#
# 2
# Boon Chong Lau26 Aug 2018Hi Kelvin
#
#
# Pao J-weiLevel 1. FreshieUpdated on 30 Apr 2019Adding my short 2 cents on to the RateX versus Youtrip comparison :)Payments via RateX at Amazon will - on top of the FX savings - still award the cardholder with their bonus points/cashback
#
# 1
# Jeff Yeo
#
# 6
# Ng Wei En
#
# 4
# RyaN CheongLevel 2. Rooki
#
# 2
# Lok Yang TengLevel 6. MasterUpdated on 07 Jun 2019Comparing between YouTrip and Revolut free plan:Both are able to store and exchange in 10 different currencies now (24 for Revolut users in Europe). For Revolut
#
# 6
# Sarveen Chester16 Dec 2018For the free subscription
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Ng Wei En
#
# 4
# Kelly Trinh
#
# 3
# Pat2w agoUnder the new t&cs
#
#
# Leslie Koh
#
# 4
# RyaN CheongLevel 2. Rooki
#
# 2
# RyaN Cheong2w agoMy referral code for revolut:
# https://revolut.com/r/mingre0l
#
#
# Junus EuTop Contributor (Sep)Level 8. Wizar
#
# 8
# Ng Wei En
#
# 4
# Kelly Trinh
#
# 4
# Pat2w agoUnder the new t&cs
#
#
# Leslie Koh
#
# 4
# RyaN Cheong6h agoHi Leslie
#
#
# RyaN CheongLevel 2. Rooki
#
# 2
# RyaN Cheong2w agoMy referral code for revolut:
# https://revolut.com/r/mingre0l
#
#
# Lok Yang TengLevel 6. MasterUpdated on 16 Nov 2018YouTrip is an app designed for travellers to pay overseas with no fees in over 150 currencies. YouTrip supports conversion of 10 currencies (SGD
#
# 6
# Lava Ama A Dios
#
# 2

# %%
question_askers_df = pd.DataFrame(question_user_list,columns=["Names"])

# %%
question_askers_df
# Out:
#                  Names
# 0     Kuriakin J. Zeng
# 1            Anonymous
# 2            Anonymous
# 3            Anonymous
# 4            Anonymous
# ...                ...
# 8354         Xinyi Lum
# 8355         Anonymous
# 8356         Anonymous
# 8357         Anonymous
# 8358         Anonymous
#
# [8359 rows x 1 columns]

# %%
question_askers_df.nunique()
# Out:
# Names    462
# dtype: int64
