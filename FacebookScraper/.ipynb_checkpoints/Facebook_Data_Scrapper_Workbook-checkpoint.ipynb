# %% [markdown]
# # 1.1 Facebook Comments Scraper
# - Please update the following FINAL variables to indicate root data folder and user credentials
# - error_log.txt file needs to be created before hand within the root data folder
# - Additionally, please follow the folder structure below
#
# ```
# FacebookScraper/
# |-- Data/
# |   |-- DollarsAndSense/
# |   |-- MortgageConsultancy/
# |   |-- Seedly/
# |   |-- WokeManSalary/
# |   |   |-- comments/
# |   |   |   |-- WokeManSalary_comments_[xxx].csv
# |   |   |   |-- ...
# |   |   |   |-- ...
# |   |   |-- WokeManSalary_posts.csv
# |   |-- error_log.txt
# |-- Facebook_Comments.ipynb
# ```

# %%
# Declaration of FINAL Static variables
ROOT_DATA_FOLDER = './Data/' 
EMAIL = '' # <--- Change to own account when using
PASSWORD = '' # <--- Change to own password when using

# Declaration of Dynamic variables
page_list = [
    'DollarsAndSense',
    'MortgageConsultancy',
    'Seedly',
    'WokeManSalary'
]

# %%
from selenium import webdriver # allow launching browser
from selenium.webdriver.support.ui import WebDriverWait # allow waiting for page to load
from bs4 import BeautifulSoup # to parse HTML objects

import os
import csv
import time
import traceback
import datetime

# %%
driver_option = webdriver.ChromeOptions()
driver_option.add_argument('--headless')

# driver_option.add_argument('--incognito')
chromedriver_path = '/Users/alfaried/Google Drive/SMU - Y04S01/IS434 SA/Project/chromedriver' # <--- Change this to your own chromedriver path!

def create_webdriver():
    return webdriver.Chrome(executable_path=chromedriver_path, chrome_options=driver_option)

def login(driver, url):
    
    # Open the website
    driver.implicitly_wait(5)
    driver.get('https://mbasic.facebook.com' + url)

    # Clicks on "Log In" button
    root_element = driver.find_element_by_id('root')
    login_element = root_element.find_element_by_tag_name('a').click()
    time.sleep(1)

    # Input username
    username_input = driver.find_element_by_name("email")
    username_input.clear()
    username_input.send_keys(EMAIL)

    # Input password
    password_input = driver.find_element_by_name("pass")
    password_input.clear()
    password_input.send_keys(PASSWORD)

    # Logs into Facebook using dummy account
    driver.find_element_by_name("login").click()
    time.sleep(1)
    
    return driver

def get_comments_post(driver, comment_link):  
    comment_list = []
    
    # Get comments
    element = driver.find_element_by_xpath('//*[@id="ufi_' + comment_link.split('=')[1].split('&')[0] + '"]/div')

    comment_content_div = element.get_attribute('innerHTML')
    soup = BeautifulSoup(comment_content_div, 'html.parser')

    comment_chunk = soup.contents[-2]
    comments = comment_chunk.contents
    
    if comment_chunk.get('id') == None:         
        for comment in comments:
            try:             
                # Get comment ID
                comment_id = comment.get('id')
                
                # Get user and contents of comments
                tmp = comment.find_all('div')[1]
                
                comment_user = comment.find('h3').get_text()
                comment_date = comment.find('abbr').get_text()
                comment_text = tmp.get_text()
                
                user_tagging_list = []
                user_tagging_link_list = []
                
                user_taggings = tmp.find_all('a')
                for user_tagging in user_taggings:
                    user_tagging_list.append(user_tagging.get_text())
                    user_tagging_link_list.append(user_tagging['href'])
                
                comment_list.append({
                    'user': comment_user,
                    'text': comment_text,
                    'date': comment_date,
                    'id': comment_id,
                    'user_tagging': user_tagging_list,
                    'user_tagging_link': user_tagging_link_list
                })  

            except:
                # If there's a "View more comments..." link
                if 'see_next' in comment.get('id'):
                    driver.get('https://mbasic.facebook.com' + comment.find('a')['href'])

                    tmp_list = get_comments_post(driver, comment_link)

                    if tmp_list != []:
                        comment_list = comment_list + tmp_list
                        
                # Uncomment to print stacktrace
                # traceback.print_exc()

    return comment_list

def get_comments_photo_posts(driver, comment_link):
    comment_list = []
    
    # Get comments
    comment_element = driver.find_element_by_xpath('//*[@id="ufi_' + comment_link.split('/')[-1] + '"]')
    
    comment_content = comment_element.get_attribute('innerHTML')
    comment_soup = BeautifulSoup(comment_content, 'html.parser')
    
    comment_chunk = comment_soup.contents[0].contents[-2]
    
    if comment_chunk.get('id') == None:  
        comments = comment_chunk.contents

        for comment in comments:
            try:
                # Get comment ID
                comment_id = comment.get('id')
                
                # Get user and contents of comments
                tmp = comment.find_all('div')[1]
                
                comment_user = comment.find('h3').get_text()
                comment_date = comment.find('abbr').get_text()
                comment_text = tmp.get_text()
                user_tagging_list = []
                user_tagging_link_list = []
                
                user_taggings = tmp.find_all('a')
                for user_tagging in user_taggings:
                    user_tagging_list.append(user_tagging.get_text())
                    user_tagging_link_list.append(user_tagging['href'])
                
                comment_list.append({
                    'user': comment_user,
                    'text': comment_text,
                    'date': comment_date,
                    'id': comment_id,
                    'user_tagging': user_tagging_list,
                    'user_tagging_link': user_tagging_link_list
                }) 
                
            except:
                # If there's a "View more comments..." link
                if 'see_next' in comment.get('id'):
                    driver.get('https://mbasic.facebook.com' + comment.find('a')['href'])

                    tmp_list = get_comments_photo_posts(driver, comment_link)

                    if tmp_list != []:
                        comment_list = comment_list + tmp_list
                        
                # Uncomment to print stacktrace
                # traceback.print_exc()
                        
    return comment_list

def read_comments_urls_csv(filepath):   
    url_list = []
    print('Reading ' + filepath.split('/')[-1] + '...')
    print('')
    
    with open(filepath, mode='r') as csv_file:
        csv_reader = csv.reader(csv_file, delimiter=',')
        for row in csv_reader:
            if 'url' not in row[-1]:
                url_list.append(row[-1])
            
    return url_list

def write_comments_csv(filepath, comments_data):
    data_size = len(comments_data)
    
    if data_size == 0:
        print('No comments')
        print('')
        return
    
    print(str(data_size) + ' comment(s)')
    print('Writing ' + filepath.split('/')[-1] + '...')
    print('')

    with open(filepath, mode='w') as csv_file:
        csv_writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

        # Write Header
        csv_writer.writerow(['User', 'Comment', 'Date', 'Comment_ID', 'User_Tagging', 'User_Tagging_Link'])

        # Write Content
        for comment in comments_data:
            tmp = comment['date'].split(' ')
            dateTime = '/'.join(tmp[:2] + ['19']) + ' ' + tmp[-1]

            csv_writer.writerow([comment['user'], comment['text'],  dateTime, comment['id'], ', '.join(comment['user_tagging']), ', '.join(comment['user_tagging_link'])])
            
def write_errors(page, url):
    print('ERROR with URL: ' + url)
    print('Writing to error_log.txt...')
    print('')
    
    with open(ROOT_DATA_FOLDER + 'error_log.txt', mode='a') as csv_file:
        now = datetime.datetime.now()
        
        # Write Content
        csv_file.write('[' + str(now) + '] ERROR for ' + page + '. URL: ' + url + '\n\n')

# %%
for page in page_list:
    url_list = read_comments_urls_csv(ROOT_DATA_FOLDER + page + '/' +  page + '_posts.txt')
    comments_folder = ROOT_DATA_FOLDER + page + '/Comments/'
    
    # Loads files in comment folders
    comment_folder_files = os.listdir(comments_folder)

    for url in url_list: 
        post_id = url.split('=')[1].split('&')[0] if 'story' in url else url.split('/')[-1]
        comments_filename = page + '_comments_' + post_id + '.txt'
        
        # Checks if file comments already exists in folder. If TRUE, skips.
        if comments_filename in comment_folder_files:
            print(post_id + ' already scraped')
            print('Skipping...')
            print('')
            continue
        
        # STARTS scraping comments from posts here
        print('Retrieving comments from ' + url)
        comments_data = None  
        comments_filepath = comments_folder + comments_filename
        
        try:
            # Get webdriver Object
            driver = create_webdriver()

            # Log into Facebook
            driver = login(driver, url)
            
            # Retrieve comments
            if 'story' in url:            
                comments_data = get_comments_post(driver, url)            
            else:
                comments_data = get_comments_photo_posts(driver, url)
            
            # Writes to CSV file
            write_comments_csv(comments_filepath, comments_data)
            
        except:
            # Handles exceptions
            write_errors(page, url)
            
            # Uncomment to print stacktrace
            traceback.print_exc()
                
        finally:
            # Close the Webdriver
            driver.close()
        
    print('Scraping comments for ' + page + ' posts, done')
    print('')
# Out:
# Reading DollarsAndSense_posts.txt...
#
# Retrieving comments from /story.php?story_fbid=3182079765195405&id=386868888049854
# /Users/alfaried/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: use options instead of chrome_options
# No comments
#
# Retrieving comments from /story.php?story_fbid=3182609391809109&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3182609391809109.txt...
#
# Retrieving comments from /story.php?story_fbid=3180221452047903&id=386868888049854
# 15 comment(s)
# Writing DollarsAndSense_comments_3180221452047903.txt...
#
# Retrieving comments from /story.php?story_fbid=3179548878781827&id=386868888049854
# 3 comment(s)
# Writing DollarsAndSense_comments_3179548878781827.txt...
#
# Retrieving comments from /story.php?story_fbid=3179059135497468&id=386868888049854
# 2 comment(s)
# Writing DollarsAndSense_comments_3179059135497468.txt...
#
# Retrieving comments from /story.php?story_fbid=3175929855810396&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=3172813522788696&id=386868888049854
# 8 comment(s)
# Writing DollarsAndSense_comments_3172813522788696.txt...
#
# Retrieving comments from /story.php?story_fbid=3170083759728339&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=3169627359773979&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3169627359773979.txt...
#
# Retrieving comments from /story.php?story_fbid=3166908160045899&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3166908160045899.txt...
#
# Retrieving comments from /story.php?story_fbid=3166688096734572&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3166688096734572.txt...
#
# Retrieving comments from /story.php?story_fbid=3164494630287252&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3164494630287252.txt...
#
# Retrieving comments from /story.php?story_fbid=3163912817012100&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3163912817012100.txt...
#
# Retrieving comments from /story.php?story_fbid=3162719090464806&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3162719090464806.txt...
#
# Retrieving comments from /story.php?story_fbid=3160511200685595&id=386868888049854
# 2 comment(s)
# Writing DollarsAndSense_comments_3160511200685595.txt...
#
# Retrieving comments from /story.php?story_fbid=3159980177405364&id=386868888049854
# 4 comment(s)
# Writing DollarsAndSense_comments_3159980177405364.txt...
#
# Retrieving comments from /story.php?story_fbid=3159485557454826&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3159485557454826.txt...
#
# Retrieving comments from /story.php?story_fbid=3157610980975617&id=386868888049854
# 2 comment(s)
# Writing DollarsAndSense_comments_3157610980975617.txt...
#
# Retrieving comments from /story.php?story_fbid=3157102611026454&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_3157102611026454.txt...
#
# Retrieving comments from /story.php?story_fbid=3156592761077439&id=386868888049854
# 3 comment(s)
# Writing DollarsAndSense_comments_
id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2847909835279068&id=386868888049854
# 5 comment(s)
# Writing DollarsAndSense_comments_2847909835279068.txt...
#
# Retrieving comments from /story.php?story_fbid=2846156185454433&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_2846156185454433.txt...
#
# Retrieving comments from /story.php?story_fbid=2839866146083437&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2829448590458526&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2824673784269340&id=386868888049854
# 2 comment(s)
# Writing DollarsAndSense_comments_2824673784269340.txt...
#
# Retrieving comments from /story.php?story_fbid=2804313596305359&id=386868888049854
# 5 comment(s)
# Writing DollarsAndSense_comments_2804313596305359.txt...
#
# Retrieving comments from /story.php?story_fbid=2803449783058407&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2790822027654516&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_2790822027654516.txt...
#
# Retrieving comments from /story.php?story_fbid=2787085774694808&id=386868888049854
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.1697485630321500/2774662429270476
# 1 comment(s)
# Writing DollarsAndSense_comments_2774662429270476.txt...
#
# Retrieving comments from /story.php?story_fbid=2757485464321506&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2756601781076541&id=386868888049854
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.900467096690028/2751670081569711
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.1697485630321500/2746837705386282
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.1697485630321500/2744233652313354
# No comments
#
# Retrieving comments from /story.php?story_fbid=2739933819410004&id=386868888049854
# 1 comment(s)
# Writing DollarsAndSense_comments_2739933819410004.txt...
#
# Retrieving comments from /story.php?story_fbid=2739461912790528&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2716074348462618&id=386868888049854
# No comments
#
# Retrieving comments from /story.php?story_fbid=2704679339602119&id=386868888049854
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.900467096690028/2694911627245557
# No comments
#
# Retrieving comments from /DollarsAndSenseSG/photos/a.900467096690028/2688094337927286
# No comments
#
# Retrieving comments from /story.php?story_fbid=2678720115531375&id=386868888049854
# No comments
#
# Scraping comments for DollarsAndSense posts, done
#
# Reading MortgageConsultancy_posts.txt...
#
# Retrieving comments from /story.php?story_fbid=1461865070634761&id=409881809166431
# 2 comment(s)
# Writing MortgageConsultancy_comments_1461865070634761.txt...
#
# Retrieving comments from /story.php?story_fbid=1460832967404638&id=409881809166431
# 2 comment(s)
# Writing MortgageConsultancy_comments_1460832967404638.txt...
#
# Retrieving comments from /story.php?story_fbid=1460832650738003&id=409881809166431
# 2 comment(s)
# Writing MortgageConsultancy_comments_1460832650738003.txt...
#
# Retrieving comments from /story.php?story_fbid=1460832334071368&id=409881809166431
# 2 comment(s)
# Writing MortgageConsultancy_comments_1460832334071368.txt...
#
# Retrieving comments from /story.php?story_fbid=1460832000738068&id=409881809166431
# 2 comment(s)
# Writing MortgageConsultancy_comments_1460832000738068.txt...
#
# Retrieving comments from /story.php?story_fbid=1459002500921018&id=409881809166431
# 1 comment(s)
# Writing MortgageConsultancy_comments_1459002500921018.txt...
#
# Retrieving comments from /story.php?story_fbid=1456071034547498&id=409881809166431
# 3 comment(s)
# Writing MortgageConsultancy_comments_1456071034547498.txt...
#
# Retrieving comments from /story.php?story_fbid=1455447134609888&id=409881809166431
# 1 comment(s)
# Writing MortgageConsultancy_comments_
id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1168823256639040.txt...
#
# Retrieving comments from /story.php?story_fbid=1168776859977013&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1168776859977013.txt...
#
# Retrieving comments from /story.php?story_fbid=1168496793338353&id=460639650790741
# 3 comment(s)
# Writing Seedly_comments_1168496793338353.txt...
#
# Retrieving comments from /story.php?story_fbid=1167912943396738&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1167912943396738.txt...
#
# Retrieving comments from /story.php?story_fbid=1167460440108655&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1167460440108655.txt...
#
# Retrieving comments from /story.php?story_fbid=1167424566778909&id=460639650790741
# 6 comment(s)
# Writing Seedly_comments_1167424566778909.txt...
#
# Retrieving comments from /story.php?story_fbid=1167377006783665&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1167377006783665.txt...
#
# Retrieving comments from /story.php?story_fbid=1167277843460248&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1167277843460248.txt...
#
# Retrieving comments from /story.php?story_fbid=1167213870133312&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1167213870133312.txt...
#
# Retrieving comments from /story.php?story_fbid=1166753396846026&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1166753396846026.txt...
#
# Retrieving comments from /story.php?story_fbid=1166634833524549&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1166634833524549.txt...
#
# Retrieving comments from /story.php?story_fbid=1166066973581335&id=460639650790741
# 5 comment(s)
# Writing Seedly_comments_1166066973581335.txt...
#
# Retrieving comments from /story.php?story_fbid=1165911836930182&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1165911836930182.txt...
#
# Retrieving comments from /story.php?story_fbid=1165881340266565&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1165881340266565.txt...
#
# Retrieving comments from /story.php?story_fbid=1165800056941360&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1165800056941360.txt...
#
# Retrieving comments from /story.php?story_fbid=1165394693648563&id=460639650790741
# 3 comment(s)
# Writing Seedly_comments_1165394693648563.txt...
#
# Retrieving comments from /story.php?story_fbid=1165295960325103&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1165295960325103.txt...
#
# Retrieving comments from /story.php?story_fbid=1164573360397363&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1164573360397363.txt...
#
# Retrieving comments from /story.php?story_fbid=1161490320705667&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1161490320705667.txt...
#
# Retrieving comments from /story.php?story_fbid=1164000127121353&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1164000127121353.txt...
#
# Retrieving comments from /story.php?story_fbid=1163948443793188&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1163948443793188.txt...
#
# Retrieving comments from /story.php?story_fbid=1161479334040099&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1161479334040099.txt...
#
# Retrieving comments from /story.php?story_fbid=1163233120531387&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1163233120531387.txt...
#
# Retrieving comments from /story.php?story_fbid=1161431577378208&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1161431577378208.txt...
#
# Retrieving comments from /story.php?story_fbid=1162613237260042&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1162613237260042.txt...
#
# Retrieving comments from /story.php?story_fbid=1162343963953636&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1162066843981348&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1162066843981348.txt...
#
# Retrieving comments from /story.php?story_fbid=1161412244046808&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1161412244046808.txt...
#
# Retrieving comments from /story.php?story_fbid=1162057050648994&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1162057050648994.txt...
#
# Retrieving comments from /story.php?story_fbid=1161993997321966&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1161993997321966.txt...
#
# Retrieving comments from /story.php?story_fbid=1161356310719068&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1161356310719068.txt...
#
# Retrieving comments from /story.php?story_fbid=1161484624039570&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1161484624039570.txt...
#
# Retrieving comments from /story.php?story_fbid=1160885104099522&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160885104099522.txt...
#
# Retrieving comments from /story.php?story_fbid=1160903380764361&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160903380764361.txt...
#
# Retrieving comments from /story.php?story_fbid=1160894637431902&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160894637431902.txt...
#
# Retrieving comments from /story.php?story_fbid=1160809244107108&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160809244107108.txt...
#
# Retrieving comments from /story.php?story_fbid=1160203937500972&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160203937500972.txt...
#
# Retrieving comments from /story.php?story_fbid=1160235304164502&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1160235304164502.txt...
#
# Retrieving comments from /story.php?story_fbid=1160254687495897&id=460639650790741
# 5 comment(s)
# Writing Seedly_comments_1160254687495897.txt...
#
# Retrieving comments from /story.php?story_fbid=1160033284184704&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1160033284184704.txt...
#
# Retrieving comments from /story.php?story_fbid=1158204161034283&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1158204161034283.txt...
#
# Retrieving comments from /story.php?story_fbid=1159323407589025&id=460639650790741
# 3 comment(s)
# Writing Seedly_comments_1159323407589025.txt...
#
# Retrieving comments from /story.php?story_fbid=1156958221158877&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1156958221158877.txt...
#
# Retrieving comments from /story.php?story_fbid=1158459851008714&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1158459851008714.txt...
#
# Retrieving comments from /story.php?story_fbid=1158256251029074&id=460639650790741
# No comments
#
# Retrieving comments from /seedlysg/photos/a.470073689847337/1059294577591909
# No comments
#
# Retrieving comments from /story.php?story_fbid=1151270681727631&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1151270681727631.txt...
#
# Retrieving comments from /story.php?story_fbid=1151858381668861&id=460639650790741
# 4 comment(s)
# Writing Seedly_comments_1151858381668861.txt...
#
# Retrieving comments from /seedlysg/photos/a.470073689847337/1143479625840070
# No comments
#
# Retrieving comments from /story.php?story_fbid=1147978272056872&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1147978272056872.txt...
#
# Retrieving comments from /story.php?story_fbid=1147988975389135&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1147988975389135.txt...
#
# Retrieving comments from /story.php?story_fbid=1144072962447403&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1144072962447403.txt...
#
# Retrieving comments from /story.php?story_fbid=1129163433938356&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1140124126175620&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1138840162970683&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1138840162970683.txt...
#
# Retrieving comments from /story.php?story_fbid=1139482606239772&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1139482606239772.txt...
#
# Retrieving comments from /story.php?story_fbid=1127052104149489&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1123911424463557&id=460639650790741
# No comments
#
# Retrieving comments from /seedlysg/photos/a.470073689847337/1111985378989495
# No comments
#
# Retrieving comments from /story.php?story_fbid=1124054344449265&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1124054344449265.txt...
#
# Retrieving comments from /story.php?story_fbid=1123102804544419&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1123102804544419.txt...
#
# Retrieving comments from /story.php?story_fbid=1118949131626453&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1118949131626453.txt...
#
# Retrieving comments from /story.php?story_fbid=1116542788533754&id=460639650790741
# 2 comment(s)
# Writing Seedly_comments_1116542788533754.txt...
#
# Retrieving comments from /story.php?story_fbid=1098211503700216&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1085333371654696&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1085333371654696.txt...
#
# Retrieving comments from /story.php?story_fbid=1089244404596926&id=460639650790741
# 14 comment(s)
# Writing Seedly_comments_1089244404596926.txt...
#
# Retrieving comments from /story.php?story_fbid=1088459001342133&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1088459001342133.txt...
#
# Retrieving comments from /story.php?story_fbid=1085799938274706&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1085799938274706.txt...
#
# Retrieving comments from /story.php?story_fbid=1085330478321652&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_1085330478321652.txt...
#
# Retrieving comments from /story.php?story_fbid=1084141615107205&id=460639650790741
# No comments
#
# Retrieving comments from /story.php?story_fbid=1081657268688973&id=460639650790741
# 1 comment(s)
# Writing Seedly_comments_
# Writing WokeManSalary_comments_2330190213963152.txt...
#
# Retrieving comments from /story.php?story_fbid=2327315257583981&id=2250666538582187
# 9 comment(s)
# Writing WokeManSalary_comments_2327315257583981.txt...
#
# Retrieving comments from /story.php?story_fbid=2323000471348793&id=2250666538582187
# 25 comment(s)
# Writing WokeManSalary_comments_2323000471348793.txt...
#
# Retrieving comments from /story.php?story_fbid=2321421011506739&id=2250666538582187
# 31 comment(s)
# Writing WokeManSalary_comments_2321421011506739.txt...
#
# Retrieving comments from /story.php?story_fbid=2316039145378259&id=2250666538582187
# 223 comment(s)
# Writing WokeManSalary_comments_2316039145378259.txt...
#
# Retrieving comments from /story.php?story_fbid=2312592035722970&id=2250666538582187
# 1 comment(s)
# Writing WokeManSalary_comments_2312592035722970.txt...
#
# Retrieving comments from /story.php?story_fbid=2309429946039179&id=2250666538582187
# 50 comment(s)
# Writing WokeManSalary_comments_2309429946039179.txt...
#
# Retrieving comments from /story.php?story_fbid=2304176989897808&id=2250666538582187
# 16 comment(s)
# Writing WokeManSalary_comments_2304176989897808.txt...
#
# Retrieving comments from /story.php?story_fbid=2301789753469865&id=2250666538582187
# 50 comment(s)
# Writing WokeManSalary_comments_2301789753469865.txt...
#
# Scraping comments for WokeManSalary posts, done

# %% [markdown]
# # 1.2 Primary Analysis of Data

# %%
import csv
import pandas as pd

# %%
d = {'Post_ID':[], 'DateTime':[], 'Post_Content':[], 'Reactions':[], 'Likes':[], 'Ahah':[], 'Love':[], 'Wow':[], 'Sigh':[], 'Grrr':[], 'Url':[]}
filepath = ROOT_DATA_FOLDER + 'WokeManSalary/WokeManSalary_posts.txt'

with open(filepath, mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',') 

    # Get header row. Usually the top of the csv file
    headers = next(csv_reader)

    # Retreive index of the respective headers
    post_id_index = headers.index('post_id')
    date_index = headers.index('date')
    content_index = headers.index('text')
    total_reactions_index = headers.index('reactions')
    likes_index = headers.index('likes')
    haha_index = headers.index('ahah')
    love_index = headers.index('love')
    wow_index = headers.index('wow')
    sigh_index = headers.index('sigh')
    grrr_index = headers.index('grrr')
    url_index = headers.index('url')
    
    # Retrieve contents
    for row in csv_reader:
        d['Post_ID'].append(row[post_id_index])
        d['DateTime'].append(row[date_index])
        d['Post_Content'].append(row[content_index])
        d['Reactions'].append(row[total_reactions_index])
        d['Likes'].append(row[likes_index])
        d['Ahah'].append(row[haha_index])
        d['Love'].append(row[love_index])
        d['Wow'].append(row[wow_index])
        d['Sigh'].append(row[sigh_index])
        d['Grrr'].append(row[grrr_index])
        d['Url'].append(row[url_index])

df = pd.DataFrame(data=d)
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_43d9fcce_0373_11ea_b720_9801a7b29125" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Post_ID</th>
#         <th class="col_heading level0 col1" >DateTime</th>
#         <th class="col_heading level0 col2" >Post_Content</th>
#         <th class="col_heading level0 col3" >Reactions</th>
#         <th class="col_heading level0 col4" >Likes</th>
#         <th class="col_heading level0 col5" >Ahah</th>
#         <th class="col_heading level0 col6" >Love</th>
#         <th class="col_heading level0 col7" >Wow</th>
#         <th class="col_heading level0 col8" >Sigh</th>
#         <th class="col_heading level0 col9" >Grrr</th>
#         <th class="col_heading level0 col10" >Url</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_43d9fcce_0373_11ea_b720_9801a7b29125level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col0" class="data row0 col0" >2413865385595634</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col1" class="data row0 col1" >15/10/19 8:22</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col2" class="data row0 col2" >Some people think being a Woke Salaryman means taking zero holidays. That's simply not true. You just take different holidays.  Get updates from us on telegram: https://t.me/wokesalaryman We're also a bit dank (and also having further discussions) on IG: https://www.instagram.com/thewokesalaryman</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col3" class="data row0 col3" >179</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col4" class="data row0 col4" >160</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col5" class="data row0 col5" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col6" class="data row0 col6" >14</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col7" class="data row0 col7" >5</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col8" class="data row0 col8" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col9" class="data row0 col9" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row0_col10" class="data row0 col10" >/story.php?story_fbid=2413865385595634&id=2250666538582187</td>
#     </tr>    <tr>
#         <th id="T_43d9fcce_0373_11ea_b720_9801a7b29125level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col0" class="data row1 col0" >2407835796198593</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col1" class="data row1 col1" >20/9/17 4:20</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col2" class="data row1 col2" >If you watch anything today, let it be this. To understand the recessionary patterns of the economy is to understand human nature. With that understanding, you can better navigate your way through your own financial journey. btw Ray Dalio is awesome. Here's the video I spoke about with Tony Robbins and Charlie Rose this week. I've been asked a lot about populism and economics and I think this template that I shared back in 2013 is very relevant today.</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col3" class="data row1 col3" >191</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col4" class="data row1 col4" >174</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col5" class="data row1 col5" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col6" class="data row1 col6" >16</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col7" class="data row1 col7" >1</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col8" class="data row1 col8" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col9" class="data row1 col9" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row1_col10" class="data row1 col10" >/story.php?story_fbid=2407835796198593&id=2250666538582187</td>
#     </tr>    <tr>
#         <th id="T_43d9fcce_0373_11ea_b720_9801a7b29125level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col0" class="data row2 col0" >2404744283174411</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col1" class="data row2 col1" >5/10/19 10:56</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col2" class="data row2 col2" >Don't wanna look at stocks for 6 hours a week? Investing in the stock market is still an option for you. Get updates from us on telegram: https://t.me/wokesalaryman We're also a bit dank (and also having further discussions) on IG: https://www.instagram.com/thewokesalaryman</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col3" class="data row2 col3" >1898</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col4" class="data row2 col4" >1600</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col5" class="data row2 col5" >3</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col6" class="data row2 col6" >247</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col7" class="data row2 col7" >48</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col8" class="data row2 col8" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col9" class="data row2 col9" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row2_col10" class="data row2 col10" >/story.php?story_fbid=2404744283174411&id=2250666538582187</td>
#     </tr>    <tr>
#         <th id="T_43d9fcce_0373_11ea_b720_9801a7b29125level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col0" class="data row3 col0" >2391879244460915</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col1" class="data row3 col1" >21/9/19 10:00</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col2" class="data row3 col2" >__SPONSORED POST__ - CPF isn't going anywhere for the foreseeable future.  Maybe that's why we've come to accept it.</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col3" class="data row3 col3" >256</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col4" class="data row3 col4" >247</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col5" class="data row3 col5" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col6" class="data row3 col6" >9</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col7" class="data row3 col7" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col8" class="data row3 col8" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col9" class="data row3 col9" >0</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row3_col10" class="data row3 col10" >/story.php?story_fbid=2391879244460915&id=2250666538582187</td>
#     </tr>    <tr>
#         <th id="T_43d9fcce_0373_11ea_b720_9801a7b29125level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row4_col0" class="data row4 col0" >2381147788867394</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row4_col1" class="data row4 col1" >7/9/19 20:20</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row4_col2" class="data row4 col2" >Here's a gentle reminder while we all hustle together.________Get updates from us on telegram: https://t.me/wokesalaryman WeÃ¢ÂÂre also a bit dank (and also having further discussions) on IG: https://www.instagram.com/thewokesalaryman</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row4_col3" class="data row4 col3" >17011</td>
#         <td id="T_43d9fcce_0373_11ea_b720_9801a7b29125row4_col4" class="data row4 col4" >11000</td>
#         <td id="T_43d9fcce_0373_11ea_

# %%
d = {'Post_ID':[], 'Commenter':[], 'Comment_Content':[], 'Comment_ID':[], 'User_Tagging':[], 'User_Tagging_Link':[]}
filepath = ROOT_DATA_FOLDER + 'WokeManSalary/WokeManSalary_comments.txt'

with open(filepath, mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',') 

    # Get header row. Usually the top of the csv file
    headers = next(csv_reader)
    
    # Retreive index of the respective headers
    post_id_index = headers.index('Post_ID')
    commenter_index = headers.index('User')
    content_index = headers.index('Comment')
    commnet_id_index = headers.index('Comment_ID')
    user_tagging_index = headers.index('User_Tagging')
    user_tagging_link_index = headers.index('User_Tagging_Link')
    
    # Retrieve contents
    for row in csv_reader:
        d['Post_ID'].append(row[post_id_index])
        d['Commenter'].append(row[commenter_index])
        d['Comment_Content'].append(row[content_index])
        d['Comment_ID'].append(row[commnet_id_index])
        d['User_Tagging'].append(row[user_tagging_index])
        d['User_Tagging_Link'].append(row[user_tagging_link_index])
        
df = pd.DataFrame(data=d)
df.style
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_2d2a23b2_0398_11ea_b720_9801a7b29125" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Post_ID</th>
#         <th class="col_heading level0 col1" >Commenter</th>
#         <th class="col_heading level0 col2" >Comment_Content</th>
#         <th class="col_heading level0 col3" >Comment_ID</th>
#         <th class="col_heading level0 col4" >User_Tagging</th>
#         <th class="col_heading level0 col5" >User_Tagging_Link</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col0" class="data row0 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col1" class="data row0 col1" >The Woke Salaryman</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col2" class="data row0 col2" >The drawing process:</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col3" class="data row0 col3" >2371246336524206</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col4" class="data row0 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row0_col5" class="data row0 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col0" class="data row1 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col1" class="data row1 col1" >Benny Chis</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col2" class="data row1 col2" >It's being burnt down to turn into grazing land for cows, consider taking direct action and stop eating meat.</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col3" class="data row1 col3" >2371846256464214</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col4" class="data row1 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row1_col5" class="data row1 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col0" class="data row2 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col1" class="data row2 col1" >Ann Celeste</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col2" class="data row2 col2" >This requires world leaders and UN intervention</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col3" class="data row2 col3" >2371709266477913</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col4" class="data row2 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row2_col5" class="data row2 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col0" class="data row3 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col1" class="data row3 col1" >Zulhilmi Ilmamahmadi</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col2" class="data row3 col2" >Kalimantan was burn 5 years ago and no one bat an eye even the Governments and the presidents himself.</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col3" class="data row3 col3" >2373170076331832</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col4" class="data row3 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row3_col5" class="data row3 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col0" class="data row4 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col1" class="data row4 col1" >SW Lee</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col2" class="data row4 col2" >Mmm s'mores.   On a more serious note, save the forests!</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col3" class="data row4 col3" >2371244736524366</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col4" class="data row4 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row4_col5" class="data row4 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col0" class="data row5 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col1" class="data row5 col1" >Adim Lutfi</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col2" class="data row5 col2" >Yeah this yearly issue, hopefully can be stopped</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col3" class="data row5 col3" >2371262859855887</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col4" class="data row5 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row5_col5" class="data row5 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col0" class="data row6 col0" >2371236206525219</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col1" class="data row6 col1" >Jocelyne Sze Shimin</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col2" class="data row6 col2" >Cool post highlighting a very important issue, but flagging up WWF as the organisation to support is rather questionable. It is known to have committed severe human rights breach, albeit in the Congo and not the Amazon. https://www.buzzfeednews.com/article/katiejmbaker/wwf-report-human-rights-abuses-rangers  But then again, you're also directing funding to the Singapore franchise which is highly unlikely to have projects in S. America...  Humans rights violations particular targeted at indigenous peoples are important because they are the best defence against deforestation. Supporting indigenous people in their pursuit to obtain land rights and defend against external economic extractive motives is one of the best ways of protecting the world's remaining rainforests Other organisations that you could show support for include Survival International https://survivalinternational.org/ or Amazon Watch https://amazonwatch.org/</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col3" class="data row6 col3" >2371423576506482</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col4" class="data row6 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row6_col5" class="data row6 col5" ></td>
#     </tr>    <tr>
#         <th id="T_2d2a23b2_0398_11ea_b720_9801a7b29125level0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col0" class="data row7 col0" >2379749222340584</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col1" class="data row7 col1" >The Woke Salaryman</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col2" class="data row7 col2" >It's out as a podcast! Have a listen: https://omny.fm/shows/money-fm-893/money-and-me-sgx-orb-winners-the-woke-salaryman-45</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col3" class="data row7 col3" >2380266458955527</td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col4" class="data row7 col4" ></td>
#         <td id="T_2d2a23b2_0398_11ea_b720_9801a7b29125row7_col5" class="data row7 col5" ></td>
#     </tr>    <tr>

# %% [markdown]
# # 2.1 Testing Section
# Methods from aboved portion can be tested and used here, just as long as they are successfully compiled

# %%
# for page in page_list[3:]:
#     posts_filepath = ROOT_DATA_FOLDER + page + '/' + page + '_collated_comments_tagging.txt'
#     data = []

#     with open(posts_filepath, mode='r', encoding='ISO-8859-1') as csv_file:
#         csv_reader = csv.reader(csv_file, delimiter=',')  
        
#         headers = next(csv_reader)
#         post_id_index = headers.index('Comment_ID')
        
#         for row in csv_reader:
            
#             if row not in data:                
#                 data.append(row)
#             else:
#                 print(row)

# %%
# # Convert CSV file into txt file and remove duplicate row
# for page in page_list:
#     posts_filepath = ROOT_DATA_FOLDER + page + '/' + page + '_posts.csv'
#     data = []
    
#     with open(posts_filepath, mode='r', encoding='ISO-8859-1') as csv_file:
#         csv_reader = csv.reader(csv_file, delimiter=',')  
        
#         headers = next(csv_reader)
#         post_id_index = headers.index('post_id')
#         url_index = headers.index('url')
        
#         data.append(headers)
#         for row in csv_reader:
#             new_row = row[:post_id_index]
            
#             url = row[url_index]
#             if 'story' in url:
#                 new_post_id = row[url_index].split('=')[-2].split('&')[0]
#             else:
#                 new_post_id = row[url_index].split('/')[-1]
            
#             new_row.append(new_post_id)
#             new_row.append(url)
            
#             if row not in data:                
#                 data.append(new_row)
            
#     write_filepath = ROOT_DATA_FOLDER + page + '/' + page + '_posts.txt'
    
#     with open(write_filepath, mode='w', encoding='utf-8') as csv_file:
#         csv_writer = csv.writer(csv_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
        
#         # Write Header
#         csv_writer.writerow(data[0])

#         # Write Content
#         for line in data[1:]:
#             csv_writer.writerow(line)

# %%
# urls_DollarsAndSense = [
#     '/DollarsAndSenseSG/photos/a.1697485630321500/2774662429270476',
#     '/DollarsAndSenseSG/photos/a.900467096690028/2751670081569711',
#     '/DollarsAndSenseSG/photos/a.1697485630321500/2746837705386282',
#     '/DollarsAndSenseSG/photos/a.1697485630321500/2744233652313354',
#     '/DollarsAndSenseSG/photos/a.900467096690028/2694911627245557',
#     '/DollarsAndSenseSG/photos/a.900467096690028/2688094337927286'
# ]

# urls_ConsultMortgage = [
#     '/consultmortgage/photos/a.1455344844620117/1455344894620112'
# ]

# urls_Seedly = [
#     '/seedlysg/photos/a.470073689847337/1059294577591909',
#     '/seedlysg/photos/a.470073689847337/1143479625840070',
#     '/seedlysg/photos/a.470073689847337/1111985378989495'
# ]


# for url in urls_Seedly:
#     comment_list = None
    
#     try:
#         # Get webdriver Object
#         driver = create_webdriver()

#         # Open the website
#         driver.implicitly_wait(5)
#         driver.get('https://mbasic.facebook.com' + url)

#         # Clicks on "Log In" button
#         root_element = driver.find_element_by_id('root')
#         login_element = root_element.find_element_by_tag_name('a').click()
#         time.sleep(1)

#         # Input username
#         username_input = driver.find_element_by_name("email")
#         username_input.clear()
#         username_input.send_keys(EMAIL)

#         # Input password
#         password_input = driver.find_element_by_name("pass")
#         password_input.clear()
#         password_input.send_keys(PASSWORD)

#         # Logs into Facebook using dummy account
#         driver.find_element_by_name("login").click()
#         time.sleep(1)

#         # Retrieve comments from photo posts
#         comment_list = get_comments_photo_posts(driver, url)
        
#         print(url)
#         print(comment_list)

#     except:
#         traceback.print_exc()

#     finally:
#         # Close the Webdriver
#         driver.close()

# %%
# url = '/story.php?story_fbid=3182079765195405&id=386868888049854'
# comments_data = None

# try:
#     # Get webdriver Object
#     driver = create_webdriver()

#     # Open the website
#     driver.implicitly_wait(3)
#     driver.get('https://mbasic.facebook.com' + url)
    
#     # Clicks on "Log In" button
#     root_element = driver.find_element_by_id('root')
#     login_element = root_element.find_element_by_tag_name('a').click()
#     time.sleep(1)

#     # tmp = root_element.get_attribute('innerHTML')
#     # print(tmp)
#     # soup = tmp(tmp, 'html.parser')
#     # print(soup)
    
#     # Input username
#     username_input = driver.find_element_by_name("email")
#     username_input.clear()
#     username_input.send_keys(EMAIL) # <--- input credentials

#     # Input password
#     password_input = driver.find_element_by_name("pass")
#     password_input.clear()
#     password_input.send_keys(PASSWORD) # <--- input password

#     # Logs into Facebook using dummy account
#     driver.find_element_by_name("login").click()
#     time.sleep(1)

#     # Retrieve comments
#     comments_data = get_comments_post(driver, url)

# except:
#     traceback.print_exc()

# finally:
#     # Close the Webdriver
#     driver.close()
