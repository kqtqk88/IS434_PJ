# %%
import pandas as pd
import glob

csv_dir_path = "../WebScraper/seedly-forum/*.csv"

# %%
def read_csv(filename,user_list):
    
    file_df = pd.read_csv(filename)
    return get_users(file_df,user_list)

# %%
def check_name(user_list, name):
    for i,user_dict in enumerate(user_list):
        if name in user_dict.keys():
            return i,user_dict
           
    return 0,None

# %%
def clean_name(name):
    if "DeleteEdit" in name:
        name = name.replace("DeleteEdit","")
    if "Top Contributor (Sep)" in name:
        name = name.replace("Top Contributor (Sep)","")
    if name.endswith("L"):
        name = name[:-1]
    if "Jonathan Chia Guangrong" in name:
        name = name[:name.find("Jonathan Chia Guangrong")]
    return name.strip()

# %%
def get_users(df,user_list):
    
    for i,content in enumerate(df.content):
        user_dict = {}
        if i == 0:
            substr_index = content.find("Asked by")
            user_details = content[substr_index:]
            new_sub_index = user_details.find("Asked on")
            question_name = user_details[:new_sub_index].replace("Asked by","").strip()
            if question_name.find("Asked")!= -1:
                question_name = question_name[:question_name.find("Asked")]      
        elif i > 1:
            substr_index = content.find("Answered")
            user_details = content[:substr_index]
            commar_index = user_details.find(",")
            level_index = user_details.find("Level")
            rank_index = user_details.find(".")
            name = user_details[:commar_index]
            level_index_2 = name.find("Level")
            if level_index_2 != -1:
                name = name[:level_index_2+1]
            level = user_details[level_index:rank_index].replace("Level","").strip()
            name = clean_name(name)
            index, user_dict = check_name(user_list,name)
            if user_dict:
                user_list.pop(index)
                user_dict[name]["counter"] += 1
                user_list.append(user_dict)
            else:
                user_dict = {name:{"level":level,"counter":0}}
                user_list.append(user_dict)
            
    return question_name, user_list

# %%
user_list = []
question_user_list = []

for filename in glob.glob(csv_dir_path):
    question_asked, user_list = read_csv(filename,user_list)
    question_user_list.append(question_asked)
# Out:
# See all 3 comments
#
#
#
#
#
#
#
#
#
#
#
#
# See all 5 comments
#
#
#
#
#
#
#
#
# Nicholas Chan07 Oct 2018Are that sg banks that don't charge for over the counter usd deposits?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# See all 3 comments
#
#
# See all 4 comments Joe Black06 Mar 2019Thank you!
#
#
#
#
#
#
#
# Question Poster09 Oct 2018The money that is used to build the malls is by capitaland limited?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# LCLEE CHEE  KEONG20 Apr 2019Direct transfer to account CIMB account sg can or not
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Esther Esther13 Feb 2019May i know medicore returns would be about how many percent returns?
#
# See all 3 comments
#
#
#
#
#
#
#
#
# See all 3 comments
#
#
#
#
#
#
#
#
#
#
# See all 4 comments Dolce Goh15 Oct 2018ILPs usually breakeven faster than Endowment Policies.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# PSPavan Surya Prakash Ponnam23 Apr 2019Great answer Mr. Jonathan.
#
# MMe20 Apr 2019Read online that Saxo is more suitable if trade at lower amount
#
#
#
# SWShaun Wq Lim18 Apr 2019Renaissance Technologies’ Medallion Fund should be one.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Question Poster09 Feb 2019What's the min cash amount required for options in your opinion?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Question Poster12 Oct 2018What’s the factors to consider before liquidating an asset?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Good Day Every Day15 Sep 2018What is the commission and how much I need to pay if the option is exercised? Thanks.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Gabriel Tham07 Feb 2019thanks for the info!
#
# Hmm..if covered calls can result in my etf shares taken away then i rather not. I am trying to build an global ETF portfolio and thinking to collect premiums and buy them at lower prices.
#
#
#
#
#
#
#
#
#
#
#
#
# Tee-Ming Chew30 Jan 2019ROI of 60%pa is quite impressive.. Could you share more?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# See all 3 comments Yoon Tay19 May 2019May i know is Ireland domiciled ETF (S&P 500) available on TD Ameritrade?
#
#
#
# Question Poster06 Aug 2019Hi STI ETF gives a return of 7-8%? Are you certain that it’s that high? Picking quality blue chip stocks such as banks telco only gives 5-6% as of now
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# MMelissa10 Sep 2019Hmm but Stashaway requires me to have a minimum of $10000 to start investing if I’m not wrong. What about if I purchase it thru a reit counter? What will be the minimum sum?
#
#
#
#
#
#
# Hariz Arthur Maloy07 May 2019ETFs are funds too...
#
#
#
# See all 3 comments
#
#
# See all 4 comments Question Poster04 May 2019Wow that so high.. for myself anything above 6% I would consider gd.
#
#
# See all 3 comments
#
# See all 3 comments
#
#
#
#
#
#
#
#
# See all 4 comments
#
#
#
#
#
#
# Question Poster05 Jun 2019Thank you for the detailed response!
#
# I share similar thoughts on this. I have looked up on the other MIP plans other places offers but plans like DBS InvestSaver actually have minimal counter options and POEMS have commission and dividends charges which I strongly do not favour. Buying into the counters manually is a viable option but it would significantly add up to my transaction cost (1% to min $10 each counter) since I was buying into 3 counte... (more)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Leong Wen Fong01 Oct 2018Can go Tat Chuan Acoustics also! IF you are looking for sound system
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# See all 4 comments Kenneth Lou24 Jan 2019This is an interesting debate.! Just found this out :) Thanks!
#
#
# See all 4 comments Jinssz Ng3w agoI’m interested to invest in REITs. But all I can find in DBS Invest-Saver is the Manulife Asia Pacific REITs. What platform should I be at?
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# See all 5 comments
#
#
#
#
#
#
#
#
#
# Elsa Goh21 Sep 2018I like this goal.
#
# Elsa Goh21 Sep 2018I like this goal.

# %%
for user_dict in user_list:
    print(user_dict)
    for user_name in user_dict.keys():
        print(user_name)
        print(user_dict[user_name])
# Out:
# {'Ang Yee Gary27 May 2019Any ball park figure on the expected growth in property price in next few yea': {'level': '', 'counter': 0}}
# Ang Yee Gary27 May 2019Any ball park figure on the expected growth in property price in next few yea
# {'level': '', 'counter': 0}
# {'Krristy Lam': {'level': '2', 'counter': 1}}
# Krristy Lam
# {'level': '2', 'counter': 1}
# {'Paul Ho': {'level': '2', 'counter': 0}}
# Paul Ho
# {'level': '2', 'counter': 0}
# {'Question Poster04 Aug 2019Basically': {'level': '', 'counter': 0}}
# Question Poster04 Aug 2019Basically
# {'level': '', 'counter': 0}
# {'Kenneth Lou07 Nov 2018100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres': {'level': '', 'counter': 1}}
# Kenneth Lou07 Nov 2018100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres
# {'level': '', 'counter': 1}
# {'Loo Cheng Chuan05 Nov 2018Hi. It is a good question. Commonly asked by aspiring home owners. Also similar to this question is that of : should one use OA and pay up their home loan compared to transferring to SA': {'level': '', 'counter': 0}}
# Loo Cheng Chuan05 Nov 2018Hi. It is a good question. Commonly asked by aspiring home owners. Also similar to this question is that of : should one use OA and pay up their home loan compared to transferring to SA
# {'level': '', 'counter': 0}
# {"Teo See Hwa10 Dec 2018Risk is about how much one know about what one is doing. e.g. if a person don't go for driving lesson and chose to drive without a licence what is the risk compare to a person who got a licence. Both driving the same ca": {'level': '', 'counter': 0}}
# Teo See Hwa10 Dec 2018Risk is about how much one know about what one is doing. e.g. if a person don't go for driving lesson and chose to drive without a licence what is the risk compare to a person who got a licence. Both driving the same ca
# {'level': '', 'counter': 0}
# {"See all 3 comments Good Day Every Day10 Dec 2018I don't understand the relevance of your answer to the question. Please enlighten me. Thanks. Teo See Hwa18 Dec 2018Risk is high when you got limited info or data. Leverage is Risky when you do it the wrong way": {'level': '', 'counter': 0}}
# See all 3 comments Good Day Every Day10 Dec 2018I don't understand the relevance of your answer to the question. Please enlighten me. Thanks. Teo See Hwa18 Dec 2018Risk is high when you got limited info or data. Leverage is Risky when you do it the wrong way
# {'level': '', 'counter': 0}
# {'Leong Wen Fong10 Dec 2018Hi See Hwa': {'level': '', 'counter': 0}}
# Leong Wen Fong10 Dec 2018Hi See Hwa
# {'level': '', 'counter': 0}
# {"Steph Yeo14 Nov 2018But you'll have to wait until you're old enough to take out money from cpf": {'level': '', 'counter': 0}}
# Steph Yeo14 Nov 2018But you'll have to wait until you're old enough to take out money from cpf
# {'level': '', 'counter': 0}
# {'Question Poster07 Nov 2018Thanks for sharing with me your answer. I think helps me shape how I think I want to retire next time. And what I will need to do to get there as well. Appreciate you helping all of us younger audience': {'level': '', 'counter': 0}}
# Question Poster07 Nov 2018Thanks for sharing with me your answer. I think helps me shape how I think I want to retire next time. And what I will need to do to get there as well. Appreciate you helping all of us younger audience
# {'level': '', 'counter': 0}
# {'Question Poster11 Nov 2018That is true. Thanks for sharin': {'level': '', 'counter': 0}}
# Question Poster11 Nov 2018That is true. Thanks for sharin
# {'level': '', 'counter': 0}
# {'See all 3 comments Question Poster11 Nov 2018Thanks for sharingGabriel Lee11 Nov 2018Nice to hear that': {'level': '', 'counter': 0}}
# See all 3 comments Question Poster11 Nov 2018Thanks for sharingGabriel Lee11 Nov 2018Nice to hear that
# {'level': '', 'counter': 0}
# {'Pat08 Nov 2018Hi just to clarify': {'level': '', 'counter': 0}}
# Pat08 Nov 2018Hi just to clarify
# {'level': '', 'counter': 0}
# {'Chong Learn Khang': {'level': '2', 'counter': 0}}
# Chong Learn Khang
# {'level': '2', 'counter': 0}
# {'Leong Wen Fong15 Nov 2018Good advice': {'level': '', 'counter': 0}}
# Leong Wen Fong15 Nov 2018Good advice
# {'level': '', 'counter': 0}
# {'See all 3 comments Yixiong Chang05 Nov 2018Hi': {'level': '', 'counter': 0}}
# See all 3 comments Yixiong Chang05 Nov 2018Hi
# {'level': '', 'counter': 0}
# {'Question Poster24 Jan 2019Thank you for your honest answer!': {'level': '', 'counter': 0}}
# Question Poster24 Jan 2019Thank you for your honest answer!
# {'level': '', 'counter': 0}
# {'Christopher Tan23 Jan 2019Thank you Gabriel! Yes you are right. We definitely don’t “prospect” you and pressure sell you anything. This you can be sure. \r\n\r\nBut I would like to correct the misconception that when one uses MoneyOwl': {'level': '', 'counter': 0}}
# Christopher Tan23 Jan 2019Thank you Gabriel! Yes you are right. We definitely don’t “prospect” you and pressure sell you anything. This you can be sure.
#
# But I would like to correct the misconception that when one uses MoneyOwl
# {'level': '', 'counter': 0}
# {'Christopher Tan25 Jan 2019Hi Luke': {'level': '', 'counter': 0}}
# Christopher Tan25 Jan 2019Hi Luke
# {'level': '', 'counter': 0}
# {'Lim Dewei Nicholas': {'level': '1', 'counter': 0}}
# Lim Dewei Nicholas
# {'level': '1', 'counter': 0}
# {'See all 6 comments Question Poster30 Jan 2019Hi thank you Jonathan you have been a great help. Will call them tomorrow to ask more about itCk Chai01 Feb 2019Thanks for sharing Jonatha': {'level': '', 'counter': 0}}
# See all 6 comments Question Poster30 Jan 2019Hi thank you Jonathan you have been a great help. Will call them tomorrow to ask more about itCk Chai01 Feb 2019Thanks for sharing Jonatha
# {'level': '', 'counter': 0}
# {'Lok Yang Teng29 Jan 2019Which market would you recommend for a not so advanced investor not seeking short term gains?Gabriel Tham29 Jan 2019Start with your local country market': {'level': '', 'counter': 0}}
# Lok Yang Teng29 Jan 2019Which market would you recommend for a not so advanced investor not seeking short term gains?Gabriel Tham29 Jan 2019Start with your local country market
# {'level': '', 'counter': 0}
# {'Question Poster28 Jan 2019How much should I roughly invest in ETFs and roboadvisors? I understand for roboadvisors is better to put in money every month (not sure for how long': {'level': '', 'counter': 0}}
# Question Poster28 Jan 2019How much should I roughly invest in ETFs and roboadvisors? I understand for roboadvisors is better to put in money every month (not sure for how long
# {'level': '', 'counter': 0}
# {'Question Poster28 Jan 2019100 - age = percentage of the lump sum I assume? \r\n\r\nAlso': {'level': '', 'counter': 0}}
# Question Poster28 Jan 2019100 - age = percentage of the lump sum I assume?
#
# Also
# {'level': '', 'counter': 0}
# {'Kenneth Lou21 Aug 2018Interesting! Thanks for your thoughts :) indeed it’s a world which is always evolving quickly. And also read about the soverign deposits one. I think along with many other bloggers': {'level': '', 'counter': 0}}
# Kenneth Lou21 Aug 2018Interesting! Thanks for your thoughts :) indeed it’s a world which is always evolving quickly. And also read about the soverign deposits one. I think along with many other bloggers
# {'level': '', 'counter': 0}
# {'See all 3 comments Kenneth Lou20 Aug 2018This is pretty cool thanks for sharing :) And in case you are wondering': {'level': '', 'counter': 0}}
# See all 3 comments Kenneth Lou20 Aug 2018This is pretty cool thanks for sharing :) And in case you are wondering
# {'level': '', 'counter': 0}
# {"See all 4 comments Charmaine Ng24 Aug 2018Thanks Low! I'll check in with you if I need help! 😉Charmaine Ng24 Aug 2018Yeah Alan": {'level': '', 'counter': 0}}
# See all 4 comments Charmaine Ng24 Aug 2018Thanks Low! I'll check in with you if I need help! 😉Charmaine Ng24 Aug 2018Yeah Alan
# {'level': '', 'counter': 0}
# {'See all 3 comments Ng Lip Hong Kyith07 May 2019Hi Chee Hoe': {'level': '', 'counter': 0}}
# See all 3 comments Ng Lip Hong Kyith07 May 2019Hi Chee Hoe
# {'level': '', 'counter': 0}
# {'Say Kiat21 Aug 2018Thank you for the effort of long explanation ! Your are just one of those kind soul that bring me one step closer to investing. God bless u! Is there any way to reach u other than this foru': {'level': '', 'counter': 0}}
# Say Kiat21 Aug 2018Thank you for the effort of long explanation ! Your are just one of those kind soul that bring me one step closer to investing. God bless u! Is there any way to reach u other than this foru
# {'level': '', 'counter': 0}
# {"Eric Chia16 Aug 2018Do note you'll need to spend at least $500 on uob credit cards for that month to qualify for bonus interest": {'level': '', 'counter': 0}}
# Eric Chia16 Aug 2018Do note you'll need to spend at least $500 on uob credit cards for that month to qualify for bonus interest
# {'level': '', 'counter': 0}
# {'See all 3 comments Kok Koon12 Sep 2018Agree with you': {'level': '', 'counter': 0}}
# See all 3 comments Kok Koon12 Sep 2018Agree with you
# {'level': '', 'counter': 0}
# {'See all 3 comments Kenneth Lou13 Sep 2018Yeah haha': {'level': '', 'counter': 0}}
# See all 3 comments Kenneth Lou13 Sep 2018Yeah haha
# {'level': '', 'counter': 0}
# {'Question Poster09 Oct 2018cool thank you for your sharing and pointing in the right directi': {'level': '', 'counter': 0}}
# Question Poster09 Oct 2018cool thank you for your sharing and pointing in the right directi
# {'level': '', 'counter': 0}
# {'Serene Toh18 Oct 2018Alamak just realised roughly the same answer after I poste': {'level': '', 'counter': 0}}
# Serene Toh18 Oct 2018Alamak just realised roughly the same answer after I poste
# {'level': '', 'counter': 0}
# {'Hao Yu08 Sep 2018Hi Dwivid': {'level': '', 'counter': 0}}
# Hao Yu08 Sep 2018Hi Dwivid
# {'level': '', 'counter': 0}
# {'Jen Kho11 Sep 2018Know stocks return and SSB then add up together to get that year return?': {'level': '', 'counter': 0}}
# Jen Kho11 Sep 2018Know stocks return and SSB then add up together to get that year return?
# {'level': '', 'counter': 0}
# {'Junda Huang': {'level': '2', 'counter': 0}}
# Junda Huang
# {'level': '2', 'counter': 0}
# {'Anant Shiva': {'level': '2', 'counter': 0}}
# Anant Shiva
# {'level': '2', 'counter': 0}
# {"Leong Wen Fong03 Oct 2018What's your experience with Autowealth? Is it a good platform to us": {'level': '', 'counter': 0}}
# Leong Wen Fong03 Oct 2018What's your experience with Autowealth? Is it a good platform to us
# {'level': '', 'counter': 0}
# {'Leong Wen Fong11 Sep 2018I guess if he invests the wait can be shortened by about a year?Gabriel Tham11 Sep 2018depends what is the rate of return. And investment also carry risk of loss unless is FD or S': {'level': '', 'counter': 0}}
# Leong Wen Fong11 Sep 2018I guess if he invests the wait can be shortened by about a year?Gabriel Tham11 Sep 2018depends what is the rate of return. And investment also carry risk of loss unless is FD or S
# {'level': '', 'counter': 0}
# {'Kenneth Lou03 Oct 2018Hi there Teo See Hwa': {'level': '', 'counter': 0}}
# Kenneth Lou03 Oct 2018Hi there Teo See Hwa
# {'level': '', 'counter': 0}
# {'Kenneth Lou11 Sep 2018Would also add that it could be good to listen to audiobooks! For me': {'level': '', 'counter': 0}}
# Kenneth Lou11 Sep 2018Would also add that it could be good to listen to audiobooks! For me
# {'level': '', 'counter': 0}
# {"Donald Kieran Ang03 Apr 2019Can't do monthly investment by byying ETFs yourself through brokers unlike regular top ups to robo advisors righ": {'level': '', 'counter': 0}}
# Donald Kieran Ang03 Apr 2019Can't do monthly investment by byying ETFs yourself through brokers unlike regular top ups to robo advisors righ
# {'level': '', 'counter': 0}
# {'Alex Chua Cheng En23 Feb 2019Based on circular flow of income': {'level': '', 'counter': 0}}
# Alex Chua Cheng En23 Feb 2019Based on circular flow of income
# {'level': '', 'counter': 0}
# {'Rich Tyler': {'level': '2', 'counter': 0}}
# Rich Tyler
# {'level': '2', 'counter': 0}
# {'Ang Yee Gary17 Feb 2019Does not help as this is overall returns. Not yearly returns and does not account for increase or decrease in portfolio amount.Ang Yee Gary17 Feb 2019https://www.fundcount.com/portfolio-accounting?gclid=CjwKCAiAqaTjBRAdEiwAOdx9xnoeObuOQTwHLa9gqct0cggydZca-cIQl9SD4-KSkv6C8iA0IjYQfBoC5DoQAvD_B': {'level': '', 'counter': 0}}
# Ang Yee Gary17 Feb 2019Does not help as this is overall returns. Not yearly returns and does not account for increase or decrease in portfolio amount.Ang Yee Gary17 Feb 2019https://www.fundcount.com/portfolio-accounting?gclid=CjwKCAiAqaTjBRAdEiwAOdx9xnoeObuOQTwHLa9gqct0cggydZca-cIQl9SD4-KSkv6C8iA0IjYQfBoC5DoQAvD_B
# {'level': '', 'counter': 0}
# {'Thaddeus Tan10 Apr 2019Solid use of graphics': {'level': '', 'counter': 0}}
# Thaddeus Tan10 Apr 2019Solid use of graphics
# {'level': '', 'counter': 0}
# {'Jon Lim': {'level': '2', 'counter': 0}}
# Jon Lim
# {'level': '2', 'counter': 0}
# {'Kenneth Lou21 Feb 2019Wow! Really love that analogy. "Are tall buildings bad? No. but people climb on top of tall buildings & jump off': {'level': '', 'counter': 0}}
# Kenneth Lou21 Feb 2019Wow! Really love that analogy. "Are tall buildings bad? No. but people climb on top of tall buildings & jump off
# {'level': '', 'counter': 0}
# {"See all 3 comments Loh Tat Tian21 Feb 2019Woah. I have a figment of reading it before. But you brought the article out. NiceHC Tang21 Feb 2019:D I heard that during Dr.Wealth preview class. So literally Leverage is as you've shared": {'level': '', 'counter': 0}}
# See all 3 comments Loh Tat Tian21 Feb 2019Woah. I have a figment of reading it before. But you brought the article out. NiceHC Tang21 Feb 2019:D I heard that during Dr.Wealth preview class. So literally Leverage is as you've shared
# {'level': '', 'counter': 0}
# {'He Jian Hong22 Feb 2019FSM - MAPS also considered robo righ': {'level': '', 'counter': 0}}
# He Jian Hong22 Feb 2019FSM - MAPS also considered robo righ
# {'level': '', 'counter': 0}
# {'Kenneth Lou21 Feb 2019For example STI ETF!Victor Chng21 Feb 2019and Hang Seng ETF': {'level': '', 'counter': 0}}
# Kenneth Lou21 Feb 2019For example STI ETF!Victor Chng21 Feb 2019and Hang Seng ETF
# {'level': '', 'counter': 0}
# {'Luke Ho27 Feb 2019Concise and well explained. Well don': {'level': '', 'counter': 0}}
# Luke Ho27 Feb 2019Concise and well explained. Well don
# {'level': '', 'counter': 0}
# {'Glenn Ong21 Feb 2019Which companies do you currently invest in there?Victor Chng21 Feb 2019Hi': {'level': '', 'counter': 0}}
# Glenn Ong21 Feb 2019Which companies do you currently invest in there?Victor Chng21 Feb 2019Hi
# {'level': '', 'counter': 0}
# {'Terence Tan22 Feb 2019Are they all from different countrie': {'level': '', 'counter': 0}}
# Terence Tan22 Feb 2019Are they all from different countrie
# {'level': '', 'counter': 0}
# {'See all 3 comments Gabriel Tham21 Feb 2019Vanguard world index etf': {'level': '', 'counter': 0}}
# See all 3 comments Gabriel Tham21 Feb 2019Vanguard world index etf
# {'level': '', 'counter': 0}
# {'Ryuichi LionHeart21 Feb 2019Noted! Thank you so much!': {'level': '', 'counter': 0}}
# Ryuichi LionHeart21 Feb 2019Noted! Thank you so much!
# {'level': '', 'counter': 0}
# {'Ryuichi LionHeart21 Feb 2019Alrighty! Thank you! Shall continue with Ssb': {'level': '', 'counter': 0}}
# Ryuichi LionHeart21 Feb 2019Alrighty! Thank you! Shall continue with Ssb
# {'level': '', 'counter': 0}
# {'Brandon Chew3w agoI guess fundamentally': {'level': '', 'counter': 0}}
# Brandon Chew3w agoI guess fundamentally
# {'level': '', 'counter': 0}
# {'See all 4 comments Question Poster19 Feb 2019Thanks a lot. really appreciate...The last query: for example: Schroder asian growth fund mention about Annual Management Fee as 1.125%. Is trailer fee included in AMF  or thats on top of this AMF?Hariz Arthur Maloy19 Feb 2019Included. :': {'level': '', 'counter': 0}}
# See all 4 comments Question Poster19 Feb 2019Thanks a lot. really appreciate...The last query: for example: Schroder asian growth fund mention about Annual Management Fee as 1.125%. Is trailer fee included in AMF  or thats on top of this AMF?Hariz Arthur Maloy19 Feb 2019Included. :
# {'level': '', 'counter': 0}
# {'Ang Yee Gary17 Feb 2019It does not offer options on hk market': {'level': '', 'counter': 0}}
# Ang Yee Gary17 Feb 2019It does not offer options on hk market
# {'level': '', 'counter': 0}
# {'See all 4 comments Ang Yee Gary18 Feb 2019It also has 0.12 percent annual feesYixiong Chang18 Feb 2019Oh': {'level': '', 'counter': 0}}
# See all 4 comments Ang Yee Gary18 Feb 2019It also has 0.12 percent annual feesYixiong Chang18 Feb 2019Oh
# {'level': '', 'counter': 0}
# {'See all 3 comments Victor Chng20 Feb 2019Personally': {'level': '', 'counter': 0}}
# See all 3 comments Victor Chng20 Feb 2019Personally
# {'level': '', 'counter': 0}
# {'Leonard Tan18 Feb 2019Hey Victor just curious- are you a believer of efficient-markets hypothesis? If so how do you usually determine a good time to buy in? Eg. after a major selloff': {'level': '', 'counter': 0}}
# Leonard Tan18 Feb 2019Hey Victor just curious- are you a believer of efficient-markets hypothesis? If so how do you usually determine a good time to buy in? Eg. after a major selloff
# {'level': '', 'counter': 0}
# {"Brandan Chen22 Feb 2019May i know why S$500? Have you considered the family's situation before providing such a number of at least S$500?": {'level': '', 'counter': 0}}
# Brandan Chen22 Feb 2019May i know why S$500? Have you considered the family's situation before providing such a number of at least S$500?
# {'level': '', 'counter': 0}
# {'Question Poster21 Feb 2019Hi': {'level': '', 'counter': 0}}
# Question Poster21 Feb 2019Hi
# {'level': '', 'counter': 0}
# {'Question Poster18 Feb 2019I see. Thanks for your advice! Will read up more before starting out': {'level': '', 'counter': 0}}
# Question Poster18 Feb 2019I see. Thanks for your advice! Will read up more before starting out
# {'level': '', 'counter': 0}
# {'Daniel Choo': {'level': '1', 'counter': 0}}
# Daniel Choo
# {'level': '1', 'counter': 0}
# {'Question Poster18 Feb 2019Thank you for linking the post': {'level': '', 'counter': 0}}
# Question Poster18 Feb 2019Thank you for linking the post
# {'level': '', 'counter': 0}
# {'Zlao Xie': {'level': '1', 'counter': 0}}
# Zlao Xie
# {'level': '1', 'counter': 0}
# {"Kenneth Lou15 Feb 2019Really shag market indeed... tough to survive and thrive as Telcos in today's worl": {'level': '', 'counter': 0}}
# Kenneth Lou15 Feb 2019Really shag market indeed... tough to survive and thrive as Telcos in today's worl
# {'level': '', 'counter': 0}
# {'Hariz Arthur Maloy18 Feb 2019And liquid!': {'level': '', 'counter': 0}}
# Hariz Arthur Maloy18 Feb 2019And liquid!
# {'level': '', 'counter': 0}
# {'Valentina Tan01 Aug 2019Hi': {'level': '', 'counter': 0}}
# Valentina Tan01 Aug 2019Hi
# {'level': '', 'counter': 0}
# {'Sa Rah': {'level': '1', 'counter': 0}}
# Sa Rah
# {'level': '1', 'counter': 0}
# {'Chupeng Dai': {'level': '2', 'counter': 0}}
# Chupeng Dai
# {'level': '2', 'counter': 0}
# {'Question Poster08 Nov 2018Hi Kenneth! Thanks for answering my question. But when I start spending on my Amex card': {'level': '', 'counter': 0}}
# Question Poster08 Nov 2018Hi Kenneth! Thanks for answering my question. But when I start spending on my Amex card
# {'level': '', 'counter': 0}
# {'Zeal Ong': {'level': '2', 'counter': 0}}
# Zeal Ong
# {'level': '2', 'counter': 0}
# {'See all 3 comments T@Takingstock @3w agoI like these comments. Harvey': {'level': '', 'counter': 0}}
# See all 3 comments T@Takingstock @3w agoI like these comments. Harvey
# {'level': '', 'counter': 0}
# {'Question Poster3w agoThat’s what I wanted to know.  Any good recommendations? A few extra thousands would be great for putting that amou': {'level': '', 'counter': 0}}
# Question Poster3w agoThat’s what I wanted to know.  Any good recommendations? A few extra thousands would be great for putting that amou
# {'level': '', 'counter': 0}
# {'Kelly Trinh4w agoI was hoping to avoid the TT route': {'level': '', 'counter': 0}}
# Kelly Trinh4w agoI was hoping to avoid the TT route
# {'level': '', 'counter': 0}
# {'SWShaun Wq Lim03 Sep 2019Ok that’s good! Don’t want to lose the old dataKenneth Lou03 Sep 2019Thank You! and yes! let me know if you have any problems with this method': {'level': '', 'counter': 0}}
# SWShaun Wq Lim03 Sep 2019Ok that’s good! Don’t want to lose the old dataKenneth Lou03 Sep 2019Thank You! and yes! let me know if you have any problems with this method
# {'level': '', 'counter': 0}
# {'AAAmi Atm02 Sep 2019Yes that works out. transaction get duplicated though.Kenneth Lou03 Sep 2019Hey Ami! Yes there will be some which will become duplicated. U will have to manually go to the transaction list and remove each of the': {'level': '', 'counter': 0}}
# AAAmi Atm02 Sep 2019Yes that works out. transaction get duplicated though.Kenneth Lou03 Sep 2019Hey Ami! Yes there will be some which will become duplicated. U will have to manually go to the transaction list and remove each of the
# {'level': '', 'counter': 0}
# {'Ryan Tham30 Jun 2019Yupp! I too have 2 dbs account and one OCBC (credit card)': {'level': '', 'counter': 0}}
# Ryan Tham30 Jun 2019Yupp! I too have 2 dbs account and one OCBC (credit card)
# {'level': '', 'counter': 0}
# {'Question Poster14 Jun 2019Hey': {'level': '', 'counter': 0}}
# Question Poster14 Jun 2019Hey
# {'level': '', 'counter': 0}
# {'HC Tang13 May 2019Thanks bro. Just in time :P ha': {'level': '', 'counter': 0}}
# HC Tang13 May 2019Thanks bro. Just in time :P ha
# {'level': '', 'counter': 0}
# {"See all 4 comments HC Tang13 May 2019I'll ask seedly help to contact you...Kenneth Lou13 May 2019Thanks HC! Yup @Benn if you need help on the other banks": {'level': '', 'counter': 0}}
# See all 4 comments HC Tang13 May 2019I'll ask seedly help to contact you...Kenneth Lou13 May 2019Thanks HC! Yup @Benn if you need help on the other banks
# {'level': '', 'counter': 0}
# {'ALAndy Lee21 Apr 2019Consider developing Malaysia market': {'level': '', 'counter': 0}}
# ALAndy Lee21 Apr 2019Consider developing Malaysia market
# {'level': '', 'counter': 0}
# {'FAFrenando Ansari03 Sep 2019Understandable': {'level': '', 'counter': 0}}
# FAFrenando Ansari03 Sep 2019Understandable
# {'level': '', 'counter': 0}
# {'Jerry Tan': {'level': '2', 'counter': 0}}
# Jerry Tan
# {'level': '2', 'counter': 0}
# {'Question Poster19 Dec 2018Hi': {'level': '', 'counter': 0}}
# Question Poster19 Dec 2018Hi
# {'level': '', 'counter': 0}
# {'Question Poster05 Dec 2018Thank you for the link! I read it up and apparently it requires me having cold hard cash of 250k which i am unable to do so.. So i decide to continue normal banking and work harder towards that goal now! On a side note.. what is the 175k not insured information that you are referring to? I cannot seem to find it..Lok Yang Teng05 Dec 2018Singapore Deposit Insurance (SDI) only insurers up to 75k in each bank account (up from 50k previously). In the unlikely event money is lost': {'level': '', 'counter': 0}}
# Question Poster05 Dec 2018Thank you for the link! I read it up and apparently it requires me having cold hard cash of 250k which i am unable to do so.. So i decide to continue normal banking and work harder towards that goal now! On a side note.. what is the 175k not insured information that you are referring to? I cannot seem to find it..Lok Yang Teng05 Dec 2018Singapore Deposit Insurance (SDI) only insurers up to 75k in each bank account (up from 50k previously). In the unlikely event money is lost
# {'level': '', 'counter': 0}
# {"Nicholas Chan07 Oct 2018Are that sg banks that don't charge for over the counter usd deposits?": {'level': '', 'counter': 0}}
# Nicholas Chan07 Oct 2018Are that sg banks that don't charge for over the counter usd deposits?
# {'level': '', 'counter': 0}
# {"Eric Chia18 Sep 2018Also agree with Gabriel and Daniel. Just adding on if you're not looking at SSB": {'level': '', 'counter': 0}}
# Eric Chia18 Sep 2018Also agree with Gabriel and Daniel. Just adding on if you're not looking at SSB
# {'level': '', 'counter': 0}
# {"Esther Esther07 Feb 2019What's DCA? HC Tang07 Feb 2019Oh it stands for Dollar Cost Averaging. It means monthly invest a fix amount automatically via giro to the investment regardless of situations usually using regular savings plan account. Due to the nature of buying consistently regardless of higher or lower price": {'level': '', 'counter': 0}}
# Esther Esther07 Feb 2019What's DCA? HC Tang07 Feb 2019Oh it stands for Dollar Cost Averaging. It means monthly invest a fix amount automatically via giro to the investment regardless of situations usually using regular savings plan account. Due to the nature of buying consistently regardless of higher or lower price
# {'level': '', 'counter': 0}
# {'LBLeo Boon Yeow': {'level': '1', 'counter': 0}}
# LBLeo Boon Yeow
# {'level': '1', 'counter': 0}
# {'Kalpesh08 Aug 2018Thanks a lot and appreciate you taking time to revert back... Cheers and have a great National Day week ahead!\r\n\r\nKenneth Kalpesh08 Aug 2018Kenneth one more question.. Can seedly consume previous data of SB account & share dashboard': {'level': '', 'counter': 0}}
# Kalpesh08 Aug 2018Thanks a lot and appreciate you taking time to revert back... Cheers and have a great National Day week ahead!
#
# Kenneth Kalpesh08 Aug 2018Kenneth one more question.. Can seedly consume previous data of SB account & share dashboard
# {'level': '', 'counter': 0}
# {'Jared Ho11 Jul 2019Hi there': {'level': '', 'counter': 0}}
# Jared Ho11 Jul 2019Hi there
# {'level': '', 'counter': 0}
# {'Zach Howe14 Jun 2018It seems that TS is mostly transferring the funds for his/ her Overseas bank to Singapore bank': {'level': '', 'counter': 0}}
# Zach Howe14 Jun 2018It seems that TS is mostly transferring the funds for his/ her Overseas bank to Singapore bank
# {'level': '', 'counter': 0}
# {'Zi Song Lim': {'level': '2', 'counter': 0}}
# Zi Song Lim
# {'level': '2', 'counter': 0}
# {'NENat E14 Sep 2019Ah I still can’t though! Will reach out to the support email w a screenshot. Thanks': {'level': '', 'counter': 0}}
# NENat E14 Sep 2019Ah I still can’t though! Will reach out to the support email w a screenshot. Thanks
# {'level': '', 'counter': 0}
# {'See all 3 comments YCYewFong Chua12 Sep 2019Logon using ocbc mobile app': {'level': '', 'counter': 0}}
# See all 3 comments YCYewFong Chua12 Sep 2019Logon using ocbc mobile app
# {'level': '', 'counter': 0}
# {"Question Poster06 Jan 2019actually may i ask what benefits do UOB one card carry? only cash rebates that's all? not sure if going through all the hassle is worth it for this credit cardLoh Tat Tian06 Jan 2019If you are able to automate payments of at least $500 to the card": {'level': '', 'counter': 0}}
# Question Poster06 Jan 2019actually may i ask what benefits do UOB one card carry? only cash rebates that's all? not sure if going through all the hassle is worth it for this credit cardLoh Tat Tian06 Jan 2019If you are able to automate payments of at least $500 to the card
# {'level': '', 'counter': 0}
# {"Question Poster04 Dec 2018Do you mean I shouldn't go for the 1.85% of DBS Multiplier? I heard SAYE have lock-in period which is a turn off for meLok Yang Teng05 Dec 2018You can go for both actually. SAYE is a second account which debits certain amount from your main account. The X amount is then locked in for 2 years monthl": {'level': '', 'counter': 0}}
# Question Poster04 Dec 2018Do you mean I shouldn't go for the 1.85% of DBS Multiplier? I heard SAYE have lock-in period which is a turn off for meLok Yang Teng05 Dec 2018You can go for both actually. SAYE is a second account which debits certain amount from your main account. The X amount is then locked in for 2 years monthl
# {'level': '', 'counter': 0}
# {'Raymond Koh02 Aug 2019Thanks for your response! However': {'level': '', 'counter': 0}}
# Raymond Koh02 Aug 2019Thanks for your response! However
# {'level': '', 'counter': 0}
# {'Ordinary Yc': {'level': '1', 'counter': 0}}
# Ordinary Yc
# {'level': '1', 'counter': 0}
# {'Question Poster18 Aug 2019Hello': {'level': '', 'counter': 0}}
# Question Poster18 Aug 2019Hello
# {'level': '', 'counter': 0}
# {'Amkaes': {'level': '2', 'counter': 0}}
# Amkaes
# {'level': '2', 'counter': 0}
# {'Chris Tang': {'level': '1', 'counter': 0}}
# Chris Tang
# {'level': '1', 'counter': 0}
# {'See all 3 comments JWjiajing wang03 Sep 2019If u are referring to the multiplier interest rate... Yes': {'level': '', 'counter': 0}}
# See all 3 comments JWjiajing wang03 Sep 2019If u are referring to the multiplier interest rate... Yes
# {'level': '', 'counter': 0}
# {'Kdz2w agoYou may want to explore Brunei market too': {'level': '', 'counter': 0}}
# Kdz2w agoYou may want to explore Brunei market too
# {'level': '', 'counter': 0}
# {'Question Poster15 Nov 2018Yep': {'level': '', 'counter': 0}}
# Question Poster15 Nov 2018Yep
# {'level': '', 'counter': 0}
# {'John Smith25 Aug 2019So just park $70k & don’t touch it. What is the interest like ? ThanksJunus Eu25 Aug 2019Most accurate info would be straight from the source: https://www.citibank.com.sg/gcb/deposits/mxgn-savacc.h': {'level': '', 'counter': 0}}
# John Smith25 Aug 2019So just park $70k & don’t touch it. What is the interest like ? ThanksJunus Eu25 Aug 2019Most accurate info would be straight from the source: https://www.citibank.com.sg/gcb/deposits/mxgn-savacc.h
# {'level': '', 'counter': 0}
# {'See all 3 comments Clarence Chua18 Jun 2019While in army I don’t use a %': {'level': '', 'counter': 0}}
# See all 3 comments Clarence Chua18 Jun 2019While in army I don’t use a %
# {'level': '', 'counter': 0}
# {'Question Poster18 Jun 2019How much of my salary would you advise me to keep aside for savings and how much for spending expenditure? \r\n\r\nAlso could you elaborate more on RSP if you don’t mind? I don’t like venturing into stuff I’m not very sure of just like investing.Thaddeus Tan19 Jun 2019Hi anon': {'level': '', 'counter': 0}}
# Question Poster18 Jun 2019How much of my salary would you advise me to keep aside for savings and how much for spending expenditure?
#
# Also could you elaborate more on RSP if you don’t mind? I don’t like venturing into stuff I’m not very sure of just like investing.Thaddeus Tan19 Jun 2019Hi anon
# {'level': '', 'counter': 0}
# {'Question Poster18 Jun 2019I don’t club or drink so I guess that’s good. Don’t even smoke. \r\n\r\nYes I’m an SCT currently': {'level': '', 'counter': 0}}
# Question Poster18 Jun 2019I don’t club or drink so I guess that’s good. Don’t even smoke.
#
# Yes I’m an SCT currently
# {'level': '', 'counter': 0}
# {'Wilson Wilson': {'level': '2', 'counter': 0}}
# Wilson Wilson
# {'level': '2', 'counter': 0}
# {'Kenichi Xi28 Sep 2018Do': {'level': '', 'counter': 0}}
# Kenichi Xi28 Sep 2018Do
# {'level': '', 'counter': 0}
# {'Tan Boon Hian': {'level': '1', 'counter': 0}}
# Tan Boon Hian
# {'level': '1', 'counter': 0}
# {"Question Poster04 Oct 2018Hmm CIMB don't need to i think for me and my bf we have no issue with this :) Tan Boon Hian13 Oct 2018I see": {'level': '', 'counter': 0}}
# Question Poster04 Oct 2018Hmm CIMB don't need to i think for me and my bf we have no issue with this :) Tan Boon Hian13 Oct 2018I see
# {'level': '', 'counter': 0}
# {'Fan ZD12 Jun 2019Just a question - the remix account seems to have been converted. I only see a DBS Savings Plus on the portal. Does it still have the same benefit': {'level': '', 'counter': 0}}
# Fan ZD12 Jun 2019Just a question - the remix account seems to have been converted. I only see a DBS Savings Plus on the portal. Does it still have the same benefit
# {'level': '', 'counter': 0}
# {'Stanley Teo17 Jul 2019😱 u got over the hurdle of integrating with the banks... but cannot allow export of data?': {'level': '', 'counter': 0}}
# Stanley Teo17 Jul 2019😱 u got over the hurdle of integrating with the banks... but cannot allow export of data?
# {'level': '', 'counter': 0}
# {'Question Poster15 Dec 2018How long will I receive the DCS letter after CDP approval? Lok Yang Teng16 Dec 2018You will receive a letter from SGX informing you on the final status of the application within 2 weeks from the application date (acceptance or rejectio': {'level': '', 'counter': 0}}
# Question Poster15 Dec 2018How long will I receive the DCS letter after CDP approval? Lok Yang Teng16 Dec 2018You will receive a letter from SGX informing you on the final status of the application within 2 weeks from the application date (acceptance or rejectio
# {'level': '', 'counter': 0}
# {'Ching Shy Lim20 Sep 2018Is US Etf subjected to tax?Gabriel Lee20 Sep 2018Yes': {'level': '', 'counter': 0}}
# Ching Shy Lim20 Sep 2018Is US Etf subjected to tax?Gabriel Lee20 Sep 2018Yes
# {'level': '', 'counter': 0}
# {'See all 5 comments Christopher How19 Sep 2018If the truth is a cheap shot': {'level': '', 'counter': 0}}
# See all 5 comments Christopher How19 Sep 2018If the truth is a cheap shot
# {'level': '', 'counter': 0}
# {'Kenneth Lou19 Sep 2018Another very good answer': {'level': '', 'counter': 0}}
# Kenneth Lou19 Sep 2018Another very good answer
# {'level': '', 'counter': 0}
# {'Yi Fong Tan25 Sep 2018Second this!! "$14mil could last 3 generations without even investing since you seem to be very prudent in your lifestyl': {'level': '', 'counter': 0}}
# Yi Fong Tan25 Sep 2018Second this!! "$14mil could last 3 generations without even investing since you seem to be very prudent in your lifestyl
# {'level': '', 'counter': 0}
# {'Kenneth Lou19 Sep 2018I love this comment haha "If this is true... congratulations. Also': {'level': '', 'counter': 0}}
# Kenneth Lou19 Sep 2018I love this comment haha "If this is true... congratulations. Also
# {'level': '', 'counter': 0}
# {'Leck Ting Yan': {'level': '2', 'counter': 0}}
# Leck Ting Yan
# {'level': '2', 'counter': 0}
# {'Leong Wen Fong20 Sep 2018Good advice! Love the thought for the future generatio': {'level': '', 'counter': 0}}
# Leong Wen Fong20 Sep 2018Good advice! Love the thought for the future generatio
# {'level': '', 'counter': 0}
# {'Tan YapSheng': {'level': '2', 'counter': 0}}
# Tan YapSheng
# {'level': '2', 'counter': 0}
# {'Kenneth Lou19 Sep 2018That is pretty interesting... private placement programs! :': {'level': '', 'counter': 0}}
# Kenneth Lou19 Sep 2018That is pretty interesting... private placement programs! :
# {'level': '', 'counter': 0}
# {'Question Poster19 Nov 2018Hi Andrew': {'level': '', 'counter': 0}}
# Question Poster19 Nov 2018Hi Andrew
# {'level': '', 'counter': 0}
# {'See all 5 comments Alcander Seow16 Jun 2019Do I need to buy insurance to get the guarantee from SDIC?Tan Wei Ming16 Jun 2019It is not a local bank. However': {'level': '', 'counter': 0}}
# See all 5 comments Alcander Seow16 Jun 2019Do I need to buy insurance to get the guarantee from SDIC?Tan Wei Ming16 Jun 2019It is not a local bank. However
# {'level': '', 'counter': 0}
# {'See all 3 comments Fan ZD12 Jun 2019Quite safe. Covered by SDIC up to 75k too. Anyways': {'level': '', 'counter': 0}}
# See all 3 comments Fan ZD12 Jun 2019Quite safe. Covered by SDIC up to 75k too. Anyways
# {'level': '', 'counter': 0}
# {"See all 3 comments Pat17 Jun 2019You can't withdraw fixed deposits during the period which you have placed it with them and you will get a fixed interest rate of 1.5-2.0% (based on current schemes). You can only place fresh funds with the bank for fixed deposits. Most banks require a min of 10/20k placement for the fixed deposits so only consider this option if you have sufficient savings. If not": {'level': '', 'counter': 0}}
# See all 3 comments Pat17 Jun 2019You can't withdraw fixed deposits during the period which you have placed it with them and you will get a fixed interest rate of 1.5-2.0% (based on current schemes). You can only place fresh funds with the bank for fixed deposits. Most banks require a min of 10/20k placement for the fixed deposits so only consider this option if you have sufficient savings. If not
# {'level': '', 'counter': 0}
# {'Gabriel Tham03 May 2019Haha dang...thought can hack..credit just spend $1 hack. Maybe can find a cheap plan': {'level': '', 'counter': 0}}
# Gabriel Tham03 May 2019Haha dang...thought can hack..credit just spend $1 hack. Maybe can find a cheap plan
# {'level': '', 'counter': 0}
# {'See all 3 comments Kenneth Lou16 Dec 2018Thanks for sharing your experience too HC!HC Tang16 Dec 2018Thanks b': {'level': '', 'counter': 0}}
# See all 3 comments Kenneth Lou16 Dec 2018Thanks for sharing your experience too HC!HC Tang16 Dec 2018Thanks b
# {'level': '', 'counter': 0}
# {"See all 3 comments Kenneth Lou20 Dec 2018Yeah but it's not the best way to do it leh... but at the same time this is capitalism at work hahaLoh Tat Tian20 Dec 2018Can't control what promoters of product do right. Marketing is all about exploiting peoples weakness sadly": {'level': '', 'counter': 0}}
# See all 3 comments Kenneth Lou20 Dec 2018Yeah but it's not the best way to do it leh... but at the same time this is capitalism at work hahaLoh Tat Tian20 Dec 2018Can't control what promoters of product do right. Marketing is all about exploiting peoples weakness sadly
# {'level': '', 'counter': 0}
# {'佩珊17 Sep 2019Cos have apply that cardcare protection that’s y I Wan to know what is wrking f': {'level': '', 'counter': 0}}
# 佩珊17 Sep 2019Cos have apply that cardcare protection that’s y I Wan to know what is wrking f
# {'level': '', 'counter': 0}
# {'Jacqueline Yan13 Sep 2019No queues at the ATM plus can use PayNow to withdraw mone': {'level': '', 'counter': 0}}
# Jacqueline Yan13 Sep 2019No queues at the ATM plus can use PayNow to withdraw mone
# {'level': '', 'counter': 0}
# {'See all 4 comments Question Poster04 Dec 2018Now wondering if stashaway can invest in IWDA? HC Tang04 Dec 2018Can post a new question': {'level': '', 'counter': 0}}
# See all 4 comments Question Poster04 Dec 2018Now wondering if stashaway can invest in IWDA? HC Tang04 Dec 2018Can post a new question
# {'level': '', 'counter': 0}
# {'Question Poster04 Dec 2018Thank you very much for your advice. Will continue to do so by increasing the standing order on a consistent basis than to do a lump s': {'level': '', 'counter': 0}}
# Question Poster04 Dec 2018Thank you very much for your advice. Will continue to do so by increasing the standing order on a consistent basis than to do a lump s
# {'level': '', 'counter': 0}
# {'See all 7 comments JDJohn Doe15 May 2019Yes but am not looking for a hack.  The multipler Account is a separate account which will earn higher interest.  The joint account where salary is credited only earns base interest.  I am looking for a joint account which is multipler and will earn higher than base interest upon salary creditHC Tang15 May 2019Not that I know off at the moment. Easiest and closest way is that you could turn one of the two DBS multiplier as joint and save combine funds there and leave the join account as it is. Once it hits the cap for high interest': {'level': '', 'counter': 0}}
# See all 7 comments JDJohn Doe15 May 2019Yes but am not looking for a hack.  The multipler Account is a separate account which will earn higher interest.  The joint account where salary is credited only earns base interest.  I am looking for a joint account which is multipler and will earn higher than base interest upon salary creditHC Tang15 May 2019Not that I know off at the moment. Easiest and closest way is that you could turn one of the two DBS multiplier as joint and save combine funds there and leave the join account as it is. Once it hits the cap for high interest
# {'level': '', 'counter': 0}
# {'Question Poster08 May 2019Thank you! How much is the amount in the savings to get 75k back?Gabriel Tham09 May 2019I am not sure I understand you. But SDIC will insure your savings up to 75k. \r\n\r\nhttps://www.straitstimes.com/business/banking/higher-deposit-safeguards-insurance-policy-protection-for-private-hire-drivers-ki': {'level': '', 'counter': 0}}
# Question Poster08 May 2019Thank you! How much is the amount in the savings to get 75k back?Gabriel Tham09 May 2019I am not sure I understand you. But SDIC will insure your savings up to 75k.
#
# https://www.straitstimes.com/business/banking/higher-deposit-safeguards-insurance-policy-protection-for-private-hire-drivers-ki
# {'level': '', 'counter': 0}
# {'Question Poster08 May 2019Alright understood. Ive transfer some money in there and will also close it then': {'level': '', 'counter': 0}}
# Question Poster08 May 2019Alright understood. Ive transfer some money in there and will also close it then
# {'level': '', 'counter': 0}
# {"Martin Low28 Apr 2019But how come the bonus interest become constant amt? Not compounded?Ang Yee Gary29 Apr 2019If I am not wrong it is incremental balance that's gets the special interest rat": {'level': '', 'counter': 0}}
# Martin Low28 Apr 2019But how come the bonus interest become constant amt? Not compounded?Ang Yee Gary29 Apr 2019If I am not wrong it is incremental balance that's gets the special interest rat
# {'level': '', 'counter': 0}
# {'Kenneth Lou02 Oct 2018Cool comment... the best way to learn to is to do it yourself! In fact': {'level': '', 'counter': 0}}
# Kenneth Lou02 Oct 2018Cool comment... the best way to learn to is to do it yourself! In fact
# {'level': '', 'counter': 0}
# {"See all 5 comments Adriel Thin02 Oct 2018I think there's no harm in seeking the advice of an adviser": {'level': '', 'counter': 0}}
# See all 5 comments Adriel Thin02 Oct 2018I think there's no harm in seeking the advice of an adviser
# {'level': '', 'counter': 0}
# {'See all 3 comments Teo See Hwa03 Oct 2018understand': {'level': '', 'counter': 0}}
# See all 3 comments Teo See Hwa03 Oct 2018understand
# {'level': '', 'counter': 0}
# {'NNinja4w agoFake news lol. The jumpstart account remains at 2% if total amount in bank is less than $20000. Above 27 years old does not reduce the ratesLow San Zeng4w agoOhh is it? Cos that time I went to the scb bank and ask about the interest rate after 27': {'level': '', 'counter': 0}}
# NNinja4w agoFake news lol. The jumpstart account remains at 2% if total amount in bank is less than $20000. Above 27 years old does not reduce the ratesLow San Zeng4w agoOhh is it? Cos that time I went to the scb bank and ask about the interest rate after 27
# {'level': '', 'counter': 0}
# {'Low San Zeng3w agoNice! Thanks for confirming!Kenneth Lou3w agoHaha awesom': {'level': '', 'counter': 0}}
# Low San Zeng3w agoNice! Thanks for confirming!Kenneth Lou3w agoHaha awesom
# {'level': '', 'counter': 0}
# {'Kenneth Lou30 Aug 2019I totally agree!NNinja30 Aug 2019Ocbc then dbs then uob. Uob is the last to catch': {'level': '', 'counter': 0}}
# Kenneth Lou30 Aug 2019I totally agree!NNinja30 Aug 2019Ocbc then dbs then uob. Uob is the last to catch
# {'level': '', 'counter': 0}
# {'Ivan Ho23 May 2019This is the only way I found out & tried. Which also means 2 entries is a must & having to bear in mind the ‘+/-‘ at which account every time. It will be really nice to have a single entry function having able to indicate within the single entry': {'level': '', 'counter': 0}}
# Ivan Ho23 May 2019This is the only way I found out & tried. Which also means 2 entries is a must & having to bear in mind the ‘+/-‘ at which account every time. It will be really nice to have a single entry function having able to indicate within the single entry
# {'level': '', 'counter': 0}
# {'Ivan Ho23 May 2019I understand what you mean': {'level': '', 'counter': 1}}
# Ivan Ho23 May 2019I understand what you mean
# {'level': '', 'counter': 1}
# {'Yong Kah Hwee28 Oct 2018oops': {'level': '', 'counter': 0}}
# Yong Kah Hwee28 Oct 2018oops
# {'level': '', 'counter': 0}
# {'Kishor Bhagwat23 Mar 2019You are right. However can I suggest you rephrase the part "different lengths of maturity BUT the same level of risk" ? because that is technically incorrect. If they had same level of risk': {'level': '', 'counter': 0}}
# Kishor Bhagwat23 Mar 2019You are right. However can I suggest you rephrase the part "different lengths of maturity BUT the same level of risk" ? because that is technically incorrect. If they had same level of risk
# {'level': '', 'counter': 0}
# {'Kenneth Lou29 Mar 2019Solid answer @Isaa': {'level': '', 'counter': 0}}
# Kenneth Lou29 Mar 2019Solid answer @Isaa
# {'level': '', 'counter': 0}
# {'ASAbhishek Singh': {'level': '2', 'counter': 0}}
# ASAbhishek Singh
# {'level': '2', 'counter': 0}
# {'See all 8 comments Lee Jiahui15 Apr 2019I did oa to sa transfer and switched to cash repayment for loan in 2013 (the yr matters more than age cos back then property and stock prices were high). The main consideration then a growing warchest with nothing to buy. Back then the plan was to reach FRS asap. In 2015 when stock prices fell': {'level': '', 'counter': 0}}
# See all 8 comments Lee Jiahui15 Apr 2019I did oa to sa transfer and switched to cash repayment for loan in 2013 (the yr matters more than age cos back then property and stock prices were high). The main consideration then a growing warchest with nothing to buy. Back then the plan was to reach FRS asap. In 2015 when stock prices fell
# {'level': '', 'counter': 0}
# {"Hariz Arthur Maloy06 Mar 2019It's a rule of thumb. Your age should be the % of bonds in your portfolio. So if you're 25": {'level': '', 'counter': 0}}
# Hariz Arthur Maloy06 Mar 2019It's a rule of thumb. Your age should be the % of bonds in your portfolio. So if you're 25
# {'level': '', 'counter': 0}
# {'Thaddeus Tan19 Mar 2019WOW! Solid chart m': {'level': '', 'counter': 0}}
# Thaddeus Tan19 Mar 2019WOW! Solid chart m
# {'level': '', 'counter': 0}
# {'Linda Tan01 Apr 2019I see! thanks again for the answer Hariz. Do you know if there are other bonds that I can compare SSBs with?Hariz Arthur Maloy01 Apr 2019US Treasuries. But then you take on currency risk. You can also try investment grade quasi sovereign bonds': {'level': '', 'counter': 0}}
# Linda Tan01 Apr 2019I see! thanks again for the answer Hariz. Do you know if there are other bonds that I can compare SSBs with?Hariz Arthur Maloy01 Apr 2019US Treasuries. But then you take on currency risk. You can also try investment grade quasi sovereign bonds
# {'level': '', 'counter': 0}
# {'Linda Tan03 Apr 2019Thank you for your well wishes': {'level': '', 'counter': 0}}
# Linda Tan03 Apr 2019Thank you for your well wishes
# {'level': '', 'counter': 0}
# {'Question Poster05 Nov 2018Thank yo': {'level': '', 'counter': 0}}
# Question Poster05 Nov 2018Thank yo
# {'level': '', 'counter': 0}
# {'Thaddeus Tan28 Mar 2019SOLID ANSWER BR': {'level': '', 'counter': 0}}
# Thaddeus Tan28 Mar 2019SOLID ANSWER BR
# {'level': '', 'counter': 0}
# {'See all 3 comments Gabriel Tham02 Jun 2019Well if u sell before going to CDP': {'level': '', 'counter': 0}}
# See all 3 comments Gabriel Tham02 Jun 2019Well if u sell before going to CDP
# {'level': '', 'counter': 0}
# {'Ross Mammino': {'level': '2', 'counter': 0}}
# Ross Mammino
# {'level': '2', 'counter': 0}
# {'Osama Agami': {'level': '1', 'counter': 0}}
# Osama Agami
# {'level': '1', 'counter': 0}
# {'Kenneth Tan': {'level': '1', 'counter': 0}}
# Kenneth Tan
# {'level': '1', 'counter': 0}
# {'Ross Mammino24 Jun 2019I disagr': {'level': '', 'counter': 0}}
# Ross Mammino24 Jun 2019I disagr
# {'level': '', 'counter': 0}
# {'Ross Mammino07 Jul 2019This is so helpful': {'level': '', 'counter': 0}}
# Ross Mammino07 Jul 2019This is so helpful
# {'level': '', 'counter': 0}
# {'Engr Invest': {'level': '2', 'counter': 0}}
# Engr Invest
# {'level': '2', 'counter': 0}
# {'Ho Shu Yuan20h agoThank Yo': {'level': '', 'counter': 0}}
# Ho Shu Yuan20h agoThank Yo
# {'level': '', 'counter': 0}
# {'Gabriel Tham19 Nov 2018actually im not sure about it leh...like so many are taking these same courses': {'level': '', 'counter': 0}}
# Gabriel Tham19 Nov 2018actually im not sure about it leh...like so many are taking these same courses
# {'level': '', 'counter': 0}
# {'Question Poster23 Sep 2019Hi! Ehh not really sure the diff roles yet so was thinking of learning more! But based in descriptions': {'level': '', 'counter': 0}}
# Question Poster23 Sep 2019Hi! Ehh not really sure the diff roles yet so was thinking of learning more! But based in descriptions
# {'level': '', 'counter': 0}
# {'Igor Kaparis': {'level': '1', 'counter': 0}}
# Igor Kaparis
# {'level': '1', 'counter': 0}
# {'Question Poster08 Sep 2019Thank you! I’m a person with low confidence and I’m always doubting myself. I guess I will give myself myself more time and figure it out. Thanks for your advise!Hariz Arthur Maloy08 Sep 2019Remember': {'level': '', 'counter': 0}}
# ...
# {'level': '2', 'counter': 0}
# {'Billy Ko': {'level': '6', 'counter': 98}}
# Billy Ko
# {'level': '6', 'counter': 98}
# {'Gerard Ong22 Oct 2018I think the last 4 points should be non-deductible expenses :) Loh Tat Tian22 Oct 2018Ops. Correct let me edit it': {'level': '', 'counter': 0}}
# Gerard Ong22 Oct 2018I think the last 4 points should be non-deductible expenses :) Loh Tat Tian22 Oct 2018Ops. Correct let me edit it
# {'level': '', 'counter': 0}
# {'JWjiajing wang': {'level': '3', 'counter': 17}}
# JWjiajing wang
# {'level': '3', 'counter': 17}
# {'See all 3 comments Gabriel Tham06 Aug 2019Perhaps can find a hitch': {'level': '', 'counter': 0}}
# See all 3 comments Gabriel Tham06 Aug 2019Perhaps can find a hitch
# {'level': '', 'counter': 0}
# {'Bang Hong': {'level': '4', 'counter': 51}}
# Bang Hong
# {'level': '4', 'counter': 51}
# {'Vincent Tan Wen Bin': {'level': '5', 'counter': 105}}
# Vincent Tan Wen Bin
# {'level': '5', 'counter': 105}
# {'Tan Guan Chuan': {'level': '1', 'counter': 0}}
# Tan Guan Chuan
# {'level': '1', 'counter': 0}
# {'Tan Siak Lim': {'level': '', 'counter': 26}}
# Tan Siak Lim
# {'level': '', 'counter': 26}
# {'Charmaine Lim Xiaomei': {'level': '4', 'counter': 19}}
# Charmaine Lim Xiaomei
# {'level': '4', 'counter': 19}
# {'Ck Chai': {'level': '4', 'counter': 57}}
# Ck Chai
# {'level': '4', 'counter': 57}
# {'Alvin Teo': {'level': '4', 'counter': 52}}
# Alvin Teo
# {'level': '4', 'counter': 52}
# {'Siti Putri': {'level': '5', 'counter': 12}}
# Siti Putri
# {'level': '5', 'counter': 12}
# {'KKimyesing': {'level': '1', 'counter': 0}}
# KKimyesing
# {'level': '1', 'counter': 0}
# {'T@Takingstock @': {'level': '5', 'counter': 106}}
# T@Takingstock @
# {'level': '5', 'counter': 106}
# {'Sim Min Xuan': {'level': '3', 'counter': 4}}
# Sim Min Xuan
# {'level': '3', 'counter': 4}
# {'Mujimoro': {'level': '4', 'counter': 28}}
# Mujimoro
# {'level': '4', 'counter': 28}
# {'Ronald Szie': {'level': '4', 'counter': 10}}
# Ronald Szie
# {'level': '4', 'counter': 10}
# {'Jolene Tan': {'level': '2', 'counter': 3}}
# Jolene Tan
# {'level': '2', 'counter': 3}
# {'Victor Chng': {'level': '4', 'counter': 100}}
# Victor Chng
# {'level': '4', 'counter': 100}
# {'Robin Lim': {'level': '2', 'counter': 4}}
# Robin Lim
# {'level': '2', 'counter': 4}
# {'Fox Arora': {'level': '1', 'counter': 0}}
# Fox Arora
# {'level': '1', 'counter': 0}
# {'Hariz Arthur Maloy10 Mar 2019Great answe': {'level': '', 'counter': 0}}
# Hariz Arthur Maloy10 Mar 2019Great answe
# {'level': '', 'counter': 0}
# {'Richard Woon Tian Jun': {'level': '6', 'counter': 158}}
# Richard Woon Tian Jun
# {'level': '6', 'counter': 158}
# {'Dominic Chang': {'level': '3', 'counter': 5}}
# Dominic Chang
# {'level': '3', 'counter': 5}
# {'Serene Toh': {'level': '5', 'counter': 67}}
# Serene Toh
# {'level': '5', 'counter': 67}
# {'Pat': {'level': '4', 'counter': 24}}
# Pat
# {'level': '4', 'counter': 24}
# {"See all 3 comments Pat25 Jun 2019I'm not certain about OEM": {'level': '', 'counter': 0}}
# See all 3 comments Pat25 Jun 2019I'm not certain about OEM
# {'level': '', 'counter': 0}
# {'Gabriel Lee': {'level': '6', 'counter': 259}}
# Gabriel Lee
# {'level': '6', 'counter': 259}
# {'Jay Liu': {'level': '6', 'counter': 126}}
# Jay Liu
# {'level': '6', 'counter': 126}
# {'Gabriel Tham': {'level': '8', 'counter': 847}}
# Gabriel Tham
# {'level': '8', 'counter': 847}
# {'Yong Kah Hwee': {'level': '6', 'counter': 463}}
# Yong Kah Hwee
# {'level': '6', 'counter': 463}
# {'Timothy Tan': {'level': '2', 'counter': 0}}
# Timothy Tan
# {'level': '2', 'counter': 0}
# {'Lam Ka Ying3w agoHSBC will allow insurance paymen': {'level': '', 'counter': 0}}
# Lam Ka Ying3w agoHSBC will allow insurance paymen
# {'level': '', 'counter': 0}
# {'Tianshu Dai': {'level': '2', 'counter': 0}}
# Tianshu Dai
# {'level': '2', 'counter': 0}
# {'See all 3 comments Tee-Ming Chew27 Mar 2019I got the UOB Priv Miles and didn’t know about the 2 years expiry. Thanks for the heads up!Wei Ling01 Jun 2019Can I check if online spending considered valid for CITI Mile Car': {'level': '', 'counter': 0}}
# See all 3 comments Tee-Ming Chew27 Mar 2019I got the UOB Priv Miles and didn’t know about the 2 years expiry. Thanks for the heads up!Wei Ling01 Jun 2019Can I check if online spending considered valid for CITI Mile Car
# {'level': '', 'counter': 0}
# {'Joel Tan Jun Rong': {'level': '2', 'counter': 0}}
# Joel Tan Jun Rong
# {'level': '2', 'counter': 0}
# {'Huang Yixuan27 Mar 2019Citibank has good sign up bonus! 30': {'level': '', 'counter': 0}}
# Huang Yixuan27 Mar 2019Citibank has good sign up bonus! 30
# {'level': '', 'counter': 0}
# {'Aik Kai': {'level': '6', 'counter': 120}}
# Aik Kai
# {'level': '6', 'counter': 120}
# {"Huang Yixuan06 Mar 2019Oooh I didn't know that": {'level': '', 'counter': 0}}
# Huang Yixuan06 Mar 2019Oooh I didn't know that
# {'level': '', 'counter': 0}
# {'Huang Yixuan': {'level': '6', 'counter': 39}}
# Huang Yixuan
# {'level': '6', 'counter': 39}
# {'Loo Cheng Chuan': {'level': '6', 'counter': 67}}
# Loo Cheng Chuan
# {'level': '6', 'counter': 67}
# {'Tee-Ming Chew': {'level': '6', 'counter': 39}}
# Tee-Ming Chew
# {'level': '6', 'counter': 39}
# {'Leonard Tan': {'level': '6', 'counter': 134}}
# Leonard Tan
# {'level': '6', 'counter': 134}
# {'Guo Hao Teo': {'level': '4', 'counter': 35}}
# Guo Hao Teo
# {'level': '4', 'counter': 35}
# {'Luke Ho': {'level': '6', 'counter': 249}}
# Luke Ho
# {'level': '6', 'counter': 249}
# {'Yeo Enk Loui': {'level': '6', 'counter': 116}}
# Yeo Enk Loui
# {'level': '6', 'counter': 116}
# {'Lim Boon Tat': {'level': '4', 'counter': 18}}
# Lim Boon Tat
# {'level': '4', 'counter': 18}
# {'See all 4 comments Kenneth Lou05 Apr 2019Very good and simple explanation. Thanks! On the concept of surge pricing hahaRichard Tang07 Apr 2019Every good way to explain value investing in an everyday excis': {'level': '', 'counter': 0}}
# See all 4 comments Kenneth Lou05 Apr 2019Very good and simple explanation. Thanks! On the concept of surge pricing hahaRichard Tang07 Apr 2019Every good way to explain value investing in an everyday excis
# {'level': '', 'counter': 0}
# {'Sandra Teo': {'level': '6', 'counter': 153}}
# Sandra Teo
# {'level': '6', 'counter': 153}
# {'Zann Chua': {'level': '6', 'counter': 172}}
# Zann Chua
# {'level': '6', 'counter': 172}
# {'Lin ML': {'level': '3', 'counter': 3}}
# Lin ML
# {'level': '3', 'counter': 3}
# {'Chris Lee Susanto': {'level': '2', 'counter': 6}}
# Chris Lee Susanto
# {'level': '2', 'counter': 6}
# {'Ang Yee Gary': {'level': '4', 'counter': 40}}
# Ang Yee Gary
# {'level': '4', 'counter': 40}
# {'Kevin Vincent27 Apr 2019I agree. Retirement savings not to be gambled . I find Non bank short term lending on First Mortgage with low LVRs at around 8-10% attractive. With 20% in Bank Term Deposits. But would love to buy into REITs and Index Funds after a crash. Trouble is when is this next one due': {'level': '', 'counter': 0}}
# Kevin Vincent27 Apr 2019I agree. Retirement savings not to be gambled . I find Non bank short term lending on First Mortgage with low LVRs at around 8-10% attractive. With 20% in Bank Term Deposits. But would love to buy into REITs and Index Funds after a crash. Trouble is when is this next one due
# {'level': '', 'counter': 0}
# {'SWShaun Wq Lim': {'level': '4', 'counter': 33}}
# SWShaun Wq Lim
# {'level': '4', 'counter': 33}
# {'Isaac Chan': {'level': '8', 'counter': 314}}
# Isaac Chan
# {'level': '8', 'counter': 314}
# {'Elijah Lee': {'level': '9', 'counter': 327}}
# Elijah Lee
# {'level': '9', 'counter': 327}
# {'Cedric Jamie Soh': {'level': '', 'counter': 269}}
# Cedric Jamie Soh
# {'level': '', 'counter': 269}
# {'Jasmine Chye Fong Yee': {'level': '3', 'counter': 10}}
# Jasmine Chye Fong Yee
# {'level': '3', 'counter': 10}
# {'Nurul Afiqah Binti Laili': {'level': '1', 'counter': 1}}
# Nurul Afiqah Binti Laili
# {'level': '1', 'counter': 1}
# {'Jim Ng': {'level': '5', 'counter': 37}}
# Jim Ng
# {'level': '5', 'counter': 37}
# {'Question Poster12 Nov 2018Hi': {'level': '', 'counter': 1}}
# Question Poster12 Nov 2018Hi
# {'level': '', 'counter': 1}
# {'Loh Tat Tian12 Nov 2018Even as an emergency fund': {'level': '', 'counter': 0}}
# Loh Tat Tian12 Nov 2018Even as an emergency fund
# {'level': '', 'counter': 0}
# {'Nicholes Wong': {'level': '6', 'counter': 407}}
# Nicholes Wong
# {'level': '6', 'counter': 407}
# {'Lim Chun Long Jimmy': {'level': '5', 'counter': 56}}
# Lim Chun Long Jimmy
# {'level': '5', 'counter': 56}
# {'Boonhow Eng': {'level': '3', 'counter': 12}}
# Boonhow Eng
# {'level': '3', 'counter': 12}
# {'Carol Tham14 Nov 2018Agree with Boonhow & Hariz.. \r\nActually life insurance is meant for family. To help deal with situations where you might be permanently disabled and need the funds to pay medical or help with living expenses. Alternatively': {'level': '', 'counter': 0}}
# Carol Tham14 Nov 2018Agree with Boonhow & Hariz..
# Actually life insurance is meant for family. To help deal with situations where you might be permanently disabled and need the funds to pay medical or help with living expenses. Alternatively
# {'level': '', 'counter': 0}
# {'Josh Tan Jian Liang': {'level': '', 'counter': 52}}
# Josh Tan Jian Liang
# {'level': '', 'counter': 52}
# {'Jacob Chong': {'level': '3', 'counter': 12}}
# Jacob Chong
# {'level': '3', 'counter': 12}
# {'Good Day Every Day': {'level': '6', 'counter': 248}}
# Good Day Every Day
# {'level': '6', 'counter': 248}
# {'Lim Wei Siang': {'level': '2', 'counter': 9}}
# Lim Wei Siang
# {'level': '2', 'counter': 9}
# {'Yixiong Chang': {'level': '5', 'counter': 203}}
# Yixiong Chang
# {'level': '5', 'counter': 203}
# {'Brandan Chen': {'level': '6', 'counter': 182}}
# Brandan Chen
# {'level': '6', 'counter': 182}
# {'Christopher Tan': {'level': '6', 'counter': 59}}
# Christopher Tan
# {'level': '6', 'counter': 59}
# {'Loh Tat Tian': {'level': '6', 'counter': 367}}
# Loh Tat Tian
# {'level': '6', 'counter': 367}
# {'KAKelvin Ang': {'level': '3', 'counter': 3}}
# KAKelvin Ang
# {'level': '3', 'counter': 3}
# {'Hariz Arthur Maloy': {'level': '9', 'counter': 877}}
# Hariz Arthur Maloy
# {'level': '9', 'counter': 877}
# {'Jacqueline Yan': {'level': '4', 'counter': 15}}
# Jacqueline Yan
# {'level': '4', 'counter': 15}
# {'Question Poster05 Sep 2019Totally understand how you feel! But yes you brought up valid points which I’ll think about before making my decisio': {'level': '', 'counter': 0}}
# Question Poster05 Sep 2019Totally understand how you feel! But yes you brought up valid points which I’ll think about before making my decisio
# {'level': '', 'counter': 0}
# {'': {'level': '6', 'counter': 506}}
#
# {'level': '6', 'counter': 506}
# {'Question Poster05 Sep 2019Thanks for your reply!\r\n\r\nI’m thinking of switching to a term plan (either with or without early CI). And for my endowment plans': {'level': '', 'counter': 0}}
# Question Poster05 Sep 2019Thanks for your reply!
#
# I’m thinking of switching to a term plan (either with or without early CI). And for my endowment plans
# {'level': '', 'counter': 0}
# {'EEvelyn': {'level': '3', 'counter': 19}}
# EEvelyn
# {'level': '3', 'counter': 19}
# {'Question Poster05 Sep 2019Ah looks like there are many people in the same situation! For me': {'level': '', 'counter': 0}}
# Question Poster05 Sep 2019Ah looks like there are many people in the same situation! For me
# {'level': '', 'counter': 0}
# {'Javier Lim': {'level': '5', 'counter': 12}}
# Javier Lim
# {'level': '5', 'counter': 12}
# {'Chin Guo Qiang': {'level': '3', 'counter': 23}}
# Chin Guo Qiang
# {'level': '3', 'counter': 23}
# {'M Sim QY09 Jun 2019You sure topup Youtrip pays reward points? \r\nI checked with DBS. They said their cards do not pay out reward points/ miles for topup to Youtr': {'level': '', 'counter': 0}}
# M Sim QY09 Jun 2019You sure topup Youtrip pays reward points?
# I checked with DBS. They said their cards do not pay out reward points/ miles for topup to Youtr
# {'level': '', 'counter': 0}
# {'NNNicholas Nbx': {'level': '2', 'counter': 2}}
# NNNicholas Nbx
# {'level': '2', 'counter': 2}
# {'Clarence Chua': {'level': '7', 'counter': 139}}
# Clarence Chua
# {'level': '7', 'counter': 139}
# {'BLBrian Lee': {'level': '3', 'counter': 11}}
# BLBrian Lee
# {'level': '3', 'counter': 11}
# {'Charmaine Ng': {'level': '6', 'counter': 93}}
# Charmaine Ng
# {'level': '6', 'counter': 93}
# {'Alex Wong': {'level': '3', 'counter': 3}}
# Alex Wong
# {'level': '3', 'counter': 3}
# {'HC Tang': {'level': '8', 'counter': 355}}
# HC Tang
# {'level': '8', 'counter': 355}
# {'Lam Ka Ying16 May 2019Personally prefers Youtrip which seems to have smaller margins for their exchange rates (you can check in the app for both accounts). Youtrip also does not charge foreign transaction fees for currencies outside of the listed 1': {'level': '', 'counter': 0}}
# Lam Ka Ying16 May 2019Personally prefers Youtrip which seems to have smaller margins for their exchange rates (you can check in the app for both accounts). Youtrip also does not charge foreign transaction fees for currencies outside of the listed 1
# {'level': '', 'counter': 0}
# {'Png Cheng Xi Damien': {'level': '4', 'counter': 54}}
# Png Cheng Xi Damien
# {'level': '4', 'counter': 54}
# {"Kenneth Lou24 Oct 2018You can check out this person's profile also. He's been answering all the YouTrip Related questions as he is from the team itself! https://seedly.sg/profile/kelvin-7382704d-7c68-4094-bbbb-49fd3dc674": {'level': '', 'counter': 0}}
# Kenneth Lou24 Oct 2018You can check out this person's profile also. He's been answering all the YouTrip Related questions as he is from the team itself! https://seedly.sg/profile/kelvin-7382704d-7c68-4094-bbbb-49fd3dc674
# {'level': '', 'counter': 0}
# {'Eng You Guan': {'level': '4', 'counter': 3}}
# Eng You Guan
# {'level': '4', 'counter': 3}
# {'Kelvin Lam24 Aug 2018We are glad you like it. Please keep the comments coming in!': {'level': '', 'counter': 0}}
# Kelvin Lam24 Aug 2018We are glad you like it. Please keep the comments coming in!
# {'level': '', 'counter': 0}
# {'Wilfred Ling': {'level': '3', 'counter': 2}}
# Wilfred Ling
# {'level': '3', 'counter': 2}
# {'Kelvin Lam24 Aug 2018Hey Wilfred - thanks for the comment! Am from YouTrip and if you don’t mind want to just do a quick response:\r\n\r\n1. Name on card: We do know that this is not the best option for some': {'level': '', 'counter': 0}}
# Kelvin Lam24 Aug 2018Hey Wilfred - thanks for the comment! Am from YouTrip and if you don’t mind want to just do a quick response:
#
# 1. Name on card: We do know that this is not the best option for some
# {'level': '', 'counter': 0}
# {'Kenneth Lou': {'level': '8', 'counter': 403}}
# Kenneth Lou
# {'level': '8', 'counter': 403}
# {'Jefferson Soh': {'level': '3', 'counter': 6}}
# Jefferson Soh
# {'level': '3', 'counter': 6}
# {'Kelvin Lam28 Aug 2018Hey Jefferson': {'level': '', 'counter': 0}}
# Kelvin Lam28 Aug 2018Hey Jefferson
# {'level': '', 'counter': 0}
# {'Kelvin Lam': {'level': '2', 'counter': 0}}
# Kelvin Lam
# {'level': '2', 'counter': 0}
# {'Boon Chong Lau26 Aug 2018Hi Kelvin': {'level': '', 'counter': 0}}
# Boon Chong Lau26 Aug 2018Hi Kelvin
# {'level': '', 'counter': 0}
# {'Pao J-wei': {'level': '1', 'counter': 0}}
# Pao J-wei
# {'level': '1', 'counter': 0}
# {'Jeff Yeo': {'level': '6', 'counter': 228}}
# Jeff Yeo
# {'level': '6', 'counter': 228}
# {'Sarveen Chester16 Dec 2018For the free subscription': {'level': '', 'counter': 0}}
# Sarveen Chester16 Dec 2018For the free subscription
# {'level': '', 'counter': 0}
# {'Junus Eu': {'level': '8', 'counter': 375}}
# Junus Eu
# {'level': '8', 'counter': 375}
# {'Ng Wei En': {'level': '4', 'counter': 9}}
# Ng Wei En
# {'level': '4', 'counter': 9}
# {'Kelly Trinh': {'level': '3', 'counter': 7}}
# Kelly Trinh
# {'level': '3', 'counter': 7}
# {'Pat2w agoUnder the new t&cs': {'level': '', 'counter': 1}}
# Pat2w agoUnder the new t&cs
# {'level': '', 'counter': 1}
# {'Leslie Koh': {'level': '4', 'counter': 33}}
# Leslie Koh
# {'level': '4', 'counter': 33}
# {'RyaN Cheong6h agoHi Leslie': {'level': '', 'counter': 0}}
# RyaN Cheong6h agoHi Leslie
# {'level': '', 'counter': 0}
# {'RyaN Cheong': {'level': '2', 'counter': 2}}
# RyaN Cheong
# {'level': '2', 'counter': 2}
# {'RyaN Cheong2w agoMy referral code for revolut:\r\nhttps://revolut.com/r/mingre0l': {'level': '', 'counter': 1}}
# RyaN Cheong2w agoMy referral code for revolut:
# https://revolut.com/r/mingre0l
# {'level': '', 'counter': 1}
# {'Lok Yang Teng': {'level': '6', 'counter': 328}}
# Lok Yang Teng
# {'level': '6', 'counter': 328}
# {'Lava Ama A Dios': {'level': '2', 'counter': 0}}
# Lava Ama A Dios
# {'level': '2', 'counter': 0}

# %%
final_user_list = []

for user_dict in user_list:
    final_user_dict = {}
    for name in user_dict.keys():
        final_user_dict["name"] = name
        final_user_dict["level"] = user_dict[name]["level"]
        final_user_dict["counter"] = user_dict[name]["counter"]
        final_user_list.append(final_user_dict)
        
final_user_list
# Out:
# [{'name': 'Ang Yee Gary27 May 2019Any ball park figure on the expected growth in property price in next few yea',
#   'level': '',
#   'counter': 0},
#  {'name': 'Krristy Lam', 'level': '2', 'counter': 1},
#  {'name': 'Paul Ho', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster04 Aug 2019Basically', 'level': '', 'counter': 0},
#  {'name': 'Kenneth Lou07 Nov 2018100% agree on the leadership training part!! There are many things Army can teach you that even the toughest problems in work (next time) cannot. EG. determination under physical stres',
#   'level': '',
#   'counter': 1},
#  {'name': 'Loo Cheng Chuan05 Nov 2018Hi. It is a good question. Commonly asked by aspiring home owners. Also similar to this question is that of : should one use OA and pay up their home loan compared to transferring to SA',
#   'level': '',
#   'counter': 0},
#  {'name': "Teo See Hwa10 Dec 2018Risk is about how much one know about what one is doing. e.g. if a person don't go for driving lesson and chose to drive without a licence what is the risk compare to a person who got a licence. Both driving the same ca",
#   'level': '',
#   'counter': 0},
#  {'name': "See all 3 comments Good Day Every Day10 Dec 2018I don't understand the relevance of your answer to the question. Please enlighten me. Thanks. Teo See Hwa18 Dec 2018Risk is high when you got limited info or data. Leverage is Risky when you do it the wrong way",
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong10 Dec 2018Hi See Hwa', 'level': '', 'counter': 0},
#  {'name': "Steph Yeo14 Nov 2018But you'll have to wait until you're old enough to take out money from cpf",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster07 Nov 2018Thanks for sharing with me your answer. I think helps me shape how I think I want to retire next time. And what I will need to do to get there as well. Appreciate you helping all of us younger audience',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster11 Nov 2018That is true. Thanks for sharin',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Question Poster11 Nov 2018Thanks for sharingGabriel Lee11 Nov 2018Nice to hear that',
#   'level': '',
#   'counter': 0},
#  {'name': 'Pat08 Nov 2018Hi just to clarify', 'level': '', 'counter': 0},
#  {'name': 'Chong Learn Khang', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong15 Nov 2018Good advice', 'level': '', 'counter': 0},
#  {'name': 'See all 3 comments Yixiong Chang05 Nov 2018Hi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster24 Jan 2019Thank you for your honest answer!',
#   'level': '',
#   'counter': 0},
#  {'name': 'Christopher Tan23 Jan 2019Thank you Gabriel! Yes you are right. We definitely don’t “prospect” you and pressure sell you anything. This you can be sure. \r\n\r\nBut I would like to correct the misconception that when one uses MoneyOwl',
#   'level': '',
#   'counter': 0},
#  {'name': 'Christopher Tan25 Jan 2019Hi Luke', 'level': '', 'counter': 0},
#  {'name': 'Lim Dewei Nicholas', 'level': '1', 'counter': 0},
#  {'name': 'See all 6 comments Question Poster30 Jan 2019Hi thank you Jonathan you have been a great help. Will call them tomorrow to ask more about itCk Chai01 Feb 2019Thanks for sharing Jonatha',
#   'level': '',
#   'counter': 0},
#  {'name': 'Lok Yang Teng29 Jan 2019Which market would you recommend for a not so advanced investor not seeking short term gains?Gabriel Tham29 Jan 2019Start with your local country market',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster28 Jan 2019How much should I roughly invest in ETFs and roboadvisors? I understand for roboadvisors is better to put in money every month (not sure for how long',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster28 Jan 2019100 - age = percentage of the lump sum I assume? \r\n\r\nAlso',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou21 Aug 2018Interesting! Thanks for your thoughts :) indeed it’s a world which is always evolving quickly. And also read about the soverign deposits one. I think along with many other bloggers',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Kenneth Lou20 Aug 2018This is pretty cool thanks for sharing :) And in case you are wondering',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 4 comments Charmaine Ng24 Aug 2018Thanks Low! I'll check in with you if I need help! 😉Charmaine Ng24 Aug 2018Yeah Alan",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Ng Lip Hong Kyith07 May 2019Hi Chee Hoe',
#   'level': '',
#   'counter': 0},
#  {'name': 'Say Kiat21 Aug 2018Thank you for the effort of long explanation ! Your are just one of those kind soul that bring me one step closer to investing. God bless u! Is there any way to reach u other than this foru',
#   'level': '',
#   'counter': 0},
#  {'name': "Eric Chia16 Aug 2018Do note you'll need to spend at least $500 on uob credit cards for that month to qualify for bonus interest",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Kok Koon12 Sep 2018Agree with you',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Kenneth Lou13 Sep 2018Yeah haha',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster09 Oct 2018cool thank you for your sharing and pointing in the right directi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Serene Toh18 Oct 2018Alamak just realised roughly the same answer after I poste',
#   'level': '',
#   'counter': 0},
#  {'name': 'Hao Yu08 Sep 2018Hi Dwivid', 'level': '', 'counter': 0},
#  {'name': 'Jen Kho11 Sep 2018Know stocks return and SSB then add up together to get that year return?',
#   'level': '',
#   'counter': 0},
#  {'name': 'Junda Huang', 'level': '2', 'counter': 0},
#  {'name': 'Anant Shiva', 'level': '2', 'counter': 0},
#  {'name': "Leong Wen Fong03 Oct 2018What's your experience with Autowealth? Is it a good platform to us",
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong11 Sep 2018I guess if he invests the wait can be shortened by about a year?Gabriel Tham11 Sep 2018depends what is the rate of return. And investment also carry risk of loss unless is FD or S',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou03 Oct 2018Hi there Teo See Hwa',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou11 Sep 2018Would also add that it could be good to listen to audiobooks! For me',
#   'level': '',
#   'counter': 0},
#  {'name': "Donald Kieran Ang03 Apr 2019Can't do monthly investment by byying ETFs yourself through brokers unlike regular top ups to robo advisors righ",
#   'level': '',
#   'counter': 0},
#  {'name': 'Alex Chua Cheng En23 Feb 2019Based on circular flow of income',
#   'level': '',
#   'counter': 0},
#  {'name': 'Rich Tyler', 'level': '2', 'counter': 0},
#  {'name': 'Ang Yee Gary17 Feb 2019Does not help as this is overall returns. Not yearly returns and does not account for increase or decrease in portfolio amount.Ang Yee Gary17 Feb 2019https://www.fundcount.com/portfolio-accounting?gclid=CjwKCAiAqaTjBRAdEiwAOdx9xnoeObuOQTwHLa9gqct0cggydZca-cIQl9SD4-KSkv6C8iA0IjYQfBoC5DoQAvD_B',
#   'level': '',
#   'counter': 0},
#  {'name': 'Thaddeus Tan10 Apr 2019Solid use of graphics',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jon Lim', 'level': '2', 'counter': 0},
#  {'name': 'Kenneth Lou21 Feb 2019Wow! Really love that analogy. "Are tall buildings bad? No. but people climb on top of tall buildings & jump off',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 3 comments Loh Tat Tian21 Feb 2019Woah. I have a figment of reading it before. But you brought the article out. NiceHC Tang21 Feb 2019:D I heard that during Dr.Wealth preview class. So literally Leverage is as you've shared",
#   'level': '',
#   'counter': 0},
#  {'name': 'He Jian Hong22 Feb 2019FSM - MAPS also considered robo righ',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou21 Feb 2019For example STI ETF!Victor Chng21 Feb 2019and Hang Seng ETF',
#   'level': '',
#   'counter': 0},
#  {'name': 'Luke Ho27 Feb 2019Concise and well explained. Well don',
#   'level': '',
#   'counter': 0},
#  {'name': 'Glenn Ong21 Feb 2019Which companies do you currently invest in there?Victor Chng21 Feb 2019Hi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Terence Tan22 Feb 2019Are they all from different countrie',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Gabriel Tham21 Feb 2019Vanguard world index etf',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ryuichi LionHeart21 Feb 2019Noted! Thank you so much!',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ryuichi LionHeart21 Feb 2019Alrighty! Thank you! Shall continue with Ssb',
#   'level': '',
#   'counter': 0},
#  {'name': 'Brandon Chew3w agoI guess fundamentally',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Question Poster19 Feb 2019Thanks a lot. really appreciate...The last query: for example: Schroder asian growth fund mention about Annual Management Fee as 1.125%. Is trailer fee included in AMF  or thats on top of this AMF?Hariz Arthur Maloy19 Feb 2019Included. :',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ang Yee Gary17 Feb 2019It does not offer options on hk market',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Ang Yee Gary18 Feb 2019It also has 0.12 percent annual feesYixiong Chang18 Feb 2019Oh',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Victor Chng20 Feb 2019Personally',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leonard Tan18 Feb 2019Hey Victor just curious- are you a believer of efficient-markets hypothesis? If so how do you usually determine a good time to buy in? Eg. after a major selloff',
#   'level': '',
#   'counter': 0},
#  {'name': "Brandan Chen22 Feb 2019May i know why S$500? Have you considered the family's situation before providing such a number of at least S$500?",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster21 Feb 2019Hi', 'level': '', 'counter': 0},
#  {'name': 'Question Poster18 Feb 2019I see. Thanks for your advice! Will read up more before starting out',
#   'level': '',
#   'counter': 0},
#  {'name': 'Daniel Choo', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster18 Feb 2019Thank you for linking the post',
#   'level': '',
#   'counter': 0},
#  {'name': 'Zlao Xie', 'level': '1', 'counter': 0},
#  {'name': "Kenneth Lou15 Feb 2019Really shag market indeed... tough to survive and thrive as Telcos in today's worl",
#   'level': '',
#   'counter': 0},
#  {'name': 'Hariz Arthur Maloy18 Feb 2019And liquid!',
#   'level': '',
#   'counter': 0},
#  {'name': 'Valentina Tan01 Aug 2019Hi', 'level': '', 'counter': 0},
#  {'name': 'Sa Rah', 'level': '1', 'counter': 0},
#  {'name': 'Chupeng Dai', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster08 Nov 2018Hi Kenneth! Thanks for answering my question. But when I start spending on my Amex card',
#   'level': '',
#   'counter': 0},
#  {'name': 'Zeal Ong', 'level': '2', 'counter': 0},
#  {'name': 'See all 3 comments T@Takingstock @3w agoI like these comments. Harvey',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster3w agoThat’s what I wanted to know.  Any good recommendations? A few extra thousands would be great for putting that amou',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kelly Trinh4w agoI was hoping to avoid the TT route',
#   'level': '',
#   'counter': 0},
#  {'name': 'SWShaun Wq Lim03 Sep 2019Ok that’s good! Don’t want to lose the old dataKenneth Lou03 Sep 2019Thank You! and yes! let me know if you have any problems with this method',
#   'level': '',
#   'counter': 0},
#  {'name': 'AAAmi Atm02 Sep 2019Yes that works out. transaction get duplicated though.Kenneth Lou03 Sep 2019Hey Ami! Yes there will be some which will become duplicated. U will have to manually go to the transaction list and remove each of the',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ryan Tham30 Jun 2019Yupp! I too have 2 dbs account and one OCBC (credit card)',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster14 Jun 2019Hey', 'level': '', 'counter': 0},
#  {'name': 'HC Tang13 May 2019Thanks bro. Just in time :P ha',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 4 comments HC Tang13 May 2019I'll ask seedly help to contact you...Kenneth Lou13 May 2019Thanks HC! Yup @Benn if you need help on the other banks",
#   'level': '',
#   'counter': 0},
#  {'name': 'ALAndy Lee21 Apr 2019Consider developing Malaysia market',
#   'level': '',
#   'counter': 0},
#  {'name': 'FAFrenando Ansari03 Sep 2019Understandable',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jerry Tan', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster19 Dec 2018Hi', 'level': '', 'counter': 0},
#  {'name': 'Question Poster05 Dec 2018Thank you for the link! I read it up and apparently it requires me having cold hard cash of 250k which i am unable to do so.. So i decide to continue normal banking and work harder towards that goal now! On a side note.. what is the 175k not insured information that you are referring to? I cannot seem to find it..Lok Yang Teng05 Dec 2018Singapore Deposit Insurance (SDI) only insurers up to 75k in each bank account (up from 50k previously). In the unlikely event money is lost',
#   'level': '',
#   'counter': 0},
#  {'name': "Nicholas Chan07 Oct 2018Are that sg banks that don't charge for over the counter usd deposits?",
#   'level': '',
#   'counter': 0},
#  {'name': "Eric Chia18 Sep 2018Also agree with Gabriel and Daniel. Just adding on if you're not looking at SSB",
#   'level': '',
#   'counter': 0},
#  {'name': "Esther Esther07 Feb 2019What's DCA? HC Tang07 Feb 2019Oh it stands for Dollar Cost Averaging. It means monthly invest a fix amount automatically via giro to the investment regardless of situations usually using regular savings plan account. Due to the nature of buying consistently regardless of higher or lower price",
#   'level': '',
#   'counter': 0},
#  {'name': 'LBLeo Boon Yeow', 'level': '1', 'counter': 0},
#  {'name': 'Kalpesh08 Aug 2018Thanks a lot and appreciate you taking time to revert back... Cheers and have a great National Day week ahead!\r\n\r\nKenneth Kalpesh08 Aug 2018Kenneth one more question.. Can seedly consume previous data of SB account & share dashboard',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jared Ho11 Jul 2019Hi there', 'level': '', 'counter': 0},
#  {'name': 'Zach Howe14 Jun 2018It seems that TS is mostly transferring the funds for his/ her Overseas bank to Singapore bank',
#   'level': '',
#   'counter': 0},
#  {'name': 'Zi Song Lim', 'level': '2', 'counter': 0},
#  {'name': 'NENat E14 Sep 2019Ah I still can’t though! Will reach out to the support email w a screenshot. Thanks',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments YCYewFong Chua12 Sep 2019Logon using ocbc mobile app',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster06 Jan 2019actually may i ask what benefits do UOB one card carry? only cash rebates that's all? not sure if going through all the hassle is worth it for this credit cardLoh Tat Tian06 Jan 2019If you are able to automate payments of at least $500 to the card",
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster04 Dec 2018Do you mean I shouldn't go for the 1.85% of DBS Multiplier? I heard SAYE have lock-in period which is a turn off for meLok Yang Teng05 Dec 2018You can go for both actually. SAYE is a second account which debits certain amount from your main account. The X amount is then locked in for 2 years monthl",
#   'level': '',
#   'counter': 0},
#  {'name': 'Raymond Koh02 Aug 2019Thanks for your response! However',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ordinary Yc', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster18 Aug 2019Hello', 'level': '', 'counter': 0},
#  {'name': 'Amkaes', 'level': '2', 'counter': 0},
#  {'name': 'Chris Tang', 'level': '1', 'counter': 0},
#  {'name': 'See all 3 comments JWjiajing wang03 Sep 2019If u are referring to the multiplier interest rate... Yes',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kdz2w agoYou may want to explore Brunei market too',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster15 Nov 2018Yep', 'level': '', 'counter': 0},
#  {'name': 'John Smith25 Aug 2019So just park $70k & don’t touch it. What is the interest like ? ThanksJunus Eu25 Aug 2019Most accurate info would be straight from the source: https://www.citibank.com.sg/gcb/deposits/mxgn-savacc.h',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Clarence Chua18 Jun 2019While in army I don’t use a %',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster18 Jun 2019How much of my salary would you advise me to keep aside for savings and how much for spending expenditure? \r\n\r\nAlso could you elaborate more on RSP if you don’t mind? I don’t like venturing into stuff I’m not very sure of just like investing.Thaddeus Tan19 Jun 2019Hi anon',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster18 Jun 2019I don’t club or drink so I guess that’s good. Don’t even smoke. \r\n\r\nYes I’m an SCT currently',
#   'level': '',
#   'counter': 0},
#  {'name': 'Wilson Wilson', 'level': '2', 'counter': 0},
#  {'name': 'Kenichi Xi28 Sep 2018Do', 'level': '', 'counter': 0},
#  {'name': 'Tan Boon Hian', 'level': '1', 'counter': 0},
#  {'name': "Question Poster04 Oct 2018Hmm CIMB don't need to i think for me and my bf we have no issue with this :) Tan Boon Hian13 Oct 2018I see",
#   'level': '',
#   'counter': 0},
#  {'name': 'Fan ZD12 Jun 2019Just a question - the remix account seems to have been converted. I only see a DBS Savings Plus on the portal. Does it still have the same benefit',
#   'level': '',
#   'counter': 0},
#  {'name': 'Stanley Teo17 Jul 2019😱 u got over the hurdle of integrating with the banks... but cannot allow export of data?',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster15 Dec 2018How long will I receive the DCS letter after CDP approval? Lok Yang Teng16 Dec 2018You will receive a letter from SGX informing you on the final status of the application within 2 weeks from the application date (acceptance or rejectio',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ching Shy Lim20 Sep 2018Is US Etf subjected to tax?Gabriel Lee20 Sep 2018Yes',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 5 comments Christopher How19 Sep 2018If the truth is a cheap shot',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou19 Sep 2018Another very good answer',
#   'level': '',
#   'counter': 0},
#  {'name': 'Yi Fong Tan25 Sep 2018Second this!! "$14mil could last 3 generations without even investing since you seem to be very prudent in your lifestyl',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou19 Sep 2018I love this comment haha "If this is true... congratulations. Also',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leck Ting Yan', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong20 Sep 2018Good advice! Love the thought for the future generatio',
#   'level': '',
#   'counter': 0},
#  {'name': 'Tan YapSheng', 'level': '2', 'counter': 0},
#  {'name': 'Kenneth Lou19 Sep 2018That is pretty interesting... private placement programs! :',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster19 Nov 2018Hi Andrew', 'level': '', 'counter': 0},
#  {'name': 'See all 5 comments Alcander Seow16 Jun 2019Do I need to buy insurance to get the guarantee from SDIC?Tan Wei Ming16 Jun 2019It is not a local bank. However',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Fan ZD12 Jun 2019Quite safe. Covered by SDIC up to 75k too. Anyways',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 3 comments Pat17 Jun 2019You can't withdraw fixed deposits during the period which you have placed it with them and you will get a fixed interest rate of 1.5-2.0% (based on current schemes). You can only place fresh funds with the bank for fixed deposits. Most banks require a min of 10/20k placement for the fixed deposits so only consider this option if you have sufficient savings. If not",
#   'level': '',
#   'counter': 0},
#  {'name': 'Gabriel Tham03 May 2019Haha dang...thought can hack..credit just spend $1 hack. Maybe can find a cheap plan',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Kenneth Lou16 Dec 2018Thanks for sharing your experience too HC!HC Tang16 Dec 2018Thanks b',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 3 comments Kenneth Lou20 Dec 2018Yeah but it's not the best way to do it leh... but at the same time this is capitalism at work hahaLoh Tat Tian20 Dec 2018Can't control what promoters of product do right. Marketing is all about exploiting peoples weakness sadly",
#   'level': '',
#   'counter': 0},
#  {'name': '佩珊17 Sep 2019Cos have apply that cardcare protection that’s y I Wan to know what is wrking f',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jacqueline Yan13 Sep 2019No queues at the ATM plus can use PayNow to withdraw mone',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Question Poster04 Dec 2018Now wondering if stashaway can invest in IWDA? HC Tang04 Dec 2018Can post a new question',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster04 Dec 2018Thank you very much for your advice. Will continue to do so by increasing the standing order on a consistent basis than to do a lump s',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 7 comments JDJohn Doe15 May 2019Yes but am not looking for a hack.  The multipler Account is a separate account which will earn higher interest.  The joint account where salary is credited only earns base interest.  I am looking for a joint account which is multipler and will earn higher than base interest upon salary creditHC Tang15 May 2019Not that I know off at the moment. Easiest and closest way is that you could turn one of the two DBS multiplier as joint and save combine funds there and leave the join account as it is. Once it hits the cap for high interest',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster08 May 2019Thank you! How much is the amount in the savings to get 75k back?Gabriel Tham09 May 2019I am not sure I understand you. But SDIC will insure your savings up to 75k. \r\n\r\nhttps://www.straitstimes.com/business/banking/higher-deposit-safeguards-insurance-policy-protection-for-private-hire-drivers-ki',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster08 May 2019Alright understood. Ive transfer some money in there and will also close it then',
#   'level': '',
#   'counter': 0},
#  {'name': "Martin Low28 Apr 2019But how come the bonus interest become constant amt? Not compounded?Ang Yee Gary29 Apr 2019If I am not wrong it is incremental balance that's gets the special interest rat",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou02 Oct 2018Cool comment... the best way to learn to is to do it yourself! In fact',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 5 comments Adriel Thin02 Oct 2018I think there's no harm in seeking the advice of an adviser",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Teo See Hwa03 Oct 2018understand',
#   'level': '',
#   'counter': 0},
#  {'name': 'NNinja4w agoFake news lol. The jumpstart account remains at 2% if total amount in bank is less than $20000. Above 27 years old does not reduce the ratesLow San Zeng4w agoOhh is it? Cos that time I went to the scb bank and ask about the interest rate after 27',
#   'level': '',
#   'counter': 0},
#  {'name': 'Low San Zeng3w agoNice! Thanks for confirming!Kenneth Lou3w agoHaha awesom',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou30 Aug 2019I totally agree!NNinja30 Aug 2019Ocbc then dbs then uob. Uob is the last to catch',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ivan Ho23 May 2019This is the only way I found out & tried. Which also means 2 entries is a must & having to bear in mind the ‘+/-‘ at which account every time. It will be really nice to have a single entry function having able to indicate within the single entry',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ivan Ho23 May 2019I understand what you mean',
#   'level': '',
#   'counter': 1},
#  {'name': 'Yong Kah Hwee28 Oct 2018oops', 'level': '', 'counter': 0},
#  {'name': 'Kishor Bhagwat23 Mar 2019You are right. However can I suggest you rephrase the part "different lengths of maturity BUT the same level of risk" ? because that is technically incorrect. If they had same level of risk',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou29 Mar 2019Solid answer @Isaa',
#   'level': '',
#   'counter': 0},
#  {'name': 'ASAbhishek Singh', 'level': '2', 'counter': 0},
#  {'name': 'See all 8 comments Lee Jiahui15 Apr 2019I did oa to sa transfer and switched to cash repayment for loan in 2013 (the yr matters more than age cos back then property and stock prices were high). The main consideration then a growing warchest with nothing to buy. Back then the plan was to reach FRS asap. In 2015 when stock prices fell',
#   'level': '',
#   'counter': 0},
#  {'name': "Hariz Arthur Maloy06 Mar 2019It's a rule of thumb. Your age should be the % of bonds in your portfolio. So if you're 25",
#   'level': '',
#   'counter': 0},
#  {'name': 'Thaddeus Tan19 Mar 2019WOW! Solid chart m',
#   'level': '',
#   'counter': 0},
#  {'name': 'Linda Tan01 Apr 2019I see! thanks again for the answer Hariz. Do you know if there are other bonds that I can compare SSBs with?Hariz Arthur Maloy01 Apr 2019US Treasuries. But then you take on currency risk. You can also try investment grade quasi sovereign bonds',
#   'level': '',
#   'counter': 0},
#  {'name': 'Linda Tan03 Apr 2019Thank you for your well wishes',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster05 Nov 2018Thank yo', 'level': '', 'counter': 0},
#  {'name': 'Thaddeus Tan28 Mar 2019SOLID ANSWER BR', 'level': '', 'counter': 0},
#  {'name': 'See all 3 comments Gabriel Tham02 Jun 2019Well if u sell before going to CDP',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ross Mammino', 'level': '2', 'counter': 0},
#  {'name': 'Osama Agami', 'level': '1', 'counter': 0},
#  {'name': 'Kenneth Tan', 'level': '1', 'counter': 0},
#  {'name': 'Ross Mammino24 Jun 2019I disagr', 'level': '', 'counter': 0},
#  {'name': 'Ross Mammino07 Jul 2019This is so helpful',
#   'level': '',
#   'counter': 0},
#  {'name': 'Engr Invest', 'level': '2', 'counter': 0},
#  {'name': 'Ho Shu Yuan20h agoThank Yo', 'level': '', 'counter': 0},
#  {'name': 'Gabriel Tham19 Nov 2018actually im not sure about it leh...like so many are taking these same courses',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster23 Sep 2019Hi! Ehh not really sure the diff roles yet so was thinking of learning more! But based in descriptions',
#   'level': '',
#   'counter': 0},
#  {'name': 'Igor Kaparis', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster08 Sep 2019Thank you! I’m a person with low confidence and I’m always doubting myself. I guess I will give myself myself more time and figure it out. Thanks for your advise!Hariz Arthur Maloy08 Sep 2019Remember',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster11 Sep 2019Thank you very much for your valuable insights! I will take all these into consideration before making my decisi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Xinyi Lum28 Nov 2018So encouraged by your answer',
#   'level': '',
#   'counter': 0},
#  {'name': 'Yuhan Lian', 'level': '3', 'counter': 0},
#  {'name': 'Tee-Ming Chew28 Nov 2018How was your experience with https://www.thoughtworks.com/jumpstart and how does it fare against General Assembly WDI?Kenneth Lou28 Nov 2018💪🏼 Solid advice m',
#   'level': '',
#   'counter': 0},
#  {'name': 'Charmaine Lim Xiaomei27 Nov 2018Linkedin will be the perfect platform to get advices! People there are generally quite friendly t',
#   'level': '',
#   'counter': 0},
#  {'name': 'Eva HJ', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster28 Nov 2018What side projects have you don',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jason Han', 'level': '2', 'counter': 0},
#  {'name': "See all 4 comments Jason Han03 Dec 2018Singapore Technologies Jason Han03 Dec 2018You don't have to go to university to learn. Some subjects u do like Physics Chemistry Biology etc because you can't afford the scientific equipment to learn these stuf",
#   'level': '',
#   'counter': 0},
#  {'name': 'Eric Loh', 'level': '2', 'counter': 2},
#  {'name': 'AAlexander03 Sep 2019Sounds like a great idea! Thank you very much',
#   'level': '',
#   'counter': 0},
#  {'name': 'AAlexander29 Aug 2019Industrial and Systems EngineeringGabriel Tham29 Aug 2019You can try the Professional conversion programme by skillsfuture \r\nhttps://conversion.mycareersfuture.sg/portal/ProgramDetails.aspx?ProgID=P000004',
#   'level': '',
#   'counter': 0},
#  {'name': "D29 Aug 2019I've emailed the HR team last week",
#   'level': '',
#   'counter': 0},
#  {'name': "WMWeber Mak20 Aug 2019Smile and leave it unanswered until you signed and confirmed the jobJacqueline Yan25 Aug 2019Luckily my colleagues didn't really ask me much. But yea",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster15 Aug 2019Thanks for the input',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ernest Yeam Wee Leong22 Jul 2019End of the day',
#   'level': '',
#   'counter': 0},
#  {'name': 'Yeap Ming Feng16 Jul 2019This is so helpful! Addresses some of my problems as wel',
#   'level': '',
#   'counter': 0},
#  {'name': 'Dousa Moobee', 'level': '2', 'counter': 0},
#  {'name': 'Darius MC', 'level': '1', 'counter': 1},
#  {'name': 'Darius MC22 Jul 2019For all other job openings - https://go.99.co/caree',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments SShieleen09 Jul 2019Hard to determine as it depends on the company culture. But likely yes they will judge. Business is rather general and it shouldn’t be a problem as it compliment current skills set. If you can juggle between studies and work',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster02 Jul 2019Hmm cos as an applicant its usually recommended we specify a salary range to show we are flexible',
#   'level': '',
#   'counter': 0},
#  {'name': 'Saleha Zoè', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster02 Jul 2019Have you had success where the HR shared the hiring budget with you? so far everytime i ask',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 4 comments Justin Kieran Ong10 Jun 2019I'm not too sure about the exact process but judging from the rest of the Aerospace insudtry it's probably something like this. \r\n\r\nWhen you are selected",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster05 Jun 2019Hmm but i dont know why i want to join a specific company though....i just know i want to upgrade from SME to MNC...any MNC doesnt matter to meJunus Eu05 Jun 2019Why exactly do you want to join an MNC? Because there are also people in MNCs who want to join smaller companies',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster05 Jun 2019Yea big brand names',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster05 Jun 2019Better benefits are my only concern though...SME benefits are shitty in SG. Even leave entitlement is 12 day haha...MNC I think minimum is 16-18 days. Plus my SME no medial claimsJacq Ng05 Jun 2019I see.. but in terms of the role that you will be applying for? i think you can focus on what you can bring to the company during the interviews.. in this case',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Christopher Tan25 May 2019Well written Thad!Thaddeus Tan27 May 2019Thank you Christoph',
#   'level': '',
#   'counter': 0},
#  {'name': 'Chuin Ting Weber19 May 2019Hi Thaddeus', 'level': '', 'counter': 0},
#  {'name': 'Question Poster02 May 2019Hi', 'level': '', 'counter': 0},
#  {'name': 'Question Poster27 Apr 2019Thanks for your input Clarence',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster27 Apr 2019Thank a lot Hariz! Appreciate',
#   'level': '',
#   'counter': 0},
#  {'name': "Kenneth Lou20 Apr 2019Really good answer Billy. :) Couldn't agree mor",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster15 Apr 2019Nice pep talk! will take the leap of faith and hopefully survive probatio',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 3 comments Hariz Arthur Maloy03 Apr 2019You wouldn't know if the new job will give you yearly raises though. Might even out sooner than you think. Is there a possible promotion on the cards as well?Question Poster05 Apr 2019Yea promotion is definitely out. Small company",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou28 Nov 2018Good well thought out answer',
#   'level': '',
#   'counter': 0},
#  {'name': 'Nau Hauser29 Nov 2018Agree get a nanny so if one has a child later must have the means to look after it wel',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong28 Nov 2018Long time no see',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jimmy Ong', 'level': '2', 'counter': 0},
#  {'name': 'Ronald Chiam05 Dec 2018nicely sai', 'level': '', 'counter': 0},
#  {'name': "See all 5 comments Nau Hauser29 Nov 2018Thanks fof the links! Having kids is a huge responsibility and it should be balanced with whether one is ready emotionally not only just physically. Definitely tougher when you're older but the focus is on the child if one isn't ready I feel the kid will definitely suffer too. Nau Hauser29 Nov 2018Oops i typed a reply it was erased? Thanks for the links",
#   'level': '',
#   'counter': 0},
#  {'name': 'Lishi Chia', 'level': '2', 'counter': 0},
#  {'name': 'Julian Goh', 'level': '2', 'counter': 0},
#  {'name': 'Wen Ling Chia', 'level': '1', 'counter': 0},
#  {'name': 'Ng Cheekoon', 'level': '1', 'counter': 0},
#  {'name': 'Leong Wen Fong05 Dec 2018Lol wh', 'level': '', 'counter': 0},
#  {'name': 'See all 5 comments Gabriel Tham14 Dec 2018wear the uncle shirts....u know those checkered ones....and wear those gold rolexElsa Goh16 Dec 2018Thanks al',
#   'level': '',
#   'counter': 0},
#  {'name': 'Geraldine Chua', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong17 Dec 2018Actually I find this answer really good! Very balance',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong14 Dec 2018Hahaha Asian very hard to grow facial hair lehJeff Yeo17 Dec 2018I also think so. I can’t grow one that is even',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong14 Dec 2018this one', 'level': '', 'counter': 0},
#  {'name': 'SHSamir Harold Syirazi', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster03 Mar 2019Hey', 'level': '', 'counter': 0},
#  {'name': 'Reagan Goh', 'level': '1', 'counter': 1},
#  {'name': 'Leetho Lo', 'level': '1', 'counter': 0},
#  {'name': 'Leetho Lo02 Feb 2019Hey luke', 'level': '', 'counter': 0},
#  {'name': 'Godson Alexander Moo28 Jan 2019Thanks for sharing',
#   'level': '',
#   'counter': 0},
#  {'name': "Celine Sze Lin Tan17 Jan 2019? What do you mean Godson Alexander Moo28 Jan 2019Don't forget to be pragmatic. Do what you like",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Gabriel Tham10 Jan 2019he mentioned not challenged at work. Can just say looking for a more challenging role to develop and grow skillsets....Loh Tat Tian11 Jan 2019Then if the role is meant to conform',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Leong Wen Fong28 Dec 2018Hmm',
#   'level': '',
#   'counter': 0},
#  {'name': 'Victor Khoo', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster31 Jan 2019thank', 'level': '', 'counter': 0},
#  {'name': 'Guan Cong', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster11 Dec 2018Thanks for the advice. Career wise',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster11 Dec 2018Hi', 'level': '', 'counter': 0},
#  {'name': 'See all 3 comments Heng Kai Le08 Jun 2019I like the way you distinguish between startup & MNC',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 6 comments Gabriel Lee04 Dec 2018Well written!Xinyi Lum05 Dec 2018Thank you for sharin',
#   'level': '',
#   'counter': 0},
#  {'name': 'Fransiska Darjanto-Lai', 'level': '3', 'counter': 0},
#  {'name': "Leong Wen Fong04 Dec 2018Haha I'm on Pawshake too! but I didn't really apply on anythi",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou01 Dec 2018This is very true: "Kindness is a virtue and you should not let this change. Just need to say no sometimes and be kind towards yourself as well',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong11 Dec 2018Hi Daniel! I sent you an email recently',
#   'level': '',
#   'counter': 0},
#  {'name': 'HC Tang06 Jun 2018Excellent way of spending the 1k or 2k bro!:) Upgrad',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kim Choo So', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster23 Nov 2018Thanks so much for sharing! Tourism has always been a popular sector',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster21 Nov 2018Haha which is kind of what I'm trying to do here! Mind telling me a bit of what you do",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster21 Nov 2018Banking/ insurance/ investment kindYixiong Chang22 Nov 2018Insurance (sales - think insurance agent) u just need a few regulatory papers. Insurance (actuary - u will prob need a degree in statistic or related field). \r\nThe others like banking',
#   'level': '',
#   'counter': 0},
#  {'name': 'Phil Yip', 'level': '2', 'counter': 0},
#  {'name': 'Jay Teo Jun Kai', 'level': '1', 'counter': 0},
#  {'name': 'Joe Lek', 'level': '1', 'counter': 0},
#  {'name': 'Meliá Widjaja07 Dec 2018So true. Also', 'level': '', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Nov 2018Wa great idea for OP',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster26 Nov 2018I think you misunderstood the question..Casey Choo26 Nov 2018oh haha! You're right! I guess the same train of thought could be applied (albeit with slightly different metrics",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster25 Nov 2018But those who earn higher are not the majority right? Since statistics shows that SMU graduates earn a starting salary of around $3k+Yong Kah Hwee25 Nov 2018if you want to look at majority i think should should look at the median',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster22 Nov 2018I'm just generally curious how some people are earning much more than others and what kind of jobs they d",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster22 Nov 2018Very cool... What’s CITO',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Yixiong Chang18 Nov 2018You might want to consider topping up your special account.  You will receive tax relief for the topped up amount. Eg',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster14 Nov 2018A pre-U student!Yixiong Chang14 Nov 2018if u go to a local uni',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Jenefar Gomes13 Nov 2018yes you right . but notes',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ho Si Min', 'level': '3', 'counter': 0},
#  {'name': 'Kenneth Lou31 Oct 2018Really good answer! well thought out ha',
#   'level': '',
#   'counter': 0},
#  {'name': 'Elen Winata', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong25 Oct 2018Hello', 'level': '', 'counter': 0},
#  {'name': 'Jane Koo', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster16 Oct 2018Hi there', 'level': '', 'counter': 0},
#  {'name': 'Question Poster15 Oct 2018Ok i will consider this.Right now i am working',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster15 Oct 2018Adobe experience manager! :)Kenneth Lou15 Oct 2018Haha ohhh sorry can't really help you out... let's see how the rest can advise yo",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou15 Oct 2018Lol hey Jen! Do you currently do any part time web design gigs?Jennifer Franslay15 Oct 2018Aye! Not currently',
#   'level': '',
#   'counter': 0},
#  {'name': 'Willy Tan', 'level': '2', 'counter': 0},
#  {'name': 'Jeff Yeo23 Sep 2018Actually as a sales person in any industry they would not review the Comm. It is the job of a sales person to influence the decision of the customer. Sales people who can’t do that are not good sales peopl',
#   'level': '',
#   'counter': 0},
#  {'name': 'Lois19 Jul 2018wow', 'level': '', 'counter': 0},
#  {'name': 'Sor Jiaming Kelvin10 Jun 2018i agree', 'level': '', 'counter': 0},
#  {'name': 'Arev Jr', 'level': '1', 'counter': 0},
#  {'name': 'Kenneth Lou18 Jul 2018Solid reply :) and thanks for sharing. I think the part on the demonstrating if curiousity and interest to level up is very tru',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Gabriel Tham18 Jul 2018haha not much bonus la...but at least its kinda guaranteed bonus + AWS. Private sector wont guarantee a bonus lor....Zongzong19 Jul 2018@kenneth',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou12 Jul 2018What a good analysis! :) haha Hopefully the person considers these factors well.HC Tang12 Jul 2018Thanks Bro. Been there done with some similar situations',
#   'level': '',
#   'counter': 0},
#  {'name': "Liew Jue Yi24 Sep 2019Hmm but I'm not very sure what kind of skills can a contract admin staff under immigration department learn other than paperwork in which people did argue that sooner or later technologies are going to take over the paperwork side of things especially in a hr sectorCedric Jamie Soh4w agoYou got a very good point",
#   'level': '',
#   'counter': 0},
#  {'name': 'Huang Yixuan20 Sep 201', 'level': '', 'counter': 0},
#  {'name': "See all 3 comments Question Poster11 Jun 2019The issue tho is that the scholarship is for a field completely irrelevant to music (engineering) which I'm okay studying but thinking I'd continue teaching music after graduating with an eng degree..Sarah Chan11 Jun 2019Ahh",
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster11 Jun 2019The scholarship is for an engineering course so yep kinda lost as I'm okay studying engineering but I'm not sure if I'll truly enjoy doing what an engineer does in the workforce tho I know I'm cool doing music as a careerSiow Nan11 Jun 2019I graduated from engineering as well",
#   'level': '',
#   'counter': 0},
#  {'name': 'Loh Tat Tian26 Dec 2018Absolutely. Nobody knows what job they like. The only issue here is the 5 years bond. Tahan and got your first pot of gol',
#   'level': '',
#   'counter': 0},
#  {'name': 'Khew Phng Pin', 'level': '2', 'counter': 1},
#  {'name': "Dinesh D'shuttlers", 'level': '2', 'counter': 1},
#  {'name': 'See all 3 comments Junus Eu20 Apr 2019Never too late to start!Bryant Tan03 May 2019Well sa',
#   'level': '',
#   'counter': 0},
#  {'name': 'Serene Toh22 Apr 2019To add on', 'level': '', 'counter': 0},
#  {'name': 'Question Poster06 Jul 2019Thank You! This is so helpful',
#   'level': '',
#   'counter': 0},
#  {'name': 'Mujimoro24 Jun 2019Great idea', 'level': '', 'counter': 1},
#  {'name': 'Mujimoro24 Jun 2019Limiting bonus spend is a good id',
#   'level': '',
#   'counter': 1},
#  {'name': 'Mujimoro24 Jun 2019Agree', 'level': '', 'counter': 1},
#  {'name': 'Question Poster17 May 2019Thanks Hariz!\r\nWhere and how do I start / get more info about CMFAS',
#   'level': '',
#   'counter': 0},
#  {'name': 'NNinja17 Aug 2019I have like five years of f&b experience. Be physical and mentally strong because you’ll be dealing with retards everyday. Not your typical customer but someone that treat you like servan',
#   'level': '',
#   'counter': 0},
#  {'name': 'T@Takingstock @04 Jul 2019Agree I thought about my behaviour and someone else I know',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster04 Jul 2019Hmm even if one has not started first day of work?Elijah Lee04 Jul 2019Yes. It's possib",
#   'level': '',
#   'counter': 0},
#  {'name': 'WOWinnie Ong', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster09 Jun 2019Thanks for replying. Yes i kind of agree with you. I will consider doing something to improve my situation at work. Hopefully it will be less stressful once i have acquired some fundamental skillsets.Heng Kai Le09 Jun 2019In the meantime',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster09 Jun 2019Thanks for your reply. Yes',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster10 Jun 2019Hi Jonathon', 'level': '', 'counter': 0},
#  {'name': 'Question Poster30 May 2019Wow thanks so much! This is so detailed. Probably should start a page for business related questions hahaThaddeus Tan30 May 2019No worries man! Hope it helpe',
#   'level': '',
#   'counter': 0},
#  {'name': 'Lewis Poh27 Apr 2019There’s a bug to the numberi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Heng Kai Le07 Jun 2019Your final point reminds me of something Mark Manson wrote: How do you choose to suffer? (https://markmanson.net/question)\r\nIndeed',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Hao Yu18 Sep 2018There can be many different what ifs scenario but it is hard for an employer to be able to find out all this information in the hiring process. Hao Yu18 Sep 2018There can be many different what ifs scenario but it is hard for an employer to be able to find out all this information in the hiring process. If there is a way to find out',
#   'level': '',
#   'counter': 0},
#  {'name': 'Serene Toh03 Oct 2018I actually considered this probation idea too. I totally agree that its the fairest method. But its not realistic',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong18 Sep 2018Sometimes good attitude may be hard to discern during interviews though! because the person can put on a show about it',
#   'level': '',
#   'counter': 0},
#  {'name': 'Abdul Lutfi', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster12 Jan 2019May I have your means of contact?Abdul Lutfi12 Jan 2019abdul.lutfi146@gmail.c',
#   'level': '',
#   'counter': 0},
#  {'name': "Good Day Every Day25 Oct 2018It's better to check with MOM",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 8 comments HC Tang21 Apr 2019Hi Wen Bin. No worries. Hope some of my suggestions helps you 😀 understand your situation',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou02 Oct 2018Yeah makes sense the bonding part :) Made many friends also from overseas countries who were here to study. bright kid',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou28 Sep 2018Feel free to leave me an anonymous reply here in this post if you may want me to connect you with my pal who was there for 2 years',
#   'level': '',
#   'counter': 0},
#  {'name': 'Singchang Toh26 Sep 2018Any prize for most upvotes?Kenichi Xi26 Sep 2018there is a competition now. \r\n\r\nTop 10 will get free ticket to DR WEALTH REITS COURSE.\r\n\r\nYou can join too.',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Brandan Chen26 Sep 2018Will definitely try to expand my Horizon. At the end of the day',
#   'level': '',
#   'counter': 0},
#  {'name': 'Jay Liu23 Sep 2018Agreed man. Connections are important. Sign a few job contracts as a part timer in the past without needed to be interviewed. HC Tang24 Sep 2018Wow. Great man ! Hope you do even better',
#   'level': '',
#   'counter': 0},
#  {'name': "Jay Liu24 Sep 2018Converting military class 3 licence to civilian licence in 4 months time!!!! Sad can't get class 4 :/Kenichi Xi28 Sep 2018u saved a lot le. Keep it up and progress on. @jay l",
#   'level': '',
#   'counter': 0},
#  {'name': "Pascal Samsoon03 Aug 2018Don't give up. I teach you (not for free) if we can make the time ;",
#   'level': '',
#   'counter': 0},
#  {'name': 'Gabriel Tham29 Aug 2018SEO', 'level': '', 'counter': 0},
#  {'name': "Say Kiat06 Aug 2018Thks for answering. Appreciated. Correct me if I'm wrong: While risk profile remains same or changes due to personal circumstances So it will not be a fix amount from time to time when rebalance is done?  Can explain how do u do the rebalance part like for my investment assets stock n bonds if deviated >5%",
#   'level': '',
#   'counter': 0},
#  {'name': 'Loh Tat Tian21 Feb 2019Expectations and communications well explained. :) thumbs upHC Tang21 Feb 2019Thanks bro :) Looking forward to learn a lot from you too on insurance',
#   'level': '',
#   'counter': 1},
#  {'name': 'See all 3 comments Randy Chai18 Jun 2019Way to promote your services @Huang YixuanThaddeus Tan18 Jun 2019The part on "your job scope will consist of multiple roles across various functions" is so true. thanks for the answer @Randy Chai This is so helpful',
#   'level': '',
#   'counter': 0},
#  {'name': 'William Ng26 Apr 2019I am doing grab part time for past 1+ year. It’s not as good as before. I suggest do other part time job like dropshipping',
#   'level': '',
#   'counter': 0},
#  {'name': 'LZLeon Zheng', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster30 Jul 2019Hi Hariz', 'level': '', 'counter': 0},
# ...
#   'level': '',
#   'counter': 0},
#  {'name': 'Anthony Lopez', 'level': '1', 'counter': 0},
#  {'name': 'Bryant Chua', 'level': '1', 'counter': 1},
#  {'name': 'Lawrence Yip', 'level': '2', 'counter': 2},
#  {'name': 'Kenris Neo', 'level': '1', 'counter': 0},
#  {'name': "Hariz Arthur Maloy23 Oct 2018IFA also doesn't mean fee based mah",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Shawn Lee05 Nov 2018Sure',
#   'level': '',
#   'counter': 0},
#  {'name': 'Thomas Ng', 'level': '1', 'counter': 0},
#  {'name': 'Luke Ho24 Jan 2019Net or Gross? Starting to sound like me',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Kenneth Lou23 Jan 201950k for SDIC insurance',
#   'level': '',
#   'counter': 0},
#  {'name': 'Linda Tan29 Mar 2019Oh yes thank you Gabrie',
#   'level': '',
#   'counter': 0},
#  {'name': 'Nick Tan', 'level': '2', 'counter': 0},
#  {'name': 'Question Poster07 Aug 2019Thanks! Have just set up an automatic giro arrangement for my credit card. Silly question - but are there any extra risks to be aware of',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster07 Aug 2019Sure', 'level': '', 'counter': 0},
#  {'name': 'See all 3 comments Lim Chun Long Jimmy04 Sep 2018Haha',
#   'level': '',
#   'counter': 0},
#  {'name': 'Daniel Loke', 'level': '2', 'counter': 0},
#  {'name': "See all 3 comments Daniel Loke17 Sep 2018Not sure which additional detail u were referring me to? There are some areas in the question that is pretty vague so I didn't want to assume things. For E.g 1",
#   'level': '',
#   'counter': 0},
#  {'name': 'Hariz Arthur Maloy02 Nov 2018Buying a stock each month with only 100 bucks would be too ex for the transaction cost thoug',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Question Poster16 Oct 2018I have around $10',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Gerard Ong16 Oct 2018Hi QP',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster16 Oct 2018Yep haha', 'level': '', 'counter': 0},
#  {'name': "See all 6 comments Alvin Teo06 Oct 20183. Still can consider sale of balance flats...only advantage is shorter waiting time typically. Got mine in a year. HC Tang06 Oct 2018WOW! That's nice man. Usually SBF harder to get. Honestly BTO also hard to get. Haha. Hope all who apply get soon so no further delay",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou05 Oct 2018Thanks for sharing this... really meaningful... especially on doing all these before baby duties come :) Thank you! "I probably would have done a lot more things I had wanted to try before baby duties (like mba',
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong20 Sep 2018Oh the mindset thing is so true',
#   'level': '',
#   'counter': 0},
#  {'name': 'Serene Toh17 May 2019Interesting concept of considering CPF as "Bond" component. I was worrying over my portfolio allocation recently',
#   'level': '',
#   'counter': 0},
#  {'name': 'CLChuan Lee', 'level': '2', 'counter': 0},
#  {'name': 'See all 6 comments Question Poster22 May 2019Has anyone compared the cost of DIYing via SC using iWDA+VWRD+EIMI vs DFA? Will probably do the former if there is enough savings..Gabriel Tham22 May 2019The cost of DIY into ETFs are definitely lower than an advisory based DF',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster22 May 2019Problem is I already know what I want',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ferlyn Tan', 'level': '1', 'counter': 0},
#  {'name': 'Kenneth Lou29 May 2019Awesome thanks for replying @Roger! Hopefully David',
#   'level': '',
#   'counter': 0},
#  {'name': 'David Loh', 'level': '1', 'counter': 0},
#  {'name': 'Thaddeus Tan28 Mar 2019Wow', 'level': '', 'counter': 0},
#  {'name': 'Bao Ren Kho30 Apr 2019How much is the administrative fe',
#   'level': '',
#   'counter': 0},
#  {'name': 'JLJaep Lee4w agoCan share the codeLuke Ho2w ago0Q6',
#   'level': '',
#   'counter': 0},
#  {'name': 'Yingying Li', 'level': '2', 'counter': 1},
#  {'name': 'See all 4 comments Yingying Li23 Apr 2019Hey Alex',
#   'level': '',
#   'counter': 1},
#  {'name': 'Kenson Tan', 'level': '3', 'counter': 1},
#  {'name': 'Alex Chua Cheng En17 Apr 2019I have posted quite a few times but seems that no one see',
#   'level': '',
#   'counter': 1},
#  {'name': 'Jacky Yap18 Jun 2018oh sorry to add on - if there are any defaults',
#   'level': '',
#   'counter': 0},
#  {'name': 'Vikas Jain', 'level': '2', 'counter': 1},
#  {'name': 'Ling Koh', 'level': '2', 'counter': 0},
#  {'name': 'Tina Sharon Lee20 Jul 2018Oh if you decide to withdraw Sterling Pounds from the DBS MCA  they will charge you a fee...if not mistaken about 1.5% for Sterling Pounds! F',
#   'level': '',
#   'counter': 0},
#  {'name': 'Loh Tat Tian26 Sep 2018you mean there is no workaround? Unless i top-up her RA to BR',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster24 Jun 2019Thank you for thi',
#   'level': '',
#   'counter': 0},
#  {'name': 'JLJ L', 'level': '2', 'counter': 2},
#  {'name': 'Question Poster24 Jun 2019Thanks for thi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster24 Jun 2019Thank Yo', 'level': '', 'counter': 0},
#  {'name': 'Ashley Lin', 'level': '3', 'counter': 1},
#  {'name': 'Heng Kai Le09 Jun 2019Indeed. aim big', 'level': '', 'counter': 0},
#  {'name': 'Question Poster05 Jul 2019Thank Yo', 'level': '', 'counter': 1},
#  {'name': 'Question Poster05 Jul 2019Thank You!Question Poster05 Jul 2019This is so helpful',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kevin Zyleon Ng', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong23 Oct 2018I would think though',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Hariz Arthur Maloy08 Oct 2018If standalone term',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster08 Oct 2018thank you this is vv helpful!Yinglin Chua09 Oct 2018No prob..  just also take note of Tat Tian's comments on the accelerated CI vs fixed sum CI on how the policy works. Just make sure it's aligned to your needs - can consider layering if necessar",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Loh Tat Tian08 Oct 2018Tough question to answer as I do not have all the figures. My rule of the thumb for this is simple. For CI cost versus multipay',
#   'level': '',
#   'counter': 0},
#  {'name': 'Mabel Tan04 Oct 2018No worries! Hope it helps. If that’s the case',
#   'level': '',
#   'counter': 0},
#  {'name': 'Joel Lok', 'level': '1', 'counter': 1},
#  {'name': 'Vincent Chong', 'level': '1', 'counter': 0},
#  {'name': 'Jarett Jeyadas Mathew', 'level': '1', 'counter': 0},
#  {'name': "See all 3 comments Leong Wen Fong16 Nov 2018Interesting!! Didn't know that!Yixiong Chang16 Nov 2018Can watch the opening bell on cnbc",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster27 Oct 2018For now I have other cash parked in conservative instruments like SSBs',
#   'level': '',
#   'counter': 0},
#  {'name': "Linda Tan01 Apr 2019Hi Hariz. You wouldn't leave any place for SSBs?Hariz Arthur Maloy01 Apr 2019SSB is a bond. Thus forming part of your bond allocation.",
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster23 Mar 2019Thanks alot Nicholas! helped me to understand the issue much better now :) Cheer',
#   'level': '',
#   'counter': 0},
#  {'name': "Question Poster29 Dec 2018I guess that will require me to actively seek out for them. Or will they call me up?Lok Yang Teng29 Dec 2018You'll need to have a sufficient pool of followers first. Then it'll be easier for your own initiation to get sponsor",
#   'level': '',
#   'counter': 0},
#  {'name': 'Hariz Arthur Maloy30 Oct 2018Disagree man. Insurance is guaranteed. This is an investment because prices can drop and rise.Good Day Every Day30 Oct 2018Perhaps I should say it acts both like insurance and investment since it hedges against inflation and it could also rise and fall in value',
#   'level': '',
#   'counter': 0},
#  {'name': 'Faihan Haque', 'level': '1', 'counter': 0},
#  {'name': 'Luke Ho15 Oct 2018You typically clean-stroke your bar of gold or silver in a quiet room wearing nothing but your underwear and whisper',
#   'level': '',
#   'counter': 0},
#  {'name': 'Question Poster27 Sep 2018Thank you for your input... do you also invest in this stock? Im considering n',
#   'level': '',
#   'counter': 0},
#  {'name': "Ching Shy Lim20 Sep 2018Any short term endowment to recommend?Dominic Chang05 Dec 2018Not looking at any at the moment. I remembered there was once FWD was offering 3 years @ 2.02%. But this month's SSB should even beat th",
#   'level': '',
#   'counter': 0},
#  {'name': 'Serene Toh20 Sep 2018Agree. in addition',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ng Hui Qun', 'level': '2', 'counter': 1},
#  {'name': 'Eric Chia16 Aug 2018Just to add on to what Brandan wrote',
#   'level': '',
#   'counter': 0},
#  {'name': 'Abhilasha Singh', 'level': '2', 'counter': 1},
#  {'name': 'CK Chua', 'level': '1', 'counter': 0},
#  {'name': 'Yap ZL', 'level': '1', 'counter': 0},
#  {'name': 'Question Poster11 Jun 2019:( need to learn to be content to attain happine',
#   'level': '',
#   'counter': 0},
#  {'name': 'JJoel04 May 2019Agreed. You gotta factor in the cost of car ownership in Singapore. Owning a car is just for convenience and in this day and age',
#   'level': '',
#   'counter': 0},
#  {'name': 'JJoel', 'level': '2', 'counter': 0},
#  {'name': 'Donald Kieran Ang07 Apr 2019I think you should network and learn to get to know more people. Go out and travel more often. Spend time with people that makes u happy as usually the happiest things in life are fre',
#   'level': '',
#   'counter': 0},
#  {'name': 'Woo Wanxin', 'level': '2', 'counter': 0},
#  {'name': 'Jing Xin Long10 Aug 2019This is so helpful',
#   'level': '',
#   'counter': 0},
#  {'name': 'Samuel Chin07 Aug 2019One tip that I always adopt in purchasing things is on: mileage. Meaning how often am I going to use it',
#   'level': '',
#   'counter': 0},
#  {'name': 'David Morgan13 Jun 2019But my advices excludes emergency fund and spending. That’s when most would crumble with the consistency. And never ever default on your payments. Late fee interest can snowball if your debtor is standard chattered especiallyGabriel Tham13 Jun 2019Thank you for helping and sharing your experience! Glad you are debt free no',
#   'level': '',
#   'counter': 1},
#  {'name': 'Syafiq Samri', 'level': '1', 'counter': 3},
#  {'name': 'Shaun Ong', 'level': '3', 'counter': 0},
#  {'name': "See all 4 comments Leong Wen Fong25 Oct 2018What's the conditions and implications of declaring bankrupt?Teo See Hwa30 Oct 2018https://www.ccs.org.sg/ call th",
#   'level': '',
#   'counter': 0},
#  {'name': 'Yixiong Chang30 Oct 2018"Let ur mum declare bankrupt after withdrawing all the cash from bank or join accounts." \r\nPlease do not advise on this. It is an offence to dispose of the property knowingly that u will be declaring bankrupt. It applies to the person receiving the property. \r\n\r\nYou are required to list all your assets with the official assignee (including assets and their value sold/gifted away within 5years from date of bankruptcy). The official assig... (more)Kenichi Xi31 Oct 2018agr',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 4 comments Kok Koon21 Sep 2018nice! v good analysis. This analysis also assumes poster can keep job that long and economy and interest rates holds at current (peak of equity markets). For poster's considerationHC Tang21 Sep 2018Haha. Nobody can guaranteed jobs and interest rate forever.  Still have to keep investing balance savings for future and if lost of job",
#   'level': '',
#   'counter': 0},
#  {'name': "Kok Koon21 Sep 2018Solid sharing! Exactly what's on my mind suppose I'm on my MOP year. FI vs condo. If it's 20 years ago",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kok Koon21 Sep 2018$4k savings a month for 2 pax is really not a lot.Jessica Tan22 Sep 2018I totally concur w Kok Koon. With 10k combine stick to present home n don’t even think of upgrade to private',
#   'level': '',
#   'counter': 0},
#  {'name': 'JY Xie', 'level': '3', 'counter': 0},
#  {'name': 'DSDaniel Soh05 Aug 2019This is so helpful 👍Charlotte Ang05 Aug 2019Ty for thi',
#   'level': '',
#   'counter': 0},
#  {'name': 'Xander Lim21 Jun 2019To add on.. Now I am using the Image Search n Camera Seach function.. Go try i',
#   'level': '',
#   'counter': 0},
#  {'name': 'Sheena Sng', 'level': '1', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Sep 2018actually thats pretty true! Spend money to save time or spend time to save mon',
#   'level': '',
#   'counter': 0},
#  {'name': 'Wendy Lee', 'level': '1', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Sep 2018haha care to share some tip',
#   'level': '',
#   'counter': 0},
#  {'name': 'Ng Jun Siang', 'level': '1', 'counter': 0},
#  {'name': "Leong Wen Fong17 Sep 2018Oh that's a pretty good thought flow",
#   'level': '',
#   'counter': 0},
#  {'name': 'Ham Dominic', 'level': '3', 'counter': 1},
#  {'name': 'Kenneth Lou20 Oct 2018Very cool indeed :) thanks for sharing. lol didnt know about this. pretty coo',
#   'level': '',
#   'counter': 0},
#  {'name': 'Xander Lim21 Jun 2019To add on.. Now I am using the Image Search n Camera Seach function only for shopping.. Go try i',
#   'level': '',
#   'counter': 0},
#  {'name': "See all 5 comments Matthew Ng26 Oct 2018He should seek Andy's dadLeong Wen Fong07 Nov 2018Congratulations Rave! You are the clear winner of the Halloween Giveaway! I will be contacting you shortly for the priz",
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments Shaun Goh26 Oct 2018Sometimes I stress over this and forget the cashback is less than 1 cent :( Kenneth Lou26 Oct 2018lol first world horror story ha',
#   'level': '',
#   'counter': 0},
#  {'name': 'Elsa Goh26 Oct 2018LONG TIME NO SEE.Kok Koon26 Oct 2018I\'ll reply: "I\'m out of job recently. Can you lend me some money',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 4 comments Kok Koon26 Oct 2018Free power bank.Nicholes Wong26 Oct 2018MLM: Do you want to be your own boss? (but too lon',
#   'level': '',
#   'counter': 0},
#  {'name': 'Nellie Lim', 'level': '3', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Oct 2018This actually happened to me before',
#   'level': '',
#   'counter': 0},
#  {'name': 'See all 3 comments HC Tang26 Oct 20182 or 5 ah. Exclude the ”or" 😜HC Tang26 Oct 2018Added another one just nice 5 words',
#   'level': '',
#   'counter': 0},
#  {'name': 'Yeap Ming Feng26 Oct 2018Cause the Ang Bao rate is the Top 5 in Singapore: https://blog.seedly.sg/how-much-wedding-ang-bao-rates/HC Tang26 Oct 2018Wedding at the "Istana" :P hahah',
#   'level': '',
#   'counter': 0},
#  {'name': 'Carrie Sim-Goh', 'level': '2', 'counter': 0},
#  {'name': "See all 8 comments Bear Cranky27 Oct 2018DON'T buy insurance from friends!Kenneth Lou30 Oct 2018wow... tough ones.",
#   'level': '',
#   'counter': 0},
#  {'name': 'Leong Wen Fong26 Oct 2018CongratsKenneth Lou26 Oct 2018lol lol nice on',
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou26 Oct 2018Wah. "buy apple stoc',
#   'level': '',
#   'counter': 0},
#  {'name': 'Shaina Catalina Peh', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Oct 2018Hahaha anything with the word "loa',
#   'level': '',
#   'counter': 0},
#  {'name': "Kenneth Lou26 Oct 2018lol hahaha. 2 carrots more like it.HC Tang26 Oct 2018🥕🥕 That's easy",
#   'level': '',
#   'counter': 0},
#  {'name': 'Kenneth Lou26 Oct 2018Wow that 1) is a big one. hahaLeong Wen Fong26 Oct 2018LOL this one really quite horr',
#   'level': '',
#   'counter': 0},
#  {'name': 'Liew Xun', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong26 Oct 2018amount better increase al',
#   'level': '',
#   'counter': 0},
#  {'name': 'Nathan Koh', 'level': '2', 'counter': 0},
#  {'name': 'Leong Wen Fong30 Oct 2018wa this one heart really can stop one l',
#   'level': '',
#   'counter': 0},
#  {'name': 'Bob Li', 'level': '2', 'counter': 0},
#  {'name': 'See all 3 comments Daniel Gan13 Mar 2019Naisee!Charmaine Lim Xiaomei14 Mar 2019Niceeee',
#   'level': '',
#   'counter': 0},
#  {'name': 'Huang Yixuan06 Mar 2019😍Kenneth Lou06 Mar 2019Awesome story man',
#   'level': '',
#   'counter': 0},
#  ...]

# %%
# user_dict = {}

# for user in user_list:
#     user_name = user.get_name()
#     if user_name in user_dict.keys():
#         user_dict[user_name] += 1
#     else:
#         user_dict[user_name] = 1
        
# print(user_dict)
# print(len(user_dict))

# %%
users_df = pd.DataFrame(final_user_list)

# %%
question_askers_df = pd.DataFrame(question_user_list,columns=["Names"])

# %%
question_askers_df
# Out:
#                  Names
# 0     Kuriakin J. Zeng
# 1            Anonymous
# 2            Anonymous
# 3            Anonymous
# 4            Anonymous
# ...                ...
# 5949         Xinyi Lum
# 5950         Anonymous
# 5951         Anonymous
# 5952         Anonymous
# 5953         Anonymous
#
# [5954 rows x 1 columns]

# %%
question_askers_df[question_askers_df["Names"]=="Anonymous"].count()
# Out:
# Names    4990
# dtype: int64

# %%
top_users_df = users_df[users_df["level"]>="4"]

# %%
top_users_df
# Out:
#                name level  counter
# 644         JJeremy     5        0
# 802      Goh Ah Mao     4        1
# 1011       Wynn Teo     4        0
# 1379      David Lim     4        0
# 1578            黎嘉欣     4        0
# ...             ...   ...      ...
# 3789       Jeff Yeo     6      228
# 3791       Junus Eu     8      375
# 3792      Ng Wei En     4        9
# 3795     Leslie Koh     4       33
# 3799  Lok Yang Teng     6      328
#
# [149 rows x 3 columns]

# %%
users_df[users_df["level"]=="5"]
# Out:
#                        name level  counter
# 644                 JJeremy     5        0
# 2621          Cassandra Tho     5        7
# 2962       YMYeap Ming Feng     5        9
# 2973            Vicky Faith     5       10
# 3103               Kok Koon     5       11
# 3121      Ng Lip Hong Kyith     5       29
# 3147           Soon Xiaohui     5       19
# 3179         Yeap Ming Feng     5       34
# 3191              Xinyi Lum     5       29
# 3209            Eveline Lau     5       17
# 3352           Kenneth Fong     5       12
# 3360       Chuin Ting Weber     5        8
# 3488          Nicholas Chan     5      130
# 3534           Tan Wei Ming     5       40
# 3540               Elsa Goh     5       63
# 3560              Tracy Lim     5       24
# 3573             AYAndy Yew     5        8
# 3597             Victor Lye     5       21
# 3604            Sin Ting So     5       21
# 3610               Alan Kor     5       87
# 3615             Harvey Tan     5       79
# 3619            Dhruv Arora     5       21
# 3627         Zen Rogue Xuan     5       58
# 3639              Steph Yeo     5       82
# 3642         Rave Ong Ci De     5       49
# 3655  Ernest Yeam Wee Leong     5       69
# 3656           Eric Ong Cfa     5       18
# 3657            Jonathan Ng     5       30
# 3662            Darren Chew     5       13
# 3674             Dawn Fiona     5       89
# 3681             Lee Jiahui     5       49
# 3689    Vincent Tan Wen Bin     5      105
# 3695             Siti Putri     5       12
# 3697        T@Takingstock @     5      106
# 3708             Serene Toh     5       67
# 3744                 Jim Ng     5       37
# 3748    Lim Chun Long Jimmy     5       56
# 3755          Yixiong Chang     5      203
# 3767             Javier Lim     5       12

# %%
users_df[users_df["level"]=="9"]
# Out:
#                     name level  counter
# 3740          Elijah Lee     9      327
# 3760  Hariz Arthur Maloy     9      877

# %%
users_df[users_df["level"]=="8"]
# Out:
#               name level  counter
# 3713  Gabriel Tham     8      847
# 3739    Isaac Chan     8      314
# 3775       HC Tang     8      355
# 3783   Kenneth Lou     8      403
# 3791      Junus Eu     8      375

# %%
users_df[users_df["level"]=="7"]
# Out:
#                name level  counter
# 3771  Clarence Chua     7      139

# %%
users_df[users_df["name"]=="Ng Wei En"]
# Out:
#            name level  counter
# 3792  Ng Wei En     4        9

# %%
users_df[users_df["level"]>="7"]
# Out:
#                     name level  counter
# 3713        Gabriel Tham     8      847
# 3739          Isaac Chan     8      314
# 3740          Elijah Lee     9      327
# 3760  Hariz Arthur Maloy     9      877
# 3771       Clarence Chua     7      139
# 3775             HC Tang     8      355
# 3783         Kenneth Lou     8      403
# 3791            Junus Eu     8      375

# %%
top_level_users_df = users_df[users_df["level"]>="6"]

# %%
top_level_users_df = top_level_users_df[top_level_users_df["counter"]!=506]

# %%
top_level_users_df
# Out:
#                        name level  counter
# 3260         Leong Wen Fong     6       96
# 3337    Cherie Julianne Tan     6       41
# 3415              CPF Board     6       15
# 3439             Sarah Chan     6       41
# 3649           Thaddeus Tan     6       32
# 3658             Kenichi Xi     6      121
# 3675               Siow Nan     6       78
# 3684               Billy Ko     6       98
# 3706  Richard Woon Tian Jun     6      158
# 3711            Gabriel Lee     6      259
# 3712                Jay Liu     6      126
# 3713           Gabriel Tham     8      847
# 3714          Yong Kah Hwee     6      463
# 3721                Aik Kai     6      120
# 3723           Huang Yixuan     6       39
# 3724        Loo Cheng Chuan     6       67
# 3725          Tee-Ming Chew     6       39
# 3726            Leonard Tan     6      134
# 3728                Luke Ho     6      249
# 3729           Yeo Enk Loui     6      116
# 3732             Sandra Teo     6      153
# 3733              Zann Chua     6      172
# 3739             Isaac Chan     8      314
# 3740             Elijah Lee     9      327
# 3747          Nicholes Wong     6      407
# 3753     Good Day Every Day     6      248
# 3756           Brandan Chen     6      182
# 3757        Christopher Tan     6       59
# 3758           Loh Tat Tian     6      367
# 3760     Hariz Arthur Maloy     9      877
# 3771          Clarence Chua     7      139
# 3773           Charmaine Ng     6       93
# 3775                HC Tang     8      355
# 3783            Kenneth Lou     8      403
# 3789               Jeff Yeo     6      228
# 3791               Junus Eu     8      375
# 3799          Lok Yang Teng     6      328

# %%
users_df
# Out:
#                                                    name level  counter
# 0     Ang Yee Gary27 May 2019Any ball park figure on...              0
# 1                                           Krristy Lam     2        1
# 2                                               Paul Ho     2        0
# 3                   Question Poster04 Aug 2019Basically              0
# 4     Kenneth Lou07 Nov 2018100% agree on the leader...              1
# ...                                                 ...   ...      ...
# 3796                         RyaN Cheong6h agoHi Leslie              0
# 3797                                        RyaN Cheong     2        2
# 3798  RyaN Cheong2w agoMy referral code for revolut:...              1
# 3799                                      Lok Yang Teng     6      328
# 3800                                    Lava Ama A Dios     2        0
#
# [3801 rows x 3 columns]
