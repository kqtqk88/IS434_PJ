# %% [markdown]
# # Instagram Media Data Cleaning

# %%
import os
import pandas as pd
from dateutil import parser
from datetime import datetime, timedelta

dir = os.getcwd()

# %%
# collate data files
files = ["dnssingapore.txt","thewokesalaryman.txt", "seedlysg.txt", "mortgageconsultancy.txt"]

data = pd.read_csv(dir + '\\data\\LikesComments\\dnssingapore.txt', delimiter = "\t")
data = data.append(pd.read_csv(dir + '\\data\\LikesComments\\thewokesalaryman.txt', delimiter = "\t"))
data = data.append(pd.read_csv(dir + '\\data\\LikesComments\\seedlysg.txt',  delimiter = "\t"))
data = data.append(pd.read_csv(dir + '\\data\\LikesComments\\mortgageconsultancy.txt', delimiter = "\t"))

data.shape
# Out:
# (1655, 7)

# %%
# format date to GMT +8
data['date']=data['date'].apply(lambda x: parser.parse(x)+timedelta(hours=8))
data.head()
# Out:
#                                              comment     commenter  \
# 0  DollarsAndSense is at the AIA #OneMoreHour of ...  dnssingapore
# 1  DollarsAndSense Managing Editor was present at...  dnssingapore
# 2          The Search For Yield In Growing Wealth 💰💰  dnssingapore
# 3  An infographic highlighting the changes for th...  dnssingapore
# 4
#
#                        date  num_comment num_likes  \
# 0 2019-09-16 15:48:36+00:00            0        16
# 1 2019-08-31 18:41:52+00:00            0        25
# 2 2019-08-24 14:47:12+00:00            0        13
# 3 2019-08-19 18:09:26+00:00            0        31
# 4 2019-08-19 09:41:53+00:00            0         5
#
#                                    url      username
# 0  http://instagram.com/p/B2dtrB8HuHq/  dnssingapore
# 1  http://instagram.com/p/B100yHtHups/  dnssingapore
# 2  http://instagram.com/p/B1iYXQ5Hf4a/  dnssingapore
# 3  http://instagram.com/p/B1V3iA_nOi5/  dnssingapore
# 4  http://instagram.com/p/B1U9criHb34/  dnssingapore

# %%
# format to YYYYMMDDThhmm
data['timestamp']=data['date'].apply(lambda x: x.strftime("%Y%m%dT%H%M"))

# %%
data
# Out:
#                                                comment            commenter  \
# 0    DollarsAndSense is at the AIA #OneMoreHour of ...         dnssingapore
# 1    DollarsAndSense Managing Editor was present at...         dnssingapore
# 2            The Search For Yield In Growing Wealth 💰💰         dnssingapore
# 3    An infographic highlighting the changes for th...         dnssingapore
# 4
# ..                                                 ...                  ...
# 152  Earn a minimum of S$500.00 in COMMISSION for e...  mortgageconsultancy
# 153                              Nice!!👍👍👍😘😘😗😙😚💋❤️👏👏‼️        eileen.yip.77
# 154                    Relax....We've got this!! 👇 👇 👇  mortgageconsultancy
# 155
# 156  Congratulations to Mortgage Consultancy to hav...  mortgageconsultancy
#
#                          date  num_comment num_likes  \
# 0   2019-09-16 15:48:36+00:00            0        16
# 1   2019-08-31 18:41:52+00:00            0        25
# 2   2019-08-24 14:47:12+00:00            0        13
# 3   2019-08-19 18:09:26+00:00            0        31
# 4   2019-08-19 09:41:53+00:00            0         5
# ..                        ...          ...       ...
# 152 2018-11-19 23:27:59+00:00            1        11
# 153 2018-11-19 23:27:59+00:00            1        11
# 154 2018-11-19 23:25:40+00:00            0         5
# 155 2018-11-19 23:23:24+00:00            0         7
# 156 2018-10-02 22:43:23+00:00            0         8
#
#                                      url             username      timestamp
# 0    http://instagram.com/p/B2dtrB8HuHq/         dnssingapore  20190916T1548
# 1    http://instagram.com/p/B100yHtHups/         dnssingapore  20190831T1841
# 2    http://instagram.com/p/B1iYXQ5Hf4a/         dnssingapore  20190824T1447
# 3    http://instagram.com/p/B1V3iA_nOi5/         dnssingapore  20190819T1809
# 4    http://instagram.com/p/B1U9criHb34/         dnssingapore  20190819T0941
# ..                                   ...                  ...            ...
# 152  http://instagram.com/p/BqXe-UjgpUG/  mortgageconsultancy  20181119T2327
# 153  http://instagram.com/p/BqXe-UjgpUG/  mortgageconsultancy  20181119T2327
# 154  http://instagram.com/p/BqXetYIgbkE/  mortgageconsultancy  20181119T2325
# 155  http://instagram.com/p/BqXecxDgIM5/  mortgageconsultancy  20181119T2323
# 156  http://instagram.com/p/BobztqFg0Ma/  mortgageconsultancy  20181002T2243
#
# [1655 rows x 8 columns]

# %%
data.to_csv(os.getcwd()+"/InstagramLikesComments.txt",sep='\t',encoding='utf-8')
